# %%
from bs4 import BeautifulSoup
import requests
import os
import json
from datetime import datetime
import pandas as pd
import time

# %%
url = 'https://bullet-ws.hitv.com/bullet/2020/06/23/095353/8337559/0.json'

# %%
res=requests.get(url)

# %%
res.encoding = 'utf-8'

# %%
jd=json.loads(res.text)

# %%
len(jd['data']['items'])
# Out:
# 360

# %%
jd['data']['items'][250]
# Out:
# {'id': 6837726087277809023,
#  'ids': '6837726087277809023',
#  'type': 0,
#  'uid': 2592787468,
#  'uuid': 'c0d9aa8a1aef49bfb3c19aeb99c00e75',
#  'content': '金晨冲冲冲',
#  'time': 41000,
#  'v2_up_count': 12}

# %%
jd['data']['items'][0]
# Out:
# {'id': 6837425357961885168,
#  'ids': '6837425357961885168',
#  'type': 3,
#  'uid': 756498141,
#  'uuid': '3cca0d6ca8514760a15ee0c1c40d61cf',
#  'uname': '听姐姐的',
#  'avatar': 'https://ugc.hitv.com/platform_oss/F35C20A0B33448E5BCA4DADA8E2F8129.png?x-oss-process=image/resize,m_fixed,w_120,h_120',
#  'content': '昕姐冲！！！',
#  'time': 0,
#  'v2_up_count': 24}

# %%
def get_danmu(num):
    url='https://bullet-ws.hitv.com/bullet/2020/06/23/095353/8337559/{}.json'
    danmuurl = url.format(num)
    res=requests.get(danmuurl)
    res.encoding = 'utf-8'
    jd=json.loads(res.text)
    details=[]
    for i in range(len(jd['data']['items'])):
        result={}
        result['id']=jd['data']['items'][i]['id']
        try:
            result['uname']=jd['data']['items'][i]['uname']
        except:
            result['uname']=''
        result['content']=jd['data']['items'][i]['content']
        result['time']=jd['data']['items'][i]['time']
        try:
            result['v2_up_count']=jd['data']['items'][i]['v2_up_count']
        except:
            result['v2_up_count']=''
        details.append(result)
    
    
    return details

# %%
def get_detail()

# %%
num=0
get_danmu(num)
# Out:
# [{'id': 6837425357961885168,
#   'uname': '听姐姐的',
#   'content': '昕姐冲！！！',
#   'time': 0,
#   'v2_up_count': 24},
#  {'id': 6837994106122529085,
#   'uname': '',
#   'content': '在看一次！',
#   'time': 0,
#   'v2_up_count': ''},
#  {'id': 6838116886352935403,
#   'uname': '',
#   'content': '为黄圣依，张雨绮，郑希怡打call',
#   'time': 0,
#   'v2_up_count': 10},
#  {'id': 6837307130396595873,
#   'uname': '',
#   'content': '姐姐们 我来了~~！！！',
#   'time': 0,
#   'v2_up_count': 21},
#  {'id': 6837758462741384194,
#   'uname': '',
#   'content': '我去，真的爱了，都是我喜欢的',
#   'time': 0,
#   'v2_up_count': 13},
#  {'id': 6840389057199198273,
#   'uname': '',
#   'content': '揭谛揭谛揭谛快点快点开始考科三考试',
#   'time': 0,
#   'v2_up_count': 1},
#  {'id': 6837307005842543888,
#   'uname': '',
#   'content': '啊啊啊坤坤我来了',
#   'time': 1000,
#   'v2_up_count': 51},
#  {'id': 6837307353734895986,
#   'uname': '',
#   'content': '姐姐冲啊',
#   'time': 1000,
#   'v2_up_count': 20},
#  {'id': 6837307336555026739,
#   'uname': '',
#   'content': '顾以森报道哈哈哈哈哈哈哈哈哈',
#   'time': 1000,
#   'v2_up_count': 15},
#  {'id': 6837309015887245077,
#   'uname': '',
#   'content': '来了来了！！！',
#   'time': 1156,
#   'v2_up_count': 13},
#  {'id': 6837403234585243393,
#   'uname': '',
#   'content': '来啦，打call姐姐们',
#   'time': 1103,
#   'v2_up_count': 5},
#  {'id': 6841131455182207588,
#   'uname': '',
#   'content': '打卡',
#   'time': 1988,
#   'v2_up_count': ''},
#  {'id': 6837306803979080344,
#   'uname': '',
#   'content': '天天天，可可第一',
#   'time': 2982,
#   'v2_up_count': 35},
#  {'id': 6837307108921759333,
#   'uname': '',
#   'content': '来了来了',
#   'time': 2823,
#   'v2_up_count': 25},
#  {'id': 6837306640770322718,
#   'uname': '',
#   'content': '啊啊啊啊啊郁可唯我来了',
#   'time': 2000,
#   'v2_up_count': 21},
#  {'id': 6837849073666703488,
#   'uname': '',
#   'content': '黄小明，面对姐姐们要挺住啊',
#   'time': 2000,
#   'v2_up_count': 9},
#  {'id': 6837306705194832272,
#   'uname': '',
#   'content': '终于来了！！！',
#   'time': 2000,
#   'v2_up_count': 19},
#  {'id': 6837710208783659473,
#   'uname': '',
#   'content': '姐姐我来了，哈哈哈哈哈',
#   'time': 2185,
#   'v2_up_count': 5},
#  {'id': 6837374578563311239,
#   'uname': '听姐姐的',
#   'content': '我来了我来了我来了我来了我来了姐姐们冲冲冲哈哈哈哈哈',
#   'time': 3971,
#   'v2_up_count': 54},
#  {'id': 6837307044497249669,
#   'uname': '',
#   'content': '啊啊啊啊啊啊啊啊姐姐们我来了',
#   'time': 3808,
#   'v2_up_count': 92},
#  {'id': 6837306675130061139,
#   'uname': '',
#   'content': '来了来了 我来了',
#   'time': 3000,
#   'v2_up_count': 42},
#  {'id': 6837741471850713027,
#   'uname': '',
#   'content': '宁静  宁静  宁静  为您打call  ',
#   'time': 3067,
#   'v2_up_count': 36},
#  {'id': 6838811889371654234,
#   'uname': '',
#   'content': '这里的姐姐都好彪悍啊，怕了怕了',
#   'time': 3978,
#   'v2_up_count': 13},
#  {'id': 6837306657950191927,
#   'uname': '',
#   'content': '第一啊啊啊啊啊啊',
#   'time': 3000,
#   'v2_up_count': 37},
#  {'id': 6837351145221630617,
#   'uname': '',
#   'content': '啊啊啊啊啊居然就悄无声息的播了',
#   'time': 4958,
#   'v2_up_count': 68},
#  {'id': 6838532944130441558,
#   'uname': '',
#   'content': '来了',
#   'time': 4045,
#   'v2_up_count': 2},
#  {'id': 6837306812569014962,
#   'uname': '',
#   'content': '来了来了看姐姐',
#   'time': 4938,
#   'v2_up_count': 45},
#  {'id': 6837314607934681970,
#   'uname': '',
#   'content': '姐姐们，我来了！',
#   'time': 4955,
#   'v2_up_count': 33},
#  {'id': 6837507134139612309,
#   'uname': '',
#   'content': '来看孟佳孟佳孟佳！',
#   'time': 4541,
#   'v2_up_count': 26},
#  {'id': 6837622458306599976,
#   'uname': '',
#   'content': '我来了我来了哈哈哈哈哈哈哈',
#   'time': 4000,
#   'v2_up_count': 10},
#  {'id': 6837325199324077237,
#   'uname': '',
#   'content': '开场白梦回srrx晰哥低音',
#   'time': 5211,
#   'v2_up_count': 109},
#  {'id': 6837327449886950340,
#   'uname': '',
#   'content': '黄晓明开始历险可还行',
#   'time': 5182,
#   'v2_up_count': 68},
#  {'id': 6839073727758125841,
#   'uname': '',
#   'content': '看了好几遍啦   姐姐们 加油啊',
#   'time': 5039,
#   'v2_up_count': 3},
#  {'id': 6837322441955060774,
#   'uname': '',
#   'content': '宁静宁静！',
#   'time': 5990,
#   'v2_up_count': 65},
#  {'id': 6838956075718921026,
#   'uname': '',
#   'content': '哪个姐姐我都想pick',
#   'time': 5357,
#   'v2_up_count': 2},
#  {'id': 6840044338828490145,
#   'uname': '',
#   'content': '恍恍惚惚哈哈',
#   'time': 5000,
#   'v2_up_count': 1},
#  {'id': 6837510179271436397,
#   'uname': '实力唱将',
#   'content': '为吴昕而来😍😍给我冲啊姐姐！！！',
#   'time': 6297,
#   'v2_up_count': 29},
#  {'id': 6838393379167952649,
#   'uname': '',
#   'content': '来了来了来了！！！！给姐姐们打call！！',
#   'time': 6137,
#   'v2_up_count': 4},
#  {'id': 6837374922160696603,
#   'uname': '',
#   'content': '付仙女，爸爸爱你',
#   'time': 6938,
#   'v2_up_count': 15},
#  {'id': 6837866627198106893,
#   'uname': '气场强大',
#   'content': '来看宁静了 哈哈',
#   'time': 6000,
#   'v2_up_count': 11},
#  {'id': 6840776080997798228,
#   'uname': '',
#   'content': '看了觉得伊能静姐姐好温柔！',
#   'time': 6000,
#   'v2_up_count': ''},
#  {'id': 6837670592005179740,
#   'uname': '',
#   'content': '啊啊啊啊姐姐们我来了！',
#   'time': 6015,
#   'v2_up_count': 2},
#  {'id': 6837378130501282257,
#   'uname': '气场强大',
#   'content': '姐姐们我来了',
#   'time': 7240,
#   'v2_up_count': 30},
#  {'id': 6837662156689388764,
#   'uname': '拎包妹',
#   'content': '刷第二遍了，全部看完要五个小时，哈哈哈',
#   'time': 7022,
#   'v2_up_count': 16},
#  {'id': 6837309050246983556,
#   'uname': '',
#   'content': '哈哈哈哈哈哈我来了姐姐们',
#   'time': 7093,
#   'v2_up_count': 24},
#  {'id': 6838102356478536108,
#   'uname': '听姐姐的',
#   'content': '昕姐昕姐加油加油(ง •̀_•́)ง',
#   'time': 7972,
#   'v2_up_count': 12},
#  {'id': 6839917053177350196,
#   'uname': '',
#   'content': '哈哈哈千呼万唤始出来啊',
#   'time': 7000,
#   'v2_up_count': 2},
#  {'id': 6839857597944981712,
#   'uname': '',
#   'content': '看多了其他的选秀节目，把姐姐们想得简单了',
#   'time': 7131,
#   'v2_up_count': ''},
#  {'id': 6837306726669668807,
#   'uname': '',
#   'content': '万茜冲啊！！！！筒子来啦！！！！',
#   'time': 8135,
#   'v2_up_count': 56},
#  {'id': 6837307770346725026,
#   'uname': '',
#   'content': '万茜冲啊！',
#   'time': 8769,
#   'v2_up_count': 32},
#  {'id': 6837653257517130157,
#   'uname': '',
#   'content': '晓明哥的微博，每一位哈哈哈哈哈哈笑死我',
#   'time': 8000,
#   'v2_up_count': 8},
#  {'id': 6837393003973098571,
#   'uname': '听姐姐的',
#   'content': '这个综艺我锁了',
#   'time': 8000,
#   'v2_up_count': 30},
#  {'id': 6839566953212870211,
#   'uname': '',
#   'content': '哈哈哈我是来看各位漂亮姐姐互撕的哈哈哈哈',
#   'time': 8000,
#   'v2_up_count': 5},
#  {'id': 6840280020864215984,
#   'uname': '',
#   'content': '啊啊啊 姐姐们我来了',
#   'time': 8299,
#   'v2_up_count': 4},
#  {'id': 6837728329250745126,
#   'uname': '',
#   'content': '小明历险记哈哈哈哈哈',
#   'time': 9000,
#   'v2_up_count': 76},
#  {'id': 6837442533536186579,
#   'uname': '听姐姐的',
#   'content': '哈哈哈哈哈哈   来了来了',
#   'time': 9729,
#   'v2_up_count': 35},
#  {'id': 6837627251490107790,
#   'uname': '',
#   'content': '没有一点点防备你就这样出现',
#   'time': 9000,
#   'v2_up_count': 24},
#  {'id': 6837307886310842388,
#   'uname': '',
#   'content': '给绮绮子排面！',
#   'time': 9855,
#   'v2_up_count': 44},
#  {'id': 6837335047684131484,
#   'uname': '听姐姐的',
#   'content': '啊啊啊啊啊，来了来了',
#   'time': 9753,
#   'v2_up_count': 21},
#  {'id': 6837309655837374003,
#   'uname': '',
#   'content': '来报道啦啊啊啊啊啊啊乘风破浪的姐姐们加油pick你们',
#   'time': 9000,
#   'v2_up_count': 18},
#  {'id': 6838609334418892864,
#   'uname': '',
#   'content': '这个文案爱了',
#   'time': 10130,
#   'v2_up_count': 6},
#  {'id': 6837332509358447504,
#   'uname': '',
#   'content': '昕昕子给我冲冲冲冲冲冲冲冲冲冲',
#   'time': 10041,
#   'v2_up_count': 18},
#  {'id': 6837320019593495292,
#   'uname': '',
#   'content': '张雨绮姐姐冲！',
#   'time': 10651,
#   'v2_up_count': 61},
#  {'id': 6837346433642485228,
#   'uname': '听姐姐的',
#   'content': '来了来了哈哈哈哈哈 让我来康康',
#   'time': 10000,
#   'v2_up_count': 16},
#  {'id': 6837724609809054226,
#   'uname': '',
#   'content': '姐子们我来看你们了！',
#   'time': 10768,
#   'v2_up_count': 13},
#  {'id': 6837626585770176035,
#   'uname': '',
#   'content': '芒果搞快点 下下一集快点出啊！！！！',
#   'time': 10131,
#   'v2_up_count': 7},
#  {'id': 6837448735468994354,
#   'uname': '',
#   'content': '啥时候开始的，没一点消息',
#   'time': 11588,
#   'v2_up_count': 19},
#  {'id': 6837324168531921557,
#   'uname': '',
#   'content': '期待吴昕！！！！',
#   'time': 11226,
#   'v2_up_count': 23},
#  {'id': 6840835965726914530,
#   'uname': '',
#   'content': '啊啊啊啊为了莎莎才来的！！金小莎我爱你！！！',
#   'time': 11000,
#   'v2_up_count': ''},
#  {'id': 6838505241591344647,
#   'uname': '实力唱将',
#   'content': '来了来了姐姐们我又来了',
#   'time': 11014,
#   'v2_up_count': 9},
#  {'id': 6837325834979239877,
#   'uname': '',
#   'content': '不错子 来了啦了',
#   'time': 11000,
#   'v2_up_count': 11},
#  {'id': 6839290048081133010,
#   'uname': '',
#   'content': '终于等到了啊啊啊，啊啊啊啊啊',
#   'time': 11020,
#   'v2_up_count': ''},
#  {'id': 6837360942042080005,
#   'uname': '气场强大',
#   'content': '吴昕加油！你一票我一票明天吴昕就出道',
#   'time': 12685,
#   'v2_up_count': 72},
#  {'id': 6837311743191486046,
#   'uname': '',
#   'content': '期待金晨',
#   'time': 12051,
#   'v2_up_count': 49},
#  {'id': 6837351922610714788,
#   'uname': '跟班小弟',
#   'content': '姐姐们我来啦',
#   'time': 12444,
#   'v2_up_count': 28},
#  {'id': 6837626401086582053,
#   'uname': '',
#   'content': '哈哈哈哈哈就我是冲海陆来的吗',
#   'time': 12012,
#   'v2_up_count': 12},
#  {'id': 6837309234930577835,
#   'uname': '',
#   'content': '郁可唯！！？！',
#   'time': 12002,
#   'v2_up_count': 22},
#  {'id': 6840283920694530981,
#   'uname': '',
#   'content': '宁静宁静！！！！？！！！',
#   'time': 12036,
#   'v2_up_count': ''},
#  {'id': 6837343358445887222,
#   'uname': '',
#   'content': '吴昕加油',
#   'time': 13053,
#   'v2_up_count': 70},
#  {'id': 6837360199012734314,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 13835,
#   'v2_up_count': 33},
#  {'id': 6837703633188704102,
#   'uname': '',
#   'content': '佳菲猫 miss a冲啊！！！！',
#   'time': 13040,
#   'v2_up_count': 12},
#  {'id': 6838908955632650599,
#   'uname': '',
#   'content': '喜欢李斯丹妮跟含韵，丁当，宁静，',
#   'time': 13409,
#   'v2_up_count': 3},
#  {'id': 6837306782504243789,
#   'uname': '',
#   'content': '终于！',
#   'time': 13000,
#   'v2_up_count': 14},
#  {'id': 6838669360881852839,
#   'uname': '跟班小弟',
#   'content': '啊啊啊啊啊啊啊啊啊啊霏霏给我冲鸭！！',
#   'time': 13000,
#   'v2_up_count': ''},
#  {'id': 6837427943532209658,
#   'uname': '听姐姐的',
#   'content': '必须留名啊！可以载入综艺史册的！',
#   'time': 14849,
#   'v2_up_count': 19},
#  {'id': 6837342495157456763,
#   'uname': '听姐姐的',
#   'content': '姐姐们我来了',
#   'time': 14317,
#   'v2_up_count': 27},
#  {'id': 6837440738239847613,
#   'uname': '听姐姐的',
#   'content': '这个旁白人声可以，表白这个旁白人声小哥哥',
#   'time': 14987,
#   'v2_up_count': 17},
#  {'id': 6837389121322644797,
#   'uname': '听姐姐的',
#   'content': '欣姐加油欣姐加油',
#   'time': 14584,
#   'v2_up_count': 18},
#  {'id': 6841117002617235679,
#   'uname': '气场强大',
#   'content': '啊啊啊啊啊，乘风破浪的小姐姐们我来了！攒了两期还是没忍住就来了。哈哈！',
#   'time': 14505,
#   'v2_up_count': 1},
#  {'id': 6837483309955908168,
#   'uname': '气场强大',
#   'content': '昕昕子 加油鸭',
#   'time': 14049,
#   'v2_up_count': 12},
#  {'id': 6837660825249523735,
#   'uname': '听姐姐的',
#   'content': '终于等到你',
#   'time': 15839,
#   'v2_up_count': 17},
#  {'id': 6837407280444453738,
#   'uname': '气场强大',
#   'content': '姐姐们我来啦！！！',
#   'time': 15000,
#   'v2_up_count': 17},
#  {'id': 6837306735259603419,
#   'uname': '',
#   'content': '来了来了姐姐们好',
#   'time': 15607,
#   'v2_up_count': 16},
#  {'id': 6837418687877643669,
#   'uname': '最强舞担',
#   'content': '这是不是花少的背景人声',
#   'time': 15000,
#   'v2_up_count': 4},
#  {'id': 6838009546529975545,
#   'uname': '',
#   'content': '啊啊啊啊姐姐蓝盈莹pick她！！❤️❤️❤️冲啊！',
#   'time': 15960,
#   'v2_up_count': 1},
#  {'id': 6837378358134550065,
#   'uname': '太后驾到',
#   'content': '特意冲了会员',
#   'time': 15857,
#   'v2_up_count': 14},
#  {'id': 6837429343691554944,
#   'uname': '听姐姐的',
#   'content': '吴昕  金晨   宁静   张雨绮出道吧',
#   'time': 16009,
#   'v2_up_count': 11},
#  {'id': 6837340270364387130,
#   'uname': '',
#   'content': '小明历险记我来啦',
#   'time': 16000,
#   'v2_up_count': 42},
#  {'id': 6837701867957138437,
#   'uname': '拎包妹',
#   'content': '来看姐姐了！！！静姐冲！！！',
#   'time': 16284,
#   'v2_up_count': 9},
#  {'id': 6837649443586163052,
#   'uname': '',
#   'content': '有人说不够流行就不够资格哈哈哈',
#   'time': 16635,
#   'v2_up_count': 8},
#  {'id': 6840290088267585705,
#   'uname': '',
#   'content': '为姐姐们加油 不一样的女团 跨界勇敢 蓝盈莹金晨 黄晓明制作人主持加油 教主暖心',
#   'time': 16797,
#   'v2_up_count': ''},
#  {'id': 6837317399663434313,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 16496,
#   'v2_up_count': 8},
#  {'id': 6837455667546247271,
#   'uname': '气场强大',
#   'content': '吴昕姐姐，加油加油💪，你一票我一票明天昕姐能出道。',
#   'time': 17000,
#   'v2_up_count': 12},
#  {'id': 6837314092538604687,
#   'uname': '',
#   'content': '孟佳霏霏加油',
#   'time': 17870,
#   'v2_up_count': 64},
#  {'id': 6837322222911727678,
#   'uname': '',
#   'content': '来啦来啦，淋雨一直走前来打call，昕昕子冲啊',
#   'time': 17000,
#   'v2_up_count': 8},
#  {'id': 6839593642139673248,
#   'uname': '',
#   'content': '海陆的当时是说自己的 而且声音很小',
#   'time': 17686,
#   'v2_up_count': 7},
#  {'id': 6837318713923431939,
#   'uname': '',
#   'content': '天呐哇哇哇',
#   'time': 17270,
#   'v2_up_count': 8},
#  {'id': 6837773727055195172,
#   'uname': '',
#   'content': '姐姐们冲啊！！！！！！！！！！',
#   'time': 17000,
#   'v2_up_count': 2},
#  {'id': 6837605003559495476,
#   'uname': '',
#   'content': '我大湖南台还是牛',
#   'time': 18000,
#   'v2_up_count': 22},
#  {'id': 6837324336035646859,
#   'uname': '',
#   'content': '姐姐们最牛 冲！！！！',
#   'time': 18778,
#   'v2_up_count': 22},
#  {'id': 6837812506315020955,
#   'uname': '',
#   'content': '王霏霏 孟佳冲啊！！！！！',
#   'time': 18957,
#   'v2_up_count': 14},
#  {'id': 6838861599323192529,
#   'uname': '',
#   'content': '蓝盈莹 沈梦辰 吴昕 给我冲！！！',
#   'time': 18106,
#   'v2_up_count': 2},
#  {'id': 6837351570423394869,
#   'uname': '演技派',
#   'content': '万茜冲冲冲',
#   'time': 18000,
#   'v2_up_count': 20},
#  {'id': 6839581083655287981,
#   'uname': '',
#   'content': '万茜姐姐姐姐我来了啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊',
#   'time': 18419,
#   'v2_up_count': 1},
#  {'id': 6837329060499693294,
#   'uname': '',
#   'content': '金晨加油！',
#   'time': 19000,
#   'v2_up_count': 24},
#  {'id': 6837306834043851504,
#   'uname': '',
#   'content': '我来了！！期待万茜',
#   'time': 19000,
#   'v2_up_count': 24},
#  {'id': 6837606107366091172,
#   'uname': '',
#   'content': '刚冲的会员，听说挺好看的',
#   'time': 19604,
#   'v2_up_count': 4},
#  {'id': 6837306782504243795,
#   'uname': '',
#   'content': '第一第一，期待姐姐们',
#   'time': 19855,
#   'v2_up_count': 17},
#  {'id': 6837998388204927176,
#   'uname': '',
#   'content': '哇哇哇,等好久了，居然悄无声息的开始了',
#   'time': 19000,
#   'v2_up_count': 2},
#  {'id': 6840454168903549062,
#   'uname': '',
#   'content': '啊啊啊啊啊，期待已久',
#   'time': 19961,
#   'v2_up_count': ''},
#  {'id': 6837353382899602477,
#   'uname': '听姐姐的',
#   'content': '为所有姐姐打call',
#   'time': 20703,
#   'v2_up_count': 21},
#  {'id': 6837306864108622673,
#   'uname': '',
#   'content': '我来了我来了宁静姐加油张雨绮加油吴昕加油',
#   'time': 20128,
#   'v2_up_count': 21},
#  {'id': 6837478125930355399,
#   'uname': '',
#   'content': '好多姐姐都好喜欢',
#   'time': 20827,
#   'v2_up_count': 15},
#  {'id': 6837626074669067143,
#   'uname': '',
#   'content': '来了。。。来了 !!! ',
#   'time': 20367,
#   'v2_up_count': 4},
#  {'id': 6837800244183355943,
#   'uname': '',
#   'content': '哈哈哈，等了好久终于等到了',
#   'time': 20031,
#   'v2_up_count': 3},
#  {'id': 6838518560284946805,
#   'uname': '',
#   'content': '声音真好听，感觉这节目高大上',
#   'time': 20006,
#   'v2_up_count': 1},
#  {'id': 6837414027838105925,
#   'uname': '',
#   'content': '宁静姐姐！！！（尖叫！）',
#   'time': 21071,
#   'v2_up_count': 34},
#  {'id': 6837457175079776043,
#   'uname': '听姐姐的',
#   'content': '你一票，我一票，姐姐都出道',
#   'time': 21606,
#   'v2_up_count': 17},
#  {'id': 6839527340729432154,
#   'uname': '',
#   'content': '为晓明来的，他最近演的鬓边不是海棠红超棒',
#   'time': 21924,
#   'v2_up_count': 1},
#  {'id': 6840711025128053926,
#   'uname': '',
#   'content': '天哪陈松林就是小时候觉得那个很漂亮的女演员',
#   'time': 21000,
#   'v2_up_count': ''},
#  {'id': 6837427093128680959,
#   'uname': '气场强大',
#   'content': '女王们！！！！！！！我来了！！！！！！',
#   'time': 21161,
#   'v2_up_count': 14},
#  {'id': 6839174784043693182,
#   'uname': '',
#   'content': '终于等到你，为啥没有通知，还好我没错过你。',
#   'time': 21637,
#   'v2_up_count': ''},
#  {'id': 6837322158487217959,
#   'uname': '',
#   'content': '为静姐打call',
#   'time': 22038,
#   'v2_up_count': 24},
#  {'id': 6837425237702800328,
#   'uname': '太后驾到',
#   'content': '每次都是为了看综艺开VIP😭',
#   'time': 22927,
#   'v2_up_count': 18},
#  {'id': 6837306881288491905,
#   'uname': '',
#   'content': '来了老姐',
#   'time': 22005,
#   'v2_up_count': 21},
#  {'id': 6837324658158195498,
#   'uname': '',
#   'content': '来啦  姐姐们冲鸭',
#   'time': 22433,
#   'v2_up_count': 14},
#  {'id': 6838149953306221409,
#   'uname': '',
#   'content': '第二遍我来了哈哈哈哈哈',
#   'time': 22000,
#   'v2_up_count': 9},
#  {'id': 6839737360335499932,
#   'uname': '',
#   'content': '这个旁白是不是王晰啊，跟声入人心好像',
#   'time': 22000,
#   'v2_up_count': 2},
#  {'id': 6837857805335250226,
#   'uname': '',
#   'content': '这段话让姐姐说啊',
#   'time': 23203,
#   'v2_up_count': 13},
#  {'id': 6837409135870333726,
#   'uname': '听姐姐的',
#   'content': '爱宁静，爱金晨',
#   'time': 23628,
#   'v2_up_count': 34},
#  {'id': 6837441300880566315,
#   'uname': '听姐姐的',
#   'content': '我的妈，才知道可以看了',
#   'time': 23756,
#   'v2_up_count': 12},
#  {'id': 6838061562879017411,
#   'uname': '',
#   'content': '为了看这个综艺专门开的会员哈哈哈哈哈',
#   'time': 23846,
#   'v2_up_count': 2},
#  {'id': 6837306829748884198,
#   'uname': '',
#   'content': '郁可唯冲',
#   'time': 23570,
#   'v2_up_count': 13},
#  {'id': 6837432393118350137,
#   'uname': '听姐姐的',
#   'content': '来啦来啦！！！姐姐们冲鸭！！',
#   'time': 23290,
#   'v2_up_count': 10},
#  {'id': 6837619280030797832,
#   'uname': '',
#   'content': '高跟鞋哒哒声听到就有气势',
#   'time': 24000,
#   'v2_up_count': 17},
#  {'id': 6838111023722561965,
#   'uname': '',
#   'content': '吴昕 加油(ง •̀_•́)ง',
#   'time': 24250,
#   'v2_up_count': 11},
#  {'id': 6839221466043283239,
#   'uname': '听姐姐的',
#   'content': '哇哦',
#   'time': 24667,
#   'v2_up_count': 1},
#  {'id': 6839919153416368222,
#   'uname': '',
#   'content': '为了看  直接开了个会员',
#   'time': 24791,
#   'v2_up_count': 2},
#  {'id': 6837306838338818820,
#   'uname': '',
#   'content': '啊啊啊啊啊啊哦',
#   'time': 24049,
#   'v2_up_count': 11},
#  {'id': 6841352620228316924,
#   'uname': '',
#   'content': '啊啊啊啊啊啊黄圣依我好可',
#   'time': 24854,
#   'v2_up_count': ''},
#  {'id': 6837314298697035629,
#   'uname': '',
#   'content': '欢迎收看《晓明历险记》',
#   'time': 25000,
#   'v2_up_count': 133},
#  {'id': 6837415664220653249,
#   'uname': '气场强大',
#   'content': '陈松伶，唱的比原版还要好啊，好给力',
#   'time': 25778,
#   'v2_up_count': 13},
#  {'id': 6837338049866285061,
#   'uname': '听姐姐的',
#   'content': '来喽',
#   'time': 25838,
#   'v2_up_count': 21},
#  {'id': 6839194884490663792,
#   'uname': '',
#   'content': '欣欣子(ง •̀_•́)ง',
#   'time': 25049,
#   'v2_up_count': 6},
#  {'id': 6837306834043851506,
#   'uname': '',
#   'content': '我来了',
#   'time': 25000,
#   'v2_up_count': 7},
#  {'id': 6838870953761972487,
#   'uname': '',
#   'content': '吴昕沈梦辰爱你们哦！',
#   'time': 25095,
#   'v2_up_count': 5},
#  {'id': 6837306816863982276,
#   'uname': '',
#   'content': '这就开始了？',
#   'time': 26460,
#   'v2_up_count': 27},
#  {'id': 6837306894173393830,
#   'uname': '',
#   'content': '来看美昕啦',
#   'time': 26000,
#   'v2_up_count': 18},
#  {'id': 6837365301433906889,
#   'uname': '',
#   'content': '冲呀 琦琦子',
#   'time': 26000,
#   'v2_up_count': 16},
#  {'id': 6837307323670124813,
#   'uname': '',
#   'content': '郁可唯冲',
#   'time': 26000,
#   'v2_up_count': 14},
#  {'id': 6837424267040186911,
#   'uname': '气场强大',
#   'content': '期待姐姐们～来啦',
#   'time': 26046,
#   'v2_up_count': 2},
#  {'id': 6837306868403589984,
#   'uname': '',
#   'content': '啊啊啊啊啊啊啊啊啊啊啊来了姐姐们我来了',
#   'time': 26053,
#   'v2_up_count': 6},
#  {'id': 6837329013255052818,
#   'uname': '',
#   'content': '第一次追选秀综艺就交给姐姐们了',
#   'time': 27865,
#   'v2_up_count': 50},
#  {'id': 6837372160496711893,
#   'uname': '听姐姐的',
#   'content': '为黄晓明打call哈哈哈哈',
#   'time': 27000,
#   'v2_up_count': 21},
#  {'id': 6837365752405475170,
#   'uname': '演技派',
#   'content': '万茜姐姐我来了！万花筒给你撑腰了！',
#   'time': 27064,
#   'v2_up_count': 14},
#  {'id': 6837811170580188274,
#   'uname': '',
#   'content': '我不喜欢看选秀，但这个的精彩吸引我了',
#   'time': 27845,
#   'v2_up_count': 3},
#  {'id': 6837338346219029797,
#   'uname': '',
#   'content': '冲鸭姐姐们',
#   'time': 27638,
#   'v2_up_count': 12},
#  {'id': 6837584503680582989,
#   'uname': '',
#   'content': '等我下班在看',
#   'time': 27054,
#   'v2_up_count': 2},
#  {'id': 6837630468420616795,
#   'uname': '',
#   'content': '猝不及防的开始了',
#   'time': 28270,
#   'v2_up_count': 58},
#  {'id': 6837307044497249686,
#   'uname': '',
#   'content': '昕昕子',
#   'time': 28858,
#   'v2_up_count': 83},
#  {'id': 6837451127765790982,
#   'uname': '',
#   'content': '金沙 吴昕 张含韵!!!',
#   'time': 28000,
#   'v2_up_count': 20},
#  {'id': 6837344470842421933,
#   'uname': '拎包妹',
#   'content': '工作人员辛苦了',
#   'time': 28000,
#   'v2_up_count': 24},
#  {'id': 6840704312094157815,
#   'uname': '',
#   'content': '我来啦  特地续费我的会员来啦 来看姐姐们',
#   'time': 28000,
#   'v2_up_count': ''},
#  {'id': 6837348027075359376,
#   'uname': '太后驾到',
#   'content': '晓明哥加油 挺住哈哈哈哈哈哈哈哈哈',
#   'time': 28000,
#   'v2_up_count': 12},
#  {'id': 6837306842633786125,
#   'uname': '',
#   'content': '本年度最期待的综艺哈哈哈哈哈哈哈',
#   'time': 29000,
#   'v2_up_count': 99},
#  {'id': 6837883463469949575,
#   'uname': '',
#   'content': '我是朋友介绍过来看的，听说很搞笑，期待！🤣',
#   'time': 29000,
#   'v2_up_count': 2},
#  {'id': 6837324512129306805,
#   'uname': '',
#   'content': '55555爱死茜茜子了',
#   'time': 29608,
#   'v2_up_count': 7},
#  {'id': 6840314951833330946,
#   'uname': '',
#   'content': '啊啊啊啊啊，乘风破浪的姐姐们，冲啊',
#   'time': 29543,
#   'v2_up_count': 1},
#  {'id': 6837774375595258736,
#   'uname': '',
#   'content': '来啦！期待(๑˙ー˙๑)',
#   'time': 29974,
#   'v2_up_count': 2},
#  {'id': 6840429833618785676,
#   'uname': '',
#   'content': '这都是神仙级的姐姐了',
#   'time': 29515,
#   'v2_up_count': ''},
#  {'id': 6837353176741171257,
#   'uname': '',
#   'content': '表示敬佩节目组',
#   'time': 30870,
#   'v2_up_count': 112},
#  {'id': 6837500202062365726,
#   'uname': '',
#   'content': '张含韵，仙女，出道吧',
#   'time': 30966,
#   'v2_up_count': 13},
#  {'id': 6840849520643720353,
#   'uname': '',
#   'content': '张雨绮，宁静冲啊啊啊啊',
#   'time': 30000,
#   'v2_up_count': ''},
#  {'id': 6837306885583459215,
#   'uname': '',
#   'content': '终于等到你！',
#   'time': 30000,
#   'v2_up_count': 10},
#  {'id': 6837390010380879271,
#   'uname': '',
#   'content': '姐姐们冲啊！！',
#   'time': 30000,
#   'v2_up_count': 9},
#  {'id': 6840680548040054960,
#   'uname': '跟班小弟',
#   'content': '被妈妈安利(ღ˘⌣˘ღ)',
#   'time': 30890,
#   'v2_up_count': ''},
#  {'id': 6837308058109534844,
#   'uname': '',
#   'content': '昕昕我来了',
#   'time': 31019,
#   'v2_up_count': 19},
#  {'id': 6837411811634971134,
#   'uname': '最强舞担',
#   'content': '哈哈哈哈哈  激动',
#   'time': 31641,
#   'v2_up_count': 9},
#  {'id': 6837318589369379861,
#   'uname': '',
#   'content': '昕昕子加油！',
#   'time': 31000,
#   'v2_up_count': 11},
#  {'id': 6837353743676857079,
#   'uname': '',
#   'content': '来了来了，来看孟佳和霏',
#   'time': 31210,
#   'v2_up_count': 6},
#  {'id': 6837389941661402214,
#   'uname': '气场强大',
#   'content': '姐姐们冲呀',
#   'time': 31018,
#   'v2_up_count': 7},
#  {'id': 6837593913953932108,
#   'uname': '听姐姐的',
#   'content': '宁静大姐大   最爱',
#   'time': 31307,
#   'v2_up_count': 2},
#  {'id': 6837306868403589987,
#   'uname': '',
#   'content': '昕姐',
#   'time': 32105,
#   'v2_up_count': 23},
#  {'id': 6837306924238165004,
#   'uname': '',
#   'content': '李斯丹妮冲冲冲',
#   'time': 32000,
#   'v2_up_count': 20},
#  {'id': 6837307018727445813,
#   'uname': '',
#   'content': '我竟然知道12点开始',
#   'time': 32648,
#   'v2_up_count': 9},
#  {'id': 6837449319584549707,
#   'uname': '实力唱将',
#   'content': '唯唯子冲啊！！！！！！！',
#   'time': 32000,
#   'v2_up_count': 6},
#  {'id': 6837348881773855092,
#   'uname': '气场强大',
#   'content': '孟佳冲冲冲！！！',
#   'time': 32997,
#   'v2_up_count': 7},
#  {'id': 6837648253880219590,
#   'uname': '',
#   'content': '加油(ง •̀_•́)ง',
#   'time': 32695,
#   'v2_up_count': 1},
#  {'id': 6837623940070318643,
#   'uname': '',
#   'content': '终于开播了。',
#   'time': 33043,
#   'v2_up_count': 3},
#  {'id': 6837399918870476408,
#   'uname': '拎包妹',
#   'content': '来了来了',
#   'time': 33956,
#   'v2_up_count': 10},
#  {'id': 6837440987347952112,
#   'uname': '气场强大',
#   'content': '静姐~宁静~',
#   'time': 33076,
#   'v2_up_count': 7},
#  {'id': 6837694472023425230,
#   'uname': '听姐姐的',
#   'content': '来啦！！~~~',
#   'time': 33217,
#   'v2_up_count': 4},
#  {'id': 6838698424925548944,
#   'uname': '',
#   'content': '终于能看正片了',
#   'time': 33000,
#   'v2_up_count': 2},
#  {'id': 6837306924238165002,
#   'uname': '',
#   'content': '我来了！！！',
#   'time': 33822,
#   'v2_up_count': 6},
#  {'id': 6839088377891575240,
#   'uname': '',
#   'content': '来了',
#   'time': 34768,
#   'v2_up_count': 1},
#  {'id': 6837826568037988461,
#   'uname': '',
#   'content': '昕昕子加油！',
#   'time': 34182,
#   'v2_up_count': 12},
#  {'id': 6837602211830751613,
#   'uname': '',
#   'content': '吴昕沈梦辰钟丽缇伊能静冲鸭！！！',
#   'time': 34124,
#   'v2_up_count': 8},
#  {'id': 6837472447983560072,
#   'uname': '听姐姐的',
#   'content': '来了来了，为什么一点消息都没有',
#   'time': 34299,
#   'v2_up_count': 2},
#  {'id': 6838500422638032039,
#   'uname': '',
#   'content': '四刷！！！！！芒果给我搞快点！！！！！',
#   'time': 34228,
#   'v2_up_count': ''},
#  {'id': 6838126060403101429,
#   'uname': '',
#   'content': '来了来了，从不追综艺的我',
#   'time': 34995,
#   'v2_up_count': 1},
#  {'id': 6837859729480605807,
#   'uname': '',
#   'content': '文案走心了，不愧是芒果台',
#   'time': 35000,
#   'v2_up_count': 6},
#  {'id': 6837307027317380448,
#   'uname': '',
#   'content': '姐姐们我来了',
#   'time': 35383,
#   'v2_up_count': 12},
#  {'id': 6837378774746379765,
#   'uname': '听姐姐的',
#   'content': '什么时候播的，怎么不知道啊',
#   'time': 35000,
#   'v2_up_count': 6},
#  {'id': 6838354127461805715,
#   'uname': '',
#   'content': '晓明哥应该退位让贤给我们朱一龙哥哥啦',
#   'time': 35757,
#   'v2_up_count': 2},
#  {'id': 6837306924238165018,
#   'uname': '',
#   'content': '郁可唯大vocal',
#   'time': 35000,
#   'v2_up_count': 4},
#  {'id': 6840606288055347683,
#   'uname': '',
#   'content': '姐姐们冲鸭！加油',
#   'time': 35000,
#   'v2_up_count': ''},
#  {'id': 6837447232230432829,
#   'uname': '听姐姐的',
#   'content': '昕姐加油(ง •̀_•́)ง',
#   'time': 36358,
#   'v2_up_count': 26},
#  {'id': 6837407374933734659,
#   'uname': '',
#   'content': '昕昕子我和你一起乘风破浪',
#   'time': 36804,
#   'v2_up_count': 14},
#  {'id': 6837779374937205361,
#   'uname': '',
#   'content': '这个字幕咋回事啊，只能看一半儿',
#   'time': 36105,
#   'v2_up_count': 2},
#  {'id': 6837686363125138939,
#   'uname': '浪花崽',
#   'content': '昕昕子冲呀！',
#   'time': 36971,
#   'v2_up_count': 5},
#  {'id': 6837306975777772718,
#   'uname': '',
#   'content': '熊奥在看吧',
#   'time': 36367,
#   'v2_up_count': 6},
#  {'id': 6839919561438263368,
#   'uname': '',
#   'content': '撕起来时候想想都非常有看点!!',
#   'time': 36814,
#   'v2_up_count': 1},
#  {'id': 6837351085092088190,
#   'uname': '听姐姐的',
#   'content': '第一次追这个类型节目',
#   'time': 37000,
#   'v2_up_count': 6},
#  {'id': 6838644750719240666,
#   'uname': '',
#   'content': 'miss A冲啊',
#   'time': 37526,
#   'v2_up_count': 2},
#  {'id': 6837306971482805418,
#   'uname': '',
#   'content': '来了来了',
#   'time': 37043,
#   'v2_up_count': 3},
#  {'id': 6837322734012838218,
#   'uname': '',
#   'content': '我来啦哈哈哈哈',
#   'time': 37963,
#   'v2_up_count': 2},
#  {'id': 6839231632230881681,
#   'uname': '',
#   'content': '来了，好看(｡･ω･｡)ﾉ♡',
#   'time': 37085,
#   'v2_up_count': ''},
#  {'id': 6839911259266443250,
#   'uname': '',
#   'content': '好看',
#   'time': 37000,
#   'v2_up_count': ''},
#  {'id': 6837659450859985665,
#   'uname': '',
#   'content': '不要惹30岁以上的女人',
#   'time': 38860,
#   'v2_up_count': 51},
#  {'id': 6837773718465260547,
#   'uname': '',
#   'content': '张含韵怎么越来越可爱了',
#   'time': 38547,
#   'v2_up_count': 36},
#  {'id': 6838780695024142808,
#   'uname': '',
#   'content': '美女们等着我哈😄',
#   'time': 38140,
#   'v2_up_count': 1},
#  {'id': 6839284340069588589,
#   'uname': '',
#   'content': '每个年龄都有自己的魅力。冲就完了。',
#   'time': 38051,
#   'v2_up_count': 2},
#  {'id': 6839518119434639540,
#   'uname': '',
#   'content': '昕姐加油，fighting！！！',
#   'time': 38070,
#   'v2_up_count': 1},
#  {'id': 6837306945713001560,
#   'uname': '',
#   'content': '小雨妈妈来了！！！',
#   'time': 38884,
#   'v2_up_count': 5},
#  {'id': 6838452795745621459,
#   'uname': '',
#   'content': '来看小明历险记啦哈哈哈哈哈哈哈哈哈',
#   'time': 39869,
#   'v2_up_count': 7},
#  {'id': 6837409445107980403,
#   'uname': '听姐姐的',
#   'content': '昕姐冲冲冲',
#   'time': 39089,
#   'v2_up_count': 11},
#  {'id': 6840002952523526183,
#   'uname': '太后驾到',
#   'content': '金晨给我冲！',
#   'time': 39038,
#   'v2_up_count': 1},
#  {'id': 6837412417225362585,
#   'uname': '',
#   'content': '有综艺追了',
#   'time': 39000,
#   'v2_up_count': 6},
#  {'id': 6841344429725678870,
#   'uname': '',
#   'content': '啊！！！！来啦来啦！！！！',
#   'time': 39549,
#   'v2_up_count': ''},
#  {'id': 6838559968064712241,
#   'uname': '',
#   'content': '郑希怡。阿朵',
#   'time': 39000,
#   'v2_up_count': 1},
#  {'id': 6837380806265920825,
#   'uname': '听姐姐的',
#   'content': '昕姐冲吖',
#   'time': 40213,
#   'v2_up_count': 13},
#  {'id': 6837354027144699937,
#   'uname': '',
#   'content': '为什么我的和别人的不一样',
#   'time': 40000,
#   'v2_up_count': 8},
#  {'id': 6837328381894857594,
#   'uname': '',
#   'content': '我爱姐姐们',
#   'time': 40571,
#   'v2_up_count': 9},
#  {'id': 6837635162819878059,
#   'uname': '',
#   'content': '哇😯100分钟？',
#   'time': 40681,
#   'v2_up_count': 5},
#  {'id': 6840233807016040720,
#   'uname': '',
#   'content': '郑希怡，陈松伶，丁当，钟丽缇加油，冲啊，姐姐们',
#   'time': 40984,
#   'v2_up_count': 1},
#  {'id': 6837488313592832728,
#   'uname': '听姐姐的',
#   'content': '为了姐姐充了会员！！！！',
#   'time': 40677,
#   'v2_up_count': 3},
#  {'id': 6837625675237108114,
#   'uname': '',
#   'content': '含韵含韵',
#   'time': 41611,
#   'v2_up_count': 28},
#  {'id': 6837376889255727664,
#   'uname': '演技派',
#   'content': '万茜 加油 冲🦆',
#   'time': 41764,
#   'v2_up_count': 15},
#  {'id': 6838121567867299268,
#   'uname': '',
#   'content': '怎么首页连推送都没有啊，翻了好几遍都翻不到',
#   'time': 41221,
#   'v2_up_count': 3},
#  {'id': 6837307276425484388,
#   'uname': '',
#   'content': '姐姐们冲啊',
#   'time': 41045,
#   'v2_up_count': 15},
#  {'id': 6837726087277809023,
#   'uname': '',
#   'content': '金晨冲冲冲',
#   'time': 41000,
#   'v2_up_count': 12},
#  {'id': 6838354294965530314,
#   'uname': '',
#   'content': '如果有乘风破浪的哥哥，我首推朱一龙哥哥！',
#   'time': 41797,
#   'v2_up_count': 2},
#  {'id': 6837390663215911273,
#   'uname': '',
#   'content': 'Wa感觉这综艺才是正能量 ',
#   'time': 42000,
#   'v2_up_count': 18},
#  {'id': 6837307568483261514,
#   'uname': '',
#   'content': '万茜小姐姐冲',
#   'time': 42385,
#   'v2_up_count': 70},
#  {'id': 6837876144845661334,
#   'uname': '',
#   'content': '给嘉尔pick的姐姐打call',
#   'time': 42113,
#   'v2_up_count': 4},
#  {'id': 6837331109199102680,
#   'uname': '气场强大',
#   'content': '王霏霏 ！姐姐加油💪',
#   'time': 42000,
#   'v2_up_count': 11},
#  {'id': 6837307594253065375,
#   'uname': '',
#   'content': '郁可唯 11年了  爱你 冲冲冲 ',
#   'time': 42000,
#   'v2_up_count': 4},
#  {'id': 6837641437767107761,
#   'uname': '',
#   'content': '所有姐姐们我都爱  姐姐们冲啊',
#   'time': 42220,
#   'v2_up_count': 2},
#  {'id': 6838220489554284224,
#   'uname': '',
#   'content': '梦辰冲呀冲呀！',
#   'time': 43761,
#   'v2_up_count': 8},
#  {'id': 6837307388094634480,
#   'uname': '',
#   'content': '来啦来啦来啦来啦啊啊啊',
#   'time': 43286,
#   'v2_up_count': 7},
#  {'id': 6839312802817899935,
#   'uname': '',
#   'content': '乘风破浪的姐姐们 ，来了来了',
#   'time': 43236,
#   'v2_up_count': 3},
#  {'id': 6838643045617223505,
#   'uname': '',
#   'content': '姐姐们冲冲冲！！！昕姐冲冲冲！！！',
#   'time': 43292,
#   'v2_up_count': 2},
#  {'id': 6837306924238165008,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 43447,
#   'v2_up_count': 4},
#  {'id': 6838540035121458245,
#   'uname': '',
#   'content': '断水大师哈哈哈哈哈哈哈哈哈哈或或',
#   'time': 43131,
#   'v2_up_count': 2},
#  {'id': 6837416080832482928,
#   'uname': '听姐姐的',
#   'content': '姐姐们，小雨我来了',
#   'time': 44013,
#   'v2_up_count': 11},
#  {'id': 6837307117511693957,
#   'uname': '',
#   'content': '郁可唯沖鸭',
#   'time': 44165,
#   'v2_up_count': 7},
#  {'id': 6837503865669486538,
#   'uname': '听姐姐的',
#   'content': '吴昕冲鸭！！！！',
#   'time': 44489,
#   'v2_up_count': 5},
#  {'id': 6837306941418034252,
#   'uname': '',
#   'content': '我来了我来了',
#   'time': 44770,
#   'v2_up_count': 7},
#  {'id': 6838014408432961809,
#   'uname': '',
#   'content': '鲜花和征途 圣依小姐姐',
#   'time': 44812,
#   'v2_up_count': ''},
#  {'id': 6837662160984356070,
#   'uname': '',
#   'content': '姐姐们给我冲',
#   'time': 44301,
#   'v2_up_count': 2},
#  {'id': 6837306958597903490,
#   'uname': '',
#   'content': '姐姐们，加油＾０＾~',
#   'time': 45772,
#   'v2_up_count': 13},
#  {'id': 6839892266921016515,
#   'uname': '',
#   'content': '张含韵这么多年都没怎么变，真是娃娃脸',
#   'time': 45971,
#   'v2_up_count': 3},
#  {'id': 6837668801003812848,
#   'uname': '',
#   'content': '宁静冲呀！！！',
#   'time': 45167,
#   'v2_up_count': 11},
#  {'id': 6837307001547576581,
#   'uname': '',
#   'content': '张含韵，是我的青春',
#   'time': 45000,
#   'v2_up_count': 10},
#  {'id': 6838559950884843033,
#   'uname': '',
#   'content': '啊都给爷pink静姐',
#   'time': 45633,
#   'v2_up_count': 2},
#  {'id': 6838040491769398802,
#   'uname': '',
#   'content': '宁静姐姐冲冲啊冲冲冲',
#   'time': 45175,
#   'v2_up_count': 2},
#  {'id': 6837808572124966857,
#   'uname': '',
#   'content': '含韵真的看起来好年轻',
#   'time': 46000,
#   'v2_up_count': 7},
#  {'id': 6837307310785222879,
#   'uname': '',
#   'content': '姐姐好飒',
#   'time': 46491,
#   'v2_up_count': 12},
#  {'id': 6838078313251538469,
#   'uname': '',
#   'content': '昕昕子加油(ง •̀_•́)ง',
#   'time': 46244,
#   'v2_up_count': 3},
#  {'id': 6837533745757045191,
#   'uname': '',
#   'content': '小花小花你最棒',
#   'time': 46000,
#   'v2_up_count': 6},
#  {'id': 6839169243535873583,
#   'uname': '',
#   'content': '愿大家都有个美妙的夏天:D(⁎⁍̴̛ᴗ⁍̴̛⁎)',
#   'time': 46408,
#   'v2_up_count': ''},
#  {'id': 6837440738239847590,
#   'uname': '听姐姐的',
#   'content': '都是VIP说话大声点~~~',
#   'time': 46000,
#   'v2_up_count': 3},
#  {'id': 6837997292988265539,
#   'uname': '',
#   'content': '老子是来看万茜的',
#   'time': 47000,
#   'v2_up_count': 12},
#  {'id': 6837307499763784548,
#   'uname': '',
#   'content': '张雨绮冲鸭！！！',
#   'time': 47652,
#   'v2_up_count': 23},
#  {'id': 6837656002001238758,
#   'uname': '',
#   'content': '是王晰念的旁白吗！',
#   'time': 47452,
#   'v2_up_count': 7},
#  {'id': 6838408703611281998,
#   'uname': '',
#   'content': '开头好像金陵十三钗那种风格',
#   'time': 47277,
#   'v2_up_count': 2},
#  {'id': 6837415758709934204,
#   'uname': '气场强大',
#   'content': '真帅啊好棒的陈松伶',
#   'time': 47958,
#   'v2_up_count': 6},
#  {'id': 6837843142316843599,
#   'uname': '',
#   'content': '在抖音一直刷到宁静姐姐哈哈来看看',
#   'time': 47061,
#   'v2_up_count': 1},
#  {'id': 6837602555428135456,
#   'uname': '',
#   'content': '吴昕沈梦辰',
#   'time': 48517,
#   'v2_up_count': 21},
#  {'id': 6837449371124157533,
#   'uname': '听姐姐的',
#   'content': '你一票我一票，昕姐明天就出道',
#   'time': 48229,
#   'v2_up_count': 8},
#  {'id': 6841160983082412509,
#   'uname': '听姐姐的',
#   'content': ' 欣姐加油，我quick你哦！',
#   'time': 48079,
#   'v2_up_count': ''},
#  {'id': 6837307508353719176,
#   'uname': '',
#   'content': '太刺激了',
#   'time': 48000,
#   'v2_up_count': 11},
#  {'id': 6837362548359856600,
#   'uname': '听姐姐的',
#   'content': '姐姐们冲鸭',
#   'time': 48460,
#   'v2_up_count': 5},
#  {'id': 6837697719018714132,
#   'uname': '',
#   'content': '在线call007',
#   'time': 48705,
#   'v2_up_count': ''},
#  {'id': 6837403041311714260,
#   'uname': '',
#   'content': '大型吃瓜  来啦 来啦',
#   'time': 49259,
#   'v2_up_count': 20},
#  {'id': 6837644229495855337,
#   'uname': '',
#   'content': '每个姐姐都好喜欢',
#   'time': 49120,
#   'v2_up_count': 7},
#  {'id': 6838210752863401376,
#   'uname': '',
#   'content': '王鸥 杨蓉 我大明侦！！！冲呀！！！',
#   'time': 49867,
#   'v2_up_count': 6},
#  {'id': 6837307160461367027,
#   'uname': '',
#   'content': '冲鸭姐姐们',
#   'time': 49313,
#   'v2_up_count': 10},
#  {'id': 6838402432959022519,
#   'uname': '',
#   'content': '这个我喜欢妞多注意进化自己词典别中文鸟语和破词',
#   'time': 49131,
#   'v2_up_count': 2},
#  {'id': 6837307667267509614,
#   'uname': '',
#   'content': '姐姐们我来了！',
#   'time': 49689,
#   'v2_up_count': 5},
#  {'id': 6837338874500009566,
#   'uname': '',
#   'content': '都不知道播了',
#   'time': 50649,
#   'v2_up_count': 24},
#  {'id': 6837307564188294196,
#   'uname': '',
#   'content': '霏霏王霏霏美死了',
#   'time': 50000,
#   'v2_up_count': 6},
#  {'id': 6840349294391901628,
#   'uname': '实力唱将',
#   'content': '姐姐们加油呀 看好你们哦',
#   'time': 50557,
#   'v2_up_count': 1},
#  {'id': 6837366113182729766,
#   'uname': '气场强大',
#   'content': '喜欢这个气场',
#   'time': 50000,
#   'v2_up_count': 4},
#  {'id': 6837307078856988161,
#   'uname': '',
#   'content': '郁可唯啊啊啊啊',
#   'time': 50000,
#   'v2_up_count': 4},
#  {'id': 6838760096360975085,
#   'uname': '',
#   'content': '含韵冲冲冲！！！！',
#   'time': 50010,
#   'v2_up_count': 1},
#  {'id': 6837448331742066372,
#   'uname': '',
#   'content': '吴昕小姐姐加油',
#   'time': 51114,
#   'v2_up_count': 36},
#  {'id': 6837608022921506296,
#   'uname': '',
#   'content': '霏霏和佳冲啊',
#   'time': 51865,
#   'v2_up_count': 8},
#  {'id': 6837307461109078756,
#   'uname': '',
#   'content': '李斯丹妮',
#   'time': 51000,
#   'v2_up_count': 10},
#  {'id': 6837400975432435800,
#   'uname': '听姐姐的',
#   'content': '绝美姐姐，太飒了',
#   'time': 51250,
#   'v2_up_count': 7},
#  {'id': 6838018209479024796,
#   'uname': '',
#   'content': '啊啊啊啊啊啊！都好喜欢我的妈！',
#   'time': 51657,
#   'v2_up_count': ''},
#  {'id': 6837306876993524600,
#   'uname': '',
#   'content': '唯唯子冲啊！！！',
#   'time': 51383,
#   'v2_up_count': 6},
#  {'id': 6837415440882352892,
#   'uname': '',
#   'content': '白冰姐姐我来了嘿嘿嘿',
#   'time': 52866,
#   'v2_up_count': 16},
#  {'id': 6837307190526138199,
#   'uname': '',
#   'content': '郁可唯我来了',
#   'time': 52412,
#   'v2_up_count': 9},
#  {'id': 6837689408256963003,
#   'uname': '太后驾到',
#   'content': '啦啦啦都不知道开播了',
#   'time': 52000,
#   'v2_up_count': 2},
#  {'id': 6837307061677118931,
#   'uname': '',
#   'content': '期待期待',
#   'time': 52000,
#   'v2_up_count': 5},
#  {'id': 6841114799299009913,
#   'uname': '',
#   'content': '我来啦',
#   'time': 52370,
#   'v2_up_count': ''},
#  {'id': 6839495832849324700,
#   'uname': '',
#   'content': '冲呀姐姐们！！',
#   'time': 52084,
#   'v2_up_count': ''},
#  {'id': 6838746292336076914,
#   'uname': '听姐姐的',
#   'content': '孟佳冲鸭',
#   'time': 53297,
#   'v2_up_count': 2},
#  {'id': 6837307254950647840,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 53384,
#   'v2_up_count': 10},
#  {'id': 6837671408048968145,
#   'uname': '气场强大',
#   'content': '张雨绮万茜钟丽缇啊啊啊麻麻爱你们',
#   'time': 53302,
#   'v2_up_count': 4},
#  {'id': 6837325585871135605,
#   'uname': '',
#   'content': '姐姐们身材好好哦',
#   'time': 53000,
#   'v2_up_count': 6},
#  {'id': 6837643709804811543,
#   'uname': '',
#   'content': '啊啊啊啊为姐姐们打call!!!!!',
#   'time': 53914,
#   'v2_up_count': 3},
#  {'id': 6837481901206627961,
#   'uname': '',
#   'content': '终于播了！',
#   'time': 53000,
#   'v2_up_count': 4},
#  {'id': 6837416338530521879,
#   'uname': '',
#   'content': '成功的女人们来了',
#   'time': 54470,
#   'v2_up_count': 62},
#  {'id': 6837345445800002665,
#   'uname': '听姐姐的',
#   'content': '给姐姐们摁棒！！！姐姐们加油鸭！！',
#   'time': 54000,
#   'v2_up_count': 24},
#  {'id': 6837656818045026960,
#   'uname': '',
#   'content': '今年最期待的节目开播啦，喜大普奔',
#   'time': 54049,
#   'v2_up_count': 5},
#  {'id': 6837678082428164278,
#   'uname': '听姐姐的',
#   'content': '竟然藏这么严实~~~~~~~~~~',
#   'time': 54962,
#   'v2_up_count': 2},
#  {'id': 6838204074189240151,
#   'uname': '',
#   'content': '姐姐们冲啊啊啊啊啊！！！！！！！！！！！！！',
#   'time': 54253,
#   'v2_up_count': ''},
#  {'id': 6837307254950647834,
#   'uname': '',
#   'content': '唯唯子沖鸭',
#   'time': 54815,
#   'v2_up_count': 9},
#  {'id': 6837406481580533160,
#   'uname': '',
#   'content': '张含韵给爷冲！！！',
#   'time': 55366,
#   'v2_up_count': 29},
#  {'id': 6837885293126020924,
#   'uname': '',
#   'content': '宁静真的很漂亮，超美丽，很有魅力，很有个性',
#   'time': 55082,
#   'v2_up_count': 6},
#  {'id': 6840343440351466178,
#   'uname': '气场强大',
#   'content': '来咯  专门开了个会员',
#   'time': 55000,
#   'v2_up_count': 2},
#  {'id': 6837307353734895983,
#   'uname': '',
#   'content': '姐姐们身材都不错阿',
#   'time': 55887,
#   'v2_up_count': 14},
#  {'id': 6840634896832543564,
#   'uname': '',
#   'content': '乘风破浪的姐姐们冲鸭！',
#   'time': 55065,
#   'v2_up_count': 1},
#  {'id': 6841036454800454397,
#   'uname': '',
#   'content': '默默努力然后惊艳所有人',
#   'time': 55239,
#   'v2_up_count': ''},
#  {'id': 6837307315080190202,
#   'uname': '',
#   'content': '我的妈姐姐们都太好看了吧！！！！',
#   'time': 56035,
#   'v2_up_count': 25},
#  {'id': 6837307151871432402,
#   'uname': '',
#   'content': '支持各位姐姐',
#   'time': 56985,
#   'v2_up_count': 22},
#  {'id': 6837307787526594257,
#   'uname': '',
#   'content': '姐姐们，冲鸭',
#   'time': 56639,
#   'v2_up_count': 17},
#  {'id': 6837308775369075716,
#   'uname': '',
#   'content': '陆陆子加油！！！！',
#   'time': 56549,
#   'v2_up_count': 10},
#  {'id': 6837447129151217130,
#   'uname': '听姐姐的',
#   'content': '墓道歌姬给我冲冲冲！！！！！',
#   'time': 56633,
#   'v2_up_count': 5},
#  {'id': 6839642999903886915,
#   'uname': '',
#   'content': '这个开头词是谁给的？',
#   'time': 56269,
#   'v2_up_count': 2},
#  {'id': 6837620096074584857,
#   'uname': '',
#   'content': '这个节目真的太有意义了',
#   'time': 57898,
#   'v2_up_count': 24},
#  {'id': 6837307813296398124,
#   'uname': '',
#   'content': '王丽坤',
#   'time': 57167,
#   'v2_up_count': 42},
#  {'id': 6837394580226103404,
#   'uname': '听姐姐的',
#   'content': '哈哈哈哈哈哈哈哈来啦',
#   'time': 57323,
#   'v2_up_count': 11},
#  {'id': 6838123882854677409,
#   'uname': '',
#   'content': '含韵姐姐加油啊，我爱你！！！',
#   'time': 57087,
#   'v2_up_count': 3},
#  {'id': 6837719911114816198,
#   'uname': '',
#   'content': '比其他选修好看',
#   'time': 57105,
#   'v2_up_count': 4},
#  {'id': 6838765666933562047,
#   'uname': '',
#   'content': '奔三的我来找自信心了',
#   'time': 57234,
#   'v2_up_count': 1},
#  {'id': 6837307272130517082,
#   'uname': '',
#   'content': '有内味了，',
#   'time': 58821,
#   'v2_up_count': 50},
#  {'id': 6837649563845247578,
#   'uname': '',
#   'content': '特地充了会员',
#   'time': 58933,
#   'v2_up_count': 9},
#  {'id': 6837307027317380435,
#   'uname': '',
#   'content': '坤坤子冲啊',
#   'time': 58000,
#   'v2_up_count': 15},
#  {'id': 6837984154683297177,
#   'uname': '',
#   'content': '姐姐们我来啦！！！',
#   'time': 58245,
#   'v2_up_count': 4},
#  {'id': 6837437396755274545,
#   'uname': '听姐姐的',
#   'content': '张含韵冲冲冲',
#   'time': 58200,
#   'v2_up_count': 8},
#  {'id': 6837797242001207378,
#   'uname': '',
#   'content': '白冰，为你打call',
#   'time': 58022,
#   'v2_up_count': 4},
#  {'id': 6837307126101628558,
#   'uname': '',
#   'content': '吴昕吴昕',
#   'time': 59000,
#   'v2_up_count': 87},
#  {'id': 6837307611432934601,
#   'uname': '',
#   'content': '张含韵我来啦',
#   'time': 59256,
#   'v2_up_count': 42},
#  {'id': 6837400507280998513,
#   'uname': '',
#   'content': '张含韵万茜冲啊！！！',
#   'time': 59608,
#   'v2_up_count': 10},
#  {'id': 6838024828023639497,
#   'uname': '',
#   'content': '会不会以后有个披荆斩棘的哥哥们，哈哈哈',
#   'time': 59365,
#   'v2_up_count': 8},
#  {'id': 6837307439634242192,
#   'uname': '',
#   'content': '万茜冲冲冲！！！！',
#   'time': 59332,
#   'v2_up_count': 10},
#  {'id': 6840441580354371528,
#   'uname': '',
#   'content': '93年。即将步入30岁，。喜欢这个节目',
#   'time': 59073,
#   'v2_up_count': ''}]

# %%
details
# Out:
# []

# %%
len(jd['data']['items'])
# Out:
# 360

# %%
    url='https://bullet-ws.hitv.com/bullet/2020/06/23/095353/8337559/0.json'
    danmuurl = url.format(num)
    res=requests.get(url)
    res.encoding = 'utf-8'
    jd=json.loads(res.text)
    details=[]
    for i in range(len(jd['data']['items'])):
        print(jd['data']['items'][i]['uname'])
        '''
        result={}
        result['id']=jd['data']['items'][i]['id']
        result['uname']=jd['data']['items'][i]['uname']
        result['content']=jd['data']['items'][i]['content']
        result['time']=jd['data']['items'][i]['time']
        result['v2_up_count']=jd['data']['items'][i]['v2_up_count']
        details.append(result)
        '''
# Out:
# 听姐姐的
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-ecb80c9aefc1> in <module>
#       6 details=[]
#       7 for i in range(len(jd['data']['items'])):
# ----> 8     print(jd['data']['items'][i]['uname'])
#       9     '''
#      10     result={}
#
# KeyError: 'uname'

# %%
def get_danmu(num1,num2,page):
    url='https://bullet-ws.hitv.com/bullet/2020/06/23/{}/{}/{}.json'
    danmuurl = url.format(num1,num2,page)
    res=requests.get(danmuurl)
    res.encoding = 'utf-8'
    jd=json.loads(res.text)
    details=[]
    for i in range(len(jd['data']['items'])):
        result={}
        result['stype']=num2
        result['id']=jd['data']['items'][i]['id']
        try:
            result['uname']=jd['data']['items'][i]['uname']
        except:
            result['uname']=''
        result['content']=jd['data']['items'][i]['content']
        result['time']=jd['data']['items'][i]['time']
        try:
            result['v2_up_count']=jd['data']['items'][i]['v2_up_count']
        except:
            result['v2_up_count']=''
        details.append(result)
    
    
    return details

# %%
def count_danmu():
    danmu_total=[]
    num1=input('第一个数字')
    num2=input('第二个数字')
    page=int(input('输入总时长'))
    for i in range(page):
        danmu_total.extend(get_danmu(num1,num2,i))
        
    return danmu_total

# %%
df=count_danmu()
# Out:
# 第一个数字095353
# 第二个数字8337559
# 输入总时长101

# %%
095353,8337559,101
135229,8339494,134
135223/8398205/100
121038/8437644/35

# %%
def main():
    danmu_end=[]
    for j in range(4):
        danmu_end.extend(count_danmu())
    df=pd.DataFrame(danmu_end)
    df.to_excel('danmu.xlsx')

    
if __name__ == '__main__':
    main()
# Out:
# 第一个数字095353
# 第二个数字8337559
# 输入总时长101
# 第一个数字135229
# 第二个数字8339494
# 输入总时长134
# 第一个数字135223
# 第二个数字8398205
# 输入总时长100
# 第一个数字121038
# 第二个数字8437644
# 输入总时长35

# %%
df
# Out:
# [{'stype': '8337559',
#   'id': 6837425357961885168,
#   'uname': '听姐姐的',
#   'content': '昕姐冲！！！',
#   'time': 0,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837994106122529085,
#   'uname': '',
#   'content': '在看一次！',
#   'time': 0,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6838116886352935403,
#   'uname': '',
#   'content': '为黄圣依，张雨绮，郑希怡打call',
#   'time': 0,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837307130396595873,
#   'uname': '',
#   'content': '姐姐们 我来了~~！！！',
#   'time': 0,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837758462741384194,
#   'uname': '',
#   'content': '我去，真的爱了，都是我喜欢的',
#   'time': 0,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6840389057199198273,
#   'uname': '',
#   'content': '揭谛揭谛揭谛快点快点开始考科三考试',
#   'time': 0,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837307005842543888,
#   'uname': '',
#   'content': '啊啊啊坤坤我来了',
#   'time': 1000,
#   'v2_up_count': 51},
#  {'stype': '8337559',
#   'id': 6837307353734895986,
#   'uname': '',
#   'content': '姐姐冲啊',
#   'time': 1000,
#   'v2_up_count': 20},
#  {'stype': '8337559',
#   'id': 6837307336555026739,
#   'uname': '',
#   'content': '顾以森报道哈哈哈哈哈哈哈哈哈',
#   'time': 1000,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837309015887245077,
#   'uname': '',
#   'content': '来了来了！！！',
#   'time': 1156,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837403234585243393,
#   'uname': '',
#   'content': '来啦，打call姐姐们',
#   'time': 1103,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6841131455182207588,
#   'uname': '',
#   'content': '打卡',
#   'time': 1988,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837306803979080344,
#   'uname': '',
#   'content': '天天天，可可第一',
#   'time': 2982,
#   'v2_up_count': 35},
#  {'stype': '8337559',
#   'id': 6837307108921759333,
#   'uname': '',
#   'content': '来了来了',
#   'time': 2823,
#   'v2_up_count': 25},
#  {'stype': '8337559',
#   'id': 6837306640770322718,
#   'uname': '',
#   'content': '啊啊啊啊啊郁可唯我来了',
#   'time': 2000,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837849073666703488,
#   'uname': '',
#   'content': '黄小明，面对姐姐们要挺住啊',
#   'time': 2000,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837306705194832272,
#   'uname': '',
#   'content': '终于来了！！！',
#   'time': 2000,
#   'v2_up_count': 19},
#  {'stype': '8337559',
#   'id': 6837710208783659473,
#   'uname': '',
#   'content': '姐姐我来了，哈哈哈哈哈',
#   'time': 2185,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837374578563311239,
#   'uname': '听姐姐的',
#   'content': '我来了我来了我来了我来了我来了姐姐们冲冲冲哈哈哈哈哈',
#   'time': 3971,
#   'v2_up_count': 54},
#  {'stype': '8337559',
#   'id': 6837307044497249669,
#   'uname': '',
#   'content': '啊啊啊啊啊啊啊啊姐姐们我来了',
#   'time': 3808,
#   'v2_up_count': 92},
#  {'stype': '8337559',
#   'id': 6837306675130061139,
#   'uname': '',
#   'content': '来了来了 我来了',
#   'time': 3000,
#   'v2_up_count': 42},
#  {'stype': '8337559',
#   'id': 6837741471850713027,
#   'uname': '',
#   'content': '宁静  宁静  宁静  为您打call  ',
#   'time': 3067,
#   'v2_up_count': 36},
#  {'stype': '8337559',
#   'id': 6838811889371654234,
#   'uname': '',
#   'content': '这里的姐姐都好彪悍啊，怕了怕了',
#   'time': 3978,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837306657950191927,
#   'uname': '',
#   'content': '第一啊啊啊啊啊啊',
#   'time': 3000,
#   'v2_up_count': 37},
#  {'stype': '8337559',
#   'id': 6837351145221630617,
#   'uname': '',
#   'content': '啊啊啊啊啊居然就悄无声息的播了',
#   'time': 4958,
#   'v2_up_count': 68},
#  {'stype': '8337559',
#   'id': 6838532944130441558,
#   'uname': '',
#   'content': '来了',
#   'time': 4045,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306812569014962,
#   'uname': '',
#   'content': '来了来了看姐姐',
#   'time': 4938,
#   'v2_up_count': 45},
#  {'stype': '8337559',
#   'id': 6837314607934681970,
#   'uname': '',
#   'content': '姐姐们，我来了！',
#   'time': 4955,
#   'v2_up_count': 33},
#  {'stype': '8337559',
#   'id': 6837507134139612309,
#   'uname': '',
#   'content': '来看孟佳孟佳孟佳！',
#   'time': 4541,
#   'v2_up_count': 26},
#  {'stype': '8337559',
#   'id': 6837622458306599976,
#   'uname': '',
#   'content': '我来了我来了哈哈哈哈哈哈哈',
#   'time': 4000,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837325199324077237,
#   'uname': '',
#   'content': '开场白梦回srrx晰哥低音',
#   'time': 5211,
#   'v2_up_count': 109},
#  {'stype': '8337559',
#   'id': 6837327449886950340,
#   'uname': '',
#   'content': '黄晓明开始历险可还行',
#   'time': 5182,
#   'v2_up_count': 68},
#  {'stype': '8337559',
#   'id': 6839073727758125841,
#   'uname': '',
#   'content': '看了好几遍啦   姐姐们 加油啊',
#   'time': 5039,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837322441955060774,
#   'uname': '',
#   'content': '宁静宁静！',
#   'time': 5990,
#   'v2_up_count': 65},
#  {'stype': '8337559',
#   'id': 6838956075718921026,
#   'uname': '',
#   'content': '哪个姐姐我都想pick',
#   'time': 5357,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6840044338828490145,
#   'uname': '',
#   'content': '恍恍惚惚哈哈',
#   'time': 5000,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837510179271436397,
#   'uname': '实力唱将',
#   'content': '为吴昕而来😍😍给我冲啊姐姐！！！',
#   'time': 6297,
#   'v2_up_count': 29},
#  {'stype': '8337559',
#   'id': 6838393379167952649,
#   'uname': '',
#   'content': '来了来了来了！！！！给姐姐们打call！！',
#   'time': 6137,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837374922160696603,
#   'uname': '',
#   'content': '付仙女，爸爸爱你',
#   'time': 6938,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837866627198106893,
#   'uname': '气场强大',
#   'content': '来看宁静了 哈哈',
#   'time': 6000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6840776080997798228,
#   'uname': '',
#   'content': '看了觉得伊能静姐姐好温柔！',
#   'time': 6000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837670592005179740,
#   'uname': '',
#   'content': '啊啊啊啊姐姐们我来了！',
#   'time': 6015,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837378130501282257,
#   'uname': '气场强大',
#   'content': '姐姐们我来了',
#   'time': 7240,
#   'v2_up_count': 30},
#  {'stype': '8337559',
#   'id': 6837662156689388764,
#   'uname': '拎包妹',
#   'content': '刷第二遍了，全部看完要五个小时，哈哈哈',
#   'time': 7022,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837309050246983556,
#   'uname': '',
#   'content': '哈哈哈哈哈哈我来了姐姐们',
#   'time': 7093,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6838102356478536108,
#   'uname': '听姐姐的',
#   'content': '昕姐昕姐加油加油(ง •̀_•́)ง',
#   'time': 7972,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6839917053177350196,
#   'uname': '',
#   'content': '哈哈哈千呼万唤始出来啊',
#   'time': 7000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6839857597944981712,
#   'uname': '',
#   'content': '看多了其他的选秀节目，把姐姐们想得简单了',
#   'time': 7131,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837306726669668807,
#   'uname': '',
#   'content': '万茜冲啊！！！！筒子来啦！！！！',
#   'time': 8135,
#   'v2_up_count': 56},
#  {'stype': '8337559',
#   'id': 6837307770346725026,
#   'uname': '',
#   'content': '万茜冲啊！',
#   'time': 8769,
#   'v2_up_count': 32},
#  {'stype': '8337559',
#   'id': 6837653257517130157,
#   'uname': '',
#   'content': '晓明哥的微博，每一位哈哈哈哈哈哈笑死我',
#   'time': 8000,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837393003973098571,
#   'uname': '听姐姐的',
#   'content': '这个综艺我锁了',
#   'time': 8000,
#   'v2_up_count': 30},
#  {'stype': '8337559',
#   'id': 6839566953212870211,
#   'uname': '',
#   'content': '哈哈哈我是来看各位漂亮姐姐互撕的哈哈哈哈',
#   'time': 8000,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6840280020864215984,
#   'uname': '',
#   'content': '啊啊啊 姐姐们我来了',
#   'time': 8299,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837728329250745126,
#   'uname': '',
#   'content': '小明历险记哈哈哈哈哈',
#   'time': 9000,
#   'v2_up_count': 76},
#  {'stype': '8337559',
#   'id': 6837442533536186579,
#   'uname': '听姐姐的',
#   'content': '哈哈哈哈哈哈   来了来了',
#   'time': 9729,
#   'v2_up_count': 35},
#  {'stype': '8337559',
#   'id': 6837627251490107790,
#   'uname': '',
#   'content': '没有一点点防备你就这样出现',
#   'time': 9000,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837307886310842388,
#   'uname': '',
#   'content': '给绮绮子排面！',
#   'time': 9855,
#   'v2_up_count': 44},
#  {'stype': '8337559',
#   'id': 6837335047684131484,
#   'uname': '听姐姐的',
#   'content': '啊啊啊啊啊，来了来了',
#   'time': 9753,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837309655837374003,
#   'uname': '',
#   'content': '来报道啦啊啊啊啊啊啊乘风破浪的姐姐们加油pick你们',
#   'time': 9000,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6838609334418892864,
#   'uname': '',
#   'content': '这个文案爱了',
#   'time': 10130,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837332509358447504,
#   'uname': '',
#   'content': '昕昕子给我冲冲冲冲冲冲冲冲冲冲',
#   'time': 10041,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6837320019593495292,
#   'uname': '',
#   'content': '张雨绮姐姐冲！',
#   'time': 10651,
#   'v2_up_count': 61},
#  {'stype': '8337559',
#   'id': 6837346433642485228,
#   'uname': '听姐姐的',
#   'content': '来了来了哈哈哈哈哈 让我来康康',
#   'time': 10000,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837724609809054226,
#   'uname': '',
#   'content': '姐子们我来看你们了！',
#   'time': 10768,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837626585770176035,
#   'uname': '',
#   'content': '芒果搞快点 下下一集快点出啊！！！！',
#   'time': 10131,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837448735468994354,
#   'uname': '',
#   'content': '啥时候开始的，没一点消息',
#   'time': 11588,
#   'v2_up_count': 19},
#  {'stype': '8337559',
#   'id': 6837324168531921557,
#   'uname': '',
#   'content': '期待吴昕！！！！',
#   'time': 11226,
#   'v2_up_count': 23},
#  {'stype': '8337559',
#   'id': 6840835965726914530,
#   'uname': '',
#   'content': '啊啊啊啊为了莎莎才来的！！金小莎我爱你！！！',
#   'time': 11000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6838505241591344647,
#   'uname': '实力唱将',
#   'content': '来了来了姐姐们我又来了',
#   'time': 11014,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837325834979239877,
#   'uname': '',
#   'content': '不错子 来了啦了',
#   'time': 11000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6839290048081133010,
#   'uname': '',
#   'content': '终于等到了啊啊啊，啊啊啊啊啊',
#   'time': 11020,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837360942042080005,
#   'uname': '气场强大',
#   'content': '吴昕加油！你一票我一票明天吴昕就出道',
#   'time': 12685,
#   'v2_up_count': 72},
#  {'stype': '8337559',
#   'id': 6837311743191486046,
#   'uname': '',
#   'content': '期待金晨',
#   'time': 12051,
#   'v2_up_count': 49},
#  {'stype': '8337559',
#   'id': 6837351922610714788,
#   'uname': '跟班小弟',
#   'content': '姐姐们我来啦',
#   'time': 12444,
#   'v2_up_count': 28},
#  {'stype': '8337559',
#   'id': 6837626401086582053,
#   'uname': '',
#   'content': '哈哈哈哈哈就我是冲海陆来的吗',
#   'time': 12012,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837309234930577835,
#   'uname': '',
#   'content': '郁可唯！！？！',
#   'time': 12002,
#   'v2_up_count': 22},
#  {'stype': '8337559',
#   'id': 6840283920694530981,
#   'uname': '',
#   'content': '宁静宁静！！！！？！！！',
#   'time': 12036,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837343358445887222,
#   'uname': '',
#   'content': '吴昕加油',
#   'time': 13053,
#   'v2_up_count': 70},
#  {'stype': '8337559',
#   'id': 6837360199012734314,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 13835,
#   'v2_up_count': 33},
#  {'stype': '8337559',
#   'id': 6837703633188704102,
#   'uname': '',
#   'content': '佳菲猫 miss a冲啊！！！！',
#   'time': 13040,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6838908955632650599,
#   'uname': '',
#   'content': '喜欢李斯丹妮跟含韵，丁当，宁静，',
#   'time': 13409,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837306782504243789,
#   'uname': '',
#   'content': '终于！',
#   'time': 13000,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6838669360881852839,
#   'uname': '跟班小弟',
#   'content': '啊啊啊啊啊啊啊啊啊啊霏霏给我冲鸭！！',
#   'time': 13000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837427943532209658,
#   'uname': '听姐姐的',
#   'content': '必须留名啊！可以载入综艺史册的！',
#   'time': 14849,
#   'v2_up_count': 19},
#  {'stype': '8337559',
#   'id': 6837342495157456763,
#   'uname': '听姐姐的',
#   'content': '姐姐们我来了',
#   'time': 14317,
#   'v2_up_count': 27},
#  {'stype': '8337559',
#   'id': 6837440738239847613,
#   'uname': '听姐姐的',
#   'content': '这个旁白人声可以，表白这个旁白人声小哥哥',
#   'time': 14987,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6837389121322644797,
#   'uname': '听姐姐的',
#   'content': '欣姐加油欣姐加油',
#   'time': 14584,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6841117002617235679,
#   'uname': '气场强大',
#   'content': '啊啊啊啊啊，乘风破浪的小姐姐们我来了！攒了两期还是没忍住就来了。哈哈！',
#   'time': 14505,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837483309955908168,
#   'uname': '气场强大',
#   'content': '昕昕子 加油鸭',
#   'time': 14049,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837660825249523735,
#   'uname': '听姐姐的',
#   'content': '终于等到你',
#   'time': 15839,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6837407280444453738,
#   'uname': '气场强大',
#   'content': '姐姐们我来啦！！！',
#   'time': 15000,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6837306735259603419,
#   'uname': '',
#   'content': '来了来了姐姐们好',
#   'time': 15607,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837418687877643669,
#   'uname': '最强舞担',
#   'content': '这是不是花少的背景人声',
#   'time': 15000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6838009546529975545,
#   'uname': '',
#   'content': '啊啊啊啊姐姐蓝盈莹pick她！！❤️❤️❤️冲啊！',
#   'time': 15960,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837378358134550065,
#   'uname': '太后驾到',
#   'content': '特意冲了会员',
#   'time': 15857,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837429343691554944,
#   'uname': '听姐姐的',
#   'content': '吴昕  金晨   宁静   张雨绮出道吧',
#   'time': 16009,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837340270364387130,
#   'uname': '',
#   'content': '小明历险记我来啦',
#   'time': 16000,
#   'v2_up_count': 42},
#  {'stype': '8337559',
#   'id': 6837701867957138437,
#   'uname': '拎包妹',
#   'content': '来看姐姐了！！！静姐冲！！！',
#   'time': 16284,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837649443586163052,
#   'uname': '',
#   'content': '有人说不够流行就不够资格哈哈哈',
#   'time': 16635,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6840290088267585705,
#   'uname': '',
#   'content': '为姐姐们加油 不一样的女团 跨界勇敢 蓝盈莹金晨 黄晓明制作人主持加油 教主暖心',
#   'time': 16797,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837317399663434313,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 16496,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837455667546247271,
#   'uname': '气场强大',
#   'content': '吴昕姐姐，加油加油💪，你一票我一票明天昕姐能出道。',
#   'time': 17000,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837314092538604687,
#   'uname': '',
#   'content': '孟佳霏霏加油',
#   'time': 17870,
#   'v2_up_count': 64},
#  {'stype': '8337559',
#   'id': 6837322222911727678,
#   'uname': '',
#   'content': '来啦来啦，淋雨一直走前来打call，昕昕子冲啊',
#   'time': 17000,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6839593642139673248,
#   'uname': '',
#   'content': '海陆的当时是说自己的 而且声音很小',
#   'time': 17686,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837318713923431939,
#   'uname': '',
#   'content': '天呐哇哇哇',
#   'time': 17270,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837773727055195172,
#   'uname': '',
#   'content': '姐姐们冲啊！！！！！！！！！！',
#   'time': 17000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837605003559495476,
#   'uname': '',
#   'content': '我大湖南台还是牛',
#   'time': 18000,
#   'v2_up_count': 22},
#  {'stype': '8337559',
#   'id': 6837324336035646859,
#   'uname': '',
#   'content': '姐姐们最牛 冲！！！！',
#   'time': 18778,
#   'v2_up_count': 22},
#  {'stype': '8337559',
#   'id': 6837812506315020955,
#   'uname': '',
#   'content': '王霏霏 孟佳冲啊！！！！！',
#   'time': 18957,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6838861599323192529,
#   'uname': '',
#   'content': '蓝盈莹 沈梦辰 吴昕 给我冲！！！',
#   'time': 18106,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837351570423394869,
#   'uname': '演技派',
#   'content': '万茜冲冲冲',
#   'time': 18000,
#   'v2_up_count': 20},
#  {'stype': '8337559',
#   'id': 6839581083655287981,
#   'uname': '',
#   'content': '万茜姐姐姐姐我来了啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊',
#   'time': 18419,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837329060499693294,
#   'uname': '',
#   'content': '金晨加油！',
#   'time': 19000,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837306834043851504,
#   'uname': '',
#   'content': '我来了！！期待万茜',
#   'time': 19000,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837606107366091172,
#   'uname': '',
#   'content': '刚冲的会员，听说挺好看的',
#   'time': 19604,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837306782504243795,
#   'uname': '',
#   'content': '第一第一，期待姐姐们',
#   'time': 19855,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6837998388204927176,
#   'uname': '',
#   'content': '哇哇哇,等好久了，居然悄无声息的开始了',
#   'time': 19000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6840454168903549062,
#   'uname': '',
#   'content': '啊啊啊啊啊，期待已久',
#   'time': 19961,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837353382899602477,
#   'uname': '听姐姐的',
#   'content': '为所有姐姐打call',
#   'time': 20703,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837306864108622673,
#   'uname': '',
#   'content': '我来了我来了宁静姐加油张雨绮加油吴昕加油',
#   'time': 20128,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837478125930355399,
#   'uname': '',
#   'content': '好多姐姐都好喜欢',
#   'time': 20827,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837626074669067143,
#   'uname': '',
#   'content': '来了。。。来了 !!! ',
#   'time': 20367,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837800244183355943,
#   'uname': '',
#   'content': '哈哈哈，等了好久终于等到了',
#   'time': 20031,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6838518560284946805,
#   'uname': '',
#   'content': '声音真好听，感觉这节目高大上',
#   'time': 20006,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837414027838105925,
#   'uname': '',
#   'content': '宁静姐姐！！！（尖叫！）',
#   'time': 21071,
#   'v2_up_count': 34},
#  {'stype': '8337559',
#   'id': 6837457175079776043,
#   'uname': '听姐姐的',
#   'content': '你一票，我一票，姐姐都出道',
#   'time': 21606,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6839527340729432154,
#   'uname': '',
#   'content': '为晓明来的，他最近演的鬓边不是海棠红超棒',
#   'time': 21924,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6840711025128053926,
#   'uname': '',
#   'content': '天哪陈松林就是小时候觉得那个很漂亮的女演员',
#   'time': 21000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837427093128680959,
#   'uname': '气场强大',
#   'content': '女王们！！！！！！！我来了！！！！！！',
#   'time': 21161,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6839174784043693182,
#   'uname': '',
#   'content': '终于等到你，为啥没有通知，还好我没错过你。',
#   'time': 21637,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837322158487217959,
#   'uname': '',
#   'content': '为静姐打call',
#   'time': 22038,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837425237702800328,
#   'uname': '太后驾到',
#   'content': '每次都是为了看综艺开VIP😭',
#   'time': 22927,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6837306881288491905,
#   'uname': '',
#   'content': '来了老姐',
#   'time': 22005,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837324658158195498,
#   'uname': '',
#   'content': '来啦  姐姐们冲鸭',
#   'time': 22433,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6838149953306221409,
#   'uname': '',
#   'content': '第二遍我来了哈哈哈哈哈',
#   'time': 22000,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6839737360335499932,
#   'uname': '',
#   'content': '这个旁白是不是王晰啊，跟声入人心好像',
#   'time': 22000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837857805335250226,
#   'uname': '',
#   'content': '这段话让姐姐说啊',
#   'time': 23203,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837409135870333726,
#   'uname': '听姐姐的',
#   'content': '爱宁静，爱金晨',
#   'time': 23628,
#   'v2_up_count': 34},
#  {'stype': '8337559',
#   'id': 6837441300880566315,
#   'uname': '听姐姐的',
#   'content': '我的妈，才知道可以看了',
#   'time': 23756,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6838061562879017411,
#   'uname': '',
#   'content': '为了看这个综艺专门开的会员哈哈哈哈哈',
#   'time': 23846,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306829748884198,
#   'uname': '',
#   'content': '郁可唯冲',
#   'time': 23570,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837432393118350137,
#   'uname': '听姐姐的',
#   'content': '来啦来啦！！！姐姐们冲鸭！！',
#   'time': 23290,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837619280030797832,
#   'uname': '',
#   'content': '高跟鞋哒哒声听到就有气势',
#   'time': 24000,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6838111023722561965,
#   'uname': '',
#   'content': '吴昕 加油(ง •̀_•́)ง',
#   'time': 24250,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6839221466043283239,
#   'uname': '听姐姐的',
#   'content': '哇哦',
#   'time': 24667,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6839919153416368222,
#   'uname': '',
#   'content': '为了看  直接开了个会员',
#   'time': 24791,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306838338818820,
#   'uname': '',
#   'content': '啊啊啊啊啊啊哦',
#   'time': 24049,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6841352620228316924,
#   'uname': '',
#   'content': '啊啊啊啊啊啊黄圣依我好可',
#   'time': 24854,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837314298697035629,
#   'uname': '',
#   'content': '欢迎收看《晓明历险记》',
#   'time': 25000,
#   'v2_up_count': 133},
#  {'stype': '8337559',
#   'id': 6837415664220653249,
#   'uname': '气场强大',
#   'content': '陈松伶，唱的比原版还要好啊，好给力',
#   'time': 25778,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837338049866285061,
#   'uname': '听姐姐的',
#   'content': '来喽',
#   'time': 25838,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6839194884490663792,
#   'uname': '',
#   'content': '欣欣子(ง •̀_•́)ง',
#   'time': 25049,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837306834043851506,
#   'uname': '',
#   'content': '我来了',
#   'time': 25000,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6838870953761972487,
#   'uname': '',
#   'content': '吴昕沈梦辰爱你们哦！',
#   'time': 25095,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837306816863982276,
#   'uname': '',
#   'content': '这就开始了？',
#   'time': 26460,
#   'v2_up_count': 27},
#  {'stype': '8337559',
#   'id': 6837306894173393830,
#   'uname': '',
#   'content': '来看美昕啦',
#   'time': 26000,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6837365301433906889,
#   'uname': '',
#   'content': '冲呀 琦琦子',
#   'time': 26000,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837307323670124813,
#   'uname': '',
#   'content': '郁可唯冲',
#   'time': 26000,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837424267040186911,
#   'uname': '气场强大',
#   'content': '期待姐姐们～来啦',
#   'time': 26046,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306868403589984,
#   'uname': '',
#   'content': '啊啊啊啊啊啊啊啊啊啊啊来了姐姐们我来了',
#   'time': 26053,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837329013255052818,
#   'uname': '',
#   'content': '第一次追选秀综艺就交给姐姐们了',
#   'time': 27865,
#   'v2_up_count': 50},
#  {'stype': '8337559',
#   'id': 6837372160496711893,
#   'uname': '听姐姐的',
#   'content': '为黄晓明打call哈哈哈哈',
#   'time': 27000,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837365752405475170,
#   'uname': '演技派',
#   'content': '万茜姐姐我来了！万花筒给你撑腰了！',
#   'time': 27064,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837811170580188274,
#   'uname': '',
#   'content': '我不喜欢看选秀，但这个的精彩吸引我了',
#   'time': 27845,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837338346219029797,
#   'uname': '',
#   'content': '冲鸭姐姐们',
#   'time': 27638,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837584503680582989,
#   'uname': '',
#   'content': '等我下班在看',
#   'time': 27054,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837630468420616795,
#   'uname': '',
#   'content': '猝不及防的开始了',
#   'time': 28270,
#   'v2_up_count': 58},
#  {'stype': '8337559',
#   'id': 6837307044497249686,
#   'uname': '',
#   'content': '昕昕子',
#   'time': 28858,
#   'v2_up_count': 83},
#  {'stype': '8337559',
#   'id': 6837451127765790982,
#   'uname': '',
#   'content': '金沙 吴昕 张含韵!!!',
#   'time': 28000,
#   'v2_up_count': 20},
#  {'stype': '8337559',
#   'id': 6837344470842421933,
#   'uname': '拎包妹',
#   'content': '工作人员辛苦了',
#   'time': 28000,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6840704312094157815,
#   'uname': '',
#   'content': '我来啦  特地续费我的会员来啦 来看姐姐们',
#   'time': 28000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837348027075359376,
#   'uname': '太后驾到',
#   'content': '晓明哥加油 挺住哈哈哈哈哈哈哈哈哈',
#   'time': 28000,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837306842633786125,
#   'uname': '',
#   'content': '本年度最期待的综艺哈哈哈哈哈哈哈',
#   'time': 29000,
#   'v2_up_count': 99},
#  {'stype': '8337559',
#   'id': 6837883463469949575,
#   'uname': '',
#   'content': '我是朋友介绍过来看的，听说很搞笑，期待！🤣',
#   'time': 29000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837324512129306805,
#   'uname': '',
#   'content': '55555爱死茜茜子了',
#   'time': 29608,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6840314951833330946,
#   'uname': '',
#   'content': '啊啊啊啊啊，乘风破浪的姐姐们，冲啊',
#   'time': 29543,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837774375595258736,
#   'uname': '',
#   'content': '来啦！期待(๑˙ー˙๑)',
#   'time': 29974,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6840429833618785676,
#   'uname': '',
#   'content': '这都是神仙级的姐姐了',
#   'time': 29515,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837353176741171257,
#   'uname': '',
#   'content': '表示敬佩节目组',
#   'time': 30870,
#   'v2_up_count': 112},
#  {'stype': '8337559',
#   'id': 6837500202062365726,
#   'uname': '',
#   'content': '张含韵，仙女，出道吧',
#   'time': 30966,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6840849520643720353,
#   'uname': '',
#   'content': '张雨绮，宁静冲啊啊啊啊',
#   'time': 30000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837306885583459215,
#   'uname': '',
#   'content': '终于等到你！',
#   'time': 30000,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837390010380879271,
#   'uname': '',
#   'content': '姐姐们冲啊！！',
#   'time': 30000,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6840680548040054960,
#   'uname': '跟班小弟',
#   'content': '被妈妈安利(ღ˘⌣˘ღ)',
#   'time': 30890,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837308058109534844,
#   'uname': '',
#   'content': '昕昕我来了',
#   'time': 31019,
#   'v2_up_count': 19},
#  {'stype': '8337559',
#   'id': 6837411811634971134,
#   'uname': '最强舞担',
#   'content': '哈哈哈哈哈  激动',
#   'time': 31641,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837318589369379861,
#   'uname': '',
#   'content': '昕昕子加油！',
#   'time': 31000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837353743676857079,
#   'uname': '',
#   'content': '来了来了，来看孟佳和霏',
#   'time': 31210,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837389941661402214,
#   'uname': '气场强大',
#   'content': '姐姐们冲呀',
#   'time': 31018,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837593913953932108,
#   'uname': '听姐姐的',
#   'content': '宁静大姐大   最爱',
#   'time': 31307,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306868403589987,
#   'uname': '',
#   'content': '昕姐',
#   'time': 32105,
#   'v2_up_count': 23},
#  {'stype': '8337559',
#   'id': 6837306924238165004,
#   'uname': '',
#   'content': '李斯丹妮冲冲冲',
#   'time': 32000,
#   'v2_up_count': 20},
#  {'stype': '8337559',
#   'id': 6837307018727445813,
#   'uname': '',
#   'content': '我竟然知道12点开始',
#   'time': 32648,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837449319584549707,
#   'uname': '实力唱将',
#   'content': '唯唯子冲啊！！！！！！！',
#   'time': 32000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837348881773855092,
#   'uname': '气场强大',
#   'content': '孟佳冲冲冲！！！',
#   'time': 32997,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837648253880219590,
#   'uname': '',
#   'content': '加油(ง •̀_•́)ง',
#   'time': 32695,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837623940070318643,
#   'uname': '',
#   'content': '终于开播了。',
#   'time': 33043,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837399918870476408,
#   'uname': '拎包妹',
#   'content': '来了来了',
#   'time': 33956,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837440987347952112,
#   'uname': '气场强大',
#   'content': '静姐~宁静~',
#   'time': 33076,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837694472023425230,
#   'uname': '听姐姐的',
#   'content': '来啦！！~~~',
#   'time': 33217,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6838698424925548944,
#   'uname': '',
#   'content': '终于能看正片了',
#   'time': 33000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306924238165002,
#   'uname': '',
#   'content': '我来了！！！',
#   'time': 33822,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6839088377891575240,
#   'uname': '',
#   'content': '来了',
#   'time': 34768,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837826568037988461,
#   'uname': '',
#   'content': '昕昕子加油！',
#   'time': 34182,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837602211830751613,
#   'uname': '',
#   'content': '吴昕沈梦辰钟丽缇伊能静冲鸭！！！',
#   'time': 34124,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837472447983560072,
#   'uname': '听姐姐的',
#   'content': '来了来了，为什么一点消息都没有',
#   'time': 34299,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6838500422638032039,
#   'uname': '',
#   'content': '四刷！！！！！芒果给我搞快点！！！！！',
#   'time': 34228,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6838126060403101429,
#   'uname': '',
#   'content': '来了来了，从不追综艺的我',
#   'time': 34995,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837859729480605807,
#   'uname': '',
#   'content': '文案走心了，不愧是芒果台',
#   'time': 35000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837307027317380448,
#   'uname': '',
#   'content': '姐姐们我来了',
#   'time': 35383,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837378774746379765,
#   'uname': '听姐姐的',
#   'content': '什么时候播的，怎么不知道啊',
#   'time': 35000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6838354127461805715,
#   'uname': '',
#   'content': '晓明哥应该退位让贤给我们朱一龙哥哥啦',
#   'time': 35757,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306924238165018,
#   'uname': '',
#   'content': '郁可唯大vocal',
#   'time': 35000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6840606288055347683,
#   'uname': '',
#   'content': '姐姐们冲鸭！加油',
#   'time': 35000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837447232230432829,
#   'uname': '听姐姐的',
#   'content': '昕姐加油(ง •̀_•́)ง',
#   'time': 36358,
#   'v2_up_count': 26},
#  {'stype': '8337559',
#   'id': 6837407374933734659,
#   'uname': '',
#   'content': '昕昕子我和你一起乘风破浪',
#   'time': 36804,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837779374937205361,
#   'uname': '',
#   'content': '这个字幕咋回事啊，只能看一半儿',
#   'time': 36105,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837686363125138939,
#   'uname': '浪花崽',
#   'content': '昕昕子冲呀！',
#   'time': 36971,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837306975777772718,
#   'uname': '',
#   'content': '熊奥在看吧',
#   'time': 36367,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6839919561438263368,
#   'uname': '',
#   'content': '撕起来时候想想都非常有看点!!',
#   'time': 36814,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837351085092088190,
#   'uname': '听姐姐的',
#   'content': '第一次追这个类型节目',
#   'time': 37000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6838644750719240666,
#   'uname': '',
#   'content': 'miss A冲啊',
#   'time': 37526,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306971482805418,
#   'uname': '',
#   'content': '来了来了',
#   'time': 37043,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837322734012838218,
#   'uname': '',
#   'content': '我来啦哈哈哈哈',
#   'time': 37963,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6839231632230881681,
#   'uname': '',
#   'content': '来了，好看(｡･ω･｡)ﾉ♡',
#   'time': 37085,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6839911259266443250,
#   'uname': '',
#   'content': '好看',
#   'time': 37000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837659450859985665,
#   'uname': '',
#   'content': '不要惹30岁以上的女人',
#   'time': 38860,
#   'v2_up_count': 51},
#  {'stype': '8337559',
#   'id': 6837773718465260547,
#   'uname': '',
#   'content': '张含韵怎么越来越可爱了',
#   'time': 38547,
#   'v2_up_count': 36},
#  {'stype': '8337559',
#   'id': 6838780695024142808,
#   'uname': '',
#   'content': '美女们等着我哈😄',
#   'time': 38140,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6839284340069588589,
#   'uname': '',
#   'content': '每个年龄都有自己的魅力。冲就完了。',
#   'time': 38051,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6839518119434639540,
#   'uname': '',
#   'content': '昕姐加油，fighting！！！',
#   'time': 38070,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837306945713001560,
#   'uname': '',
#   'content': '小雨妈妈来了！！！',
#   'time': 38884,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6838452795745621459,
#   'uname': '',
#   'content': '来看小明历险记啦哈哈哈哈哈哈哈哈哈',
#   'time': 39869,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837409445107980403,
#   'uname': '听姐姐的',
#   'content': '昕姐冲冲冲',
#   'time': 39089,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6840002952523526183,
#   'uname': '太后驾到',
#   'content': '金晨给我冲！',
#   'time': 39038,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837412417225362585,
#   'uname': '',
#   'content': '有综艺追了',
#   'time': 39000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6841344429725678870,
#   'uname': '',
#   'content': '啊！！！！来啦来啦！！！！',
#   'time': 39549,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6838559968064712241,
#   'uname': '',
#   'content': '郑希怡。阿朵',
#   'time': 39000,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837380806265920825,
#   'uname': '听姐姐的',
#   'content': '昕姐冲吖',
#   'time': 40213,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837354027144699937,
#   'uname': '',
#   'content': '为什么我的和别人的不一样',
#   'time': 40000,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837328381894857594,
#   'uname': '',
#   'content': '我爱姐姐们',
#   'time': 40571,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837635162819878059,
#   'uname': '',
#   'content': '哇😯100分钟？',
#   'time': 40681,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6840233807016040720,
#   'uname': '',
#   'content': '郑希怡，陈松伶，丁当，钟丽缇加油，冲啊，姐姐们',
#   'time': 40984,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837488313592832728,
#   'uname': '听姐姐的',
#   'content': '为了姐姐充了会员！！！！',
#   'time': 40677,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837625675237108114,
#   'uname': '',
#   'content': '含韵含韵',
#   'time': 41611,
#   'v2_up_count': 28},
#  {'stype': '8337559',
#   'id': 6837376889255727664,
#   'uname': '演技派',
#   'content': '万茜 加油 冲🦆',
#   'time': 41764,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6838121567867299268,
#   'uname': '',
#   'content': '怎么首页连推送都没有啊，翻了好几遍都翻不到',
#   'time': 41221,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837307276425484388,
#   'uname': '',
#   'content': '姐姐们冲啊',
#   'time': 41045,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837726087277809023,
#   'uname': '',
#   'content': '金晨冲冲冲',
#   'time': 41000,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6838354294965530314,
#   'uname': '',
#   'content': '如果有乘风破浪的哥哥，我首推朱一龙哥哥！',
#   'time': 41797,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837390663215911273,
#   'uname': '',
#   'content': 'Wa感觉这综艺才是正能量 ',
#   'time': 42000,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6837307568483261514,
#   'uname': '',
#   'content': '万茜小姐姐冲',
#   'time': 42385,
#   'v2_up_count': 70},
#  {'stype': '8337559',
#   'id': 6837876144845661334,
#   'uname': '',
#   'content': '给嘉尔pick的姐姐打call',
#   'time': 42113,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837331109199102680,
#   'uname': '气场强大',
#   'content': '王霏霏 ！姐姐加油💪',
#   'time': 42000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837307594253065375,
#   'uname': '',
#   'content': '郁可唯 11年了  爱你 冲冲冲 ',
#   'time': 42000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837641437767107761,
#   'uname': '',
#   'content': '所有姐姐们我都爱  姐姐们冲啊',
#   'time': 42220,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6838220489554284224,
#   'uname': '',
#   'content': '梦辰冲呀冲呀！',
#   'time': 43761,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837307388094634480,
#   'uname': '',
#   'content': '来啦来啦来啦来啦啊啊啊',
#   'time': 43286,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6839312802817899935,
#   'uname': '',
#   'content': '乘风破浪的姐姐们 ，来了来了',
#   'time': 43236,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6838643045617223505,
#   'uname': '',
#   'content': '姐姐们冲冲冲！！！昕姐冲冲冲！！！',
#   'time': 43292,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306924238165008,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 43447,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6838540035121458245,
#   'uname': '',
#   'content': '断水大师哈哈哈哈哈哈哈哈哈哈或或',
#   'time': 43131,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837416080832482928,
#   'uname': '听姐姐的',
#   'content': '姐姐们，小雨我来了',
#   'time': 44013,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837307117511693957,
#   'uname': '',
#   'content': '郁可唯沖鸭',
#   'time': 44165,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837503865669486538,
#   'uname': '听姐姐的',
#   'content': '吴昕冲鸭！！！！',
#   'time': 44489,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837306941418034252,
#   'uname': '',
#   'content': '我来了我来了',
#   'time': 44770,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6838014408432961809,
#   'uname': '',
#   'content': '鲜花和征途 圣依小姐姐',
#   'time': 44812,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837662160984356070,
#   'uname': '',
#   'content': '姐姐们给我冲',
#   'time': 44301,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837306958597903490,
#   'uname': '',
#   'content': '姐姐们，加油＾０＾~',
#   'time': 45772,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6839892266921016515,
#   'uname': '',
#   'content': '张含韵这么多年都没怎么变，真是娃娃脸',
#   'time': 45971,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837668801003812848,
#   'uname': '',
#   'content': '宁静冲呀！！！',
#   'time': 45167,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837307001547576581,
#   'uname': '',
#   'content': '张含韵，是我的青春',
#   'time': 45000,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6838559950884843033,
#   'uname': '',
#   'content': '啊都给爷pink静姐',
#   'time': 45633,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6838040491769398802,
#   'uname': '',
#   'content': '宁静姐姐冲冲啊冲冲冲',
#   'time': 45175,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837808572124966857,
#   'uname': '',
#   'content': '含韵真的看起来好年轻',
#   'time': 46000,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6837307310785222879,
#   'uname': '',
#   'content': '姐姐好飒',
#   'time': 46491,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6838078313251538469,
#   'uname': '',
#   'content': '昕昕子加油(ง •̀_•́)ง',
#   'time': 46244,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837533745757045191,
#   'uname': '',
#   'content': '小花小花你最棒',
#   'time': 46000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6839169243535873583,
#   'uname': '',
#   'content': '愿大家都有个美妙的夏天:D(⁎⁍̴̛ᴗ⁍̴̛⁎)',
#   'time': 46408,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837440738239847590,
#   'uname': '听姐姐的',
#   'content': '都是VIP说话大声点~~~',
#   'time': 46000,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837997292988265539,
#   'uname': '',
#   'content': '老子是来看万茜的',
#   'time': 47000,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837307499763784548,
#   'uname': '',
#   'content': '张雨绮冲鸭！！！',
#   'time': 47652,
#   'v2_up_count': 23},
#  {'stype': '8337559',
#   'id': 6837656002001238758,
#   'uname': '',
#   'content': '是王晰念的旁白吗！',
#   'time': 47452,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6838408703611281998,
#   'uname': '',
#   'content': '开头好像金陵十三钗那种风格',
#   'time': 47277,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837415758709934204,
#   'uname': '气场强大',
#   'content': '真帅啊好棒的陈松伶',
#   'time': 47958,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837843142316843599,
#   'uname': '',
#   'content': '在抖音一直刷到宁静姐姐哈哈来看看',
#   'time': 47061,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837602555428135456,
#   'uname': '',
#   'content': '吴昕沈梦辰',
#   'time': 48517,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837449371124157533,
#   'uname': '听姐姐的',
#   'content': '你一票我一票，昕姐明天就出道',
#   'time': 48229,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6841160983082412509,
#   'uname': '听姐姐的',
#   'content': ' 欣姐加油，我quick你哦！',
#   'time': 48079,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837307508353719176,
#   'uname': '',
#   'content': '太刺激了',
#   'time': 48000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837362548359856600,
#   'uname': '听姐姐的',
#   'content': '姐姐们冲鸭',
#   'time': 48460,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837697719018714132,
#   'uname': '',
#   'content': '在线call007',
#   'time': 48705,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837403041311714260,
#   'uname': '',
#   'content': '大型吃瓜  来啦 来啦',
#   'time': 49259,
#   'v2_up_count': 20},
#  {'stype': '8337559',
#   'id': 6837644229495855337,
#   'uname': '',
#   'content': '每个姐姐都好喜欢',
#   'time': 49120,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6838210752863401376,
#   'uname': '',
#   'content': '王鸥 杨蓉 我大明侦！！！冲呀！！！',
#   'time': 49867,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837307160461367027,
#   'uname': '',
#   'content': '冲鸭姐姐们',
#   'time': 49313,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6838402432959022519,
#   'uname': '',
#   'content': '这个我喜欢妞多注意进化自己词典别中文鸟语和破词',
#   'time': 49131,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837307667267509614,
#   'uname': '',
#   'content': '姐姐们我来了！',
#   'time': 49689,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837338874500009566,
#   'uname': '',
#   'content': '都不知道播了',
#   'time': 50649,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837307564188294196,
#   'uname': '',
#   'content': '霏霏王霏霏美死了',
#   'time': 50000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6840349294391901628,
#   'uname': '实力唱将',
#   'content': '姐姐们加油呀 看好你们哦',
#   'time': 50557,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837366113182729766,
#   'uname': '气场强大',
#   'content': '喜欢这个气场',
#   'time': 50000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837307078856988161,
#   'uname': '',
#   'content': '郁可唯啊啊啊啊',
#   'time': 50000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6838760096360975085,
#   'uname': '',
#   'content': '含韵冲冲冲！！！！',
#   'time': 50010,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837448331742066372,
#   'uname': '',
#   'content': '吴昕小姐姐加油',
#   'time': 51114,
#   'v2_up_count': 36},
#  {'stype': '8337559',
#   'id': 6837608022921506296,
#   'uname': '',
#   'content': '霏霏和佳冲啊',
#   'time': 51865,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837307461109078756,
#   'uname': '',
#   'content': '李斯丹妮',
#   'time': 51000,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837400975432435800,
#   'uname': '听姐姐的',
#   'content': '绝美姐姐，太飒了',
#   'time': 51250,
#   'v2_up_count': 7},
#  {'stype': '8337559',
#   'id': 6838018209479024796,
#   'uname': '',
#   'content': '啊啊啊啊啊啊！都好喜欢我的妈！',
#   'time': 51657,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837306876993524600,
#   'uname': '',
#   'content': '唯唯子冲啊！！！',
#   'time': 51383,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837415440882352892,
#   'uname': '',
#   'content': '白冰姐姐我来了嘿嘿嘿',
#   'time': 52866,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837307190526138199,
#   'uname': '',
#   'content': '郁可唯我来了',
#   'time': 52412,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837689408256963003,
#   'uname': '太后驾到',
#   'content': '啦啦啦都不知道开播了',
#   'time': 52000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837307061677118931,
#   'uname': '',
#   'content': '期待期待',
#   'time': 52000,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6841114799299009913,
#   'uname': '',
#   'content': '我来啦',
#   'time': 52370,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6839495832849324700,
#   'uname': '',
#   'content': '冲呀姐姐们！！',
#   'time': 52084,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6838746292336076914,
#   'uname': '听姐姐的',
#   'content': '孟佳冲鸭',
#   'time': 53297,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837307254950647840,
#   'uname': '',
#   'content': '姐姐们冲鸭',
#   'time': 53384,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837671408048968145,
#   'uname': '气场强大',
#   'content': '张雨绮万茜钟丽缇啊啊啊麻麻爱你们',
#   'time': 53302,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837325585871135605,
#   'uname': '',
#   'content': '姐姐们身材好好哦',
#   'time': 53000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837643709804811543,
#   'uname': '',
#   'content': '啊啊啊啊为姐姐们打call!!!!!',
#   'time': 53914,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837481901206627961,
#   'uname': '',
#   'content': '终于播了！',
#   'time': 53000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837416338530521879,
#   'uname': '',
#   'content': '成功的女人们来了',
#   'time': 54470,
#   'v2_up_count': 62},
#  {'stype': '8337559',
#   'id': 6837345445800002665,
#   'uname': '听姐姐的',
#   'content': '给姐姐们摁棒！！！姐姐们加油鸭！！',
#   'time': 54000,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837656818045026960,
#   'uname': '',
#   'content': '今年最期待的节目开播啦，喜大普奔',
#   'time': 54049,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837678082428164278,
#   'uname': '听姐姐的',
#   'content': '竟然藏这么严实~~~~~~~~~~',
#   'time': 54962,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6838204074189240151,
#   'uname': '',
#   'content': '姐姐们冲啊啊啊啊啊！！！！！！！！！！！！！',
#   'time': 54253,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837307254950647834,
#   'uname': '',
#   'content': '唯唯子沖鸭',
#   'time': 54815,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837406481580533160,
#   'uname': '',
#   'content': '张含韵给爷冲！！！',
#   'time': 55366,
#   'v2_up_count': 29},
#  {'stype': '8337559',
#   'id': 6837885293126020924,
#   'uname': '',
#   'content': '宁静真的很漂亮，超美丽，很有魅力，很有个性',
#   'time': 55082,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6840343440351466178,
#   'uname': '气场强大',
#   'content': '来咯  专门开了个会员',
#   'time': 55000,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837307353734895983,
#   'uname': '',
#   'content': '姐姐们身材都不错阿',
#   'time': 55887,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6840634896832543564,
#   'uname': '',
#   'content': '乘风破浪的姐姐们冲鸭！',
#   'time': 55065,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6841036454800454397,
#   'uname': '',
#   'content': '默默努力然后惊艳所有人',
#   'time': 55239,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837307315080190202,
#   'uname': '',
#   'content': '我的妈姐姐们都太好看了吧！！！！',
#   'time': 56035,
#   'v2_up_count': 25},
#  {'stype': '8337559',
#   'id': 6837307151871432402,
#   'uname': '',
#   'content': '支持各位姐姐',
#   'time': 56985,
#   'v2_up_count': 22},
#  {'stype': '8337559',
#   'id': 6837307787526594257,
#   'uname': '',
#   'content': '姐姐们，冲鸭',
#   'time': 56639,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6837308775369075716,
#   'uname': '',
#   'content': '陆陆子加油！！！！',
#   'time': 56549,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837447129151217130,
#   'uname': '听姐姐的',
#   'content': '墓道歌姬给我冲冲冲！！！！！',
#   'time': 56633,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6839642999903886915,
#   'uname': '',
#   'content': '这个开头词是谁给的？',
#   'time': 56269,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837620096074584857,
#   'uname': '',
#   'content': '这个节目真的太有意义了',
#   'time': 57898,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837307813296398124,
#   'uname': '',
#   'content': '王丽坤',
#   'time': 57167,
#   'v2_up_count': 42},
#  {'stype': '8337559',
#   'id': 6837394580226103404,
#   'uname': '听姐姐的',
#   'content': '哈哈哈哈哈哈哈哈来啦',
#   'time': 57323,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6838123882854677409,
#   'uname': '',
#   'content': '含韵姐姐加油啊，我爱你！！！',
#   'time': 57087,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837719911114816198,
#   'uname': '',
#   'content': '比其他选修好看',
#   'time': 57105,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6838765666933562047,
#   'uname': '',
#   'content': '奔三的我来找自信心了',
#   'time': 57234,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837307272130517082,
#   'uname': '',
#   'content': '有内味了，',
#   'time': 58821,
#   'v2_up_count': 50},
#  {'stype': '8337559',
#   'id': 6837649563845247578,
#   'uname': '',
#   'content': '特地充了会员',
#   'time': 58933,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837307027317380435,
#   'uname': '',
#   'content': '坤坤子冲啊',
#   'time': 58000,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837984154683297177,
#   'uname': '',
#   'content': '姐姐们我来啦！！！',
#   'time': 58245,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837437396755274545,
#   'uname': '听姐姐的',
#   'content': '张含韵冲冲冲',
#   'time': 58200,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837797242001207378,
#   'uname': '',
#   'content': '白冰，为你打call',
#   'time': 58022,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837307126101628558,
#   'uname': '',
#   'content': '吴昕吴昕',
#   'time': 59000,
#   'v2_up_count': 87},
#  {'stype': '8337559',
#   'id': 6837307611432934601,
#   'uname': '',
#   'content': '张含韵我来啦',
#   'time': 59256,
#   'v2_up_count': 42},
#  {'stype': '8337559',
#   'id': 6837400507280998513,
#   'uname': '',
#   'content': '张含韵万茜冲啊！！！',
#   'time': 59608,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6838024828023639497,
#   'uname': '',
#   'content': '会不会以后有个披荆斩棘的哥哥们，哈哈哈',
#   'time': 59365,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837307439634242192,
#   'uname': '',
#   'content': '万茜冲冲冲！！！！',
#   'time': 59332,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6840441580354371528,
#   'uname': '',
#   'content': '93年。即将步入30岁，。喜欢这个节目',
#   'time': 59073,
#   'v2_up_count': ''},
#  {'stype': '8337559',
# ...
#  {'stype': '8337559',
#   'id': 6837453666091476477,
#   'uname': '听姐姐的',
#   'content': '姐姐们，冲啊！！！',
#   'time': 147177,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837307538418490334,
#   'uname': '',
#   'content': '姐姐们我来啦',
#   'time': 147145,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6837671309264720042,
#   'uname': '',
#   'content': '啊～姐姐们，我爱你们。',
#   'time': 147491,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6840460967836794701,
#   'uname': '',
#   'content': '这节目是真的可以！！！！大爱！！！！',
#   'time': 147000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837384899369773092,
#   'uname': '听姐姐的',
#   'content': '姐姐们真的越来越好看了！！',
#   'time': 147743,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837689794804021124,
#   'uname': '气场强大',
#   'content': '终于找到了一个不用快进和加倍速的综艺节目',
#   'time': 148104,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837308418886788988,
#   'uname': '',
#   'content': '好激动，鸡皮疙瘩起来了。',
#   'time': 148081,
#   'v2_up_count': 90},
#  {'stype': '8337559',
#   'id': 6838328349068088445,
#   'uname': '',
#   'content': '这节目实在是感动了，就还没有看完，就觉得30岁以后的女人需要重启，泪目中',
#   'time': 148283,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837311949349916877,
#   'uname': '',
#   'content': '姐姐们加油',
#   'time': 148847,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837639191499208116,
#   'uname': '',
#   'content': '姐姐们 加油！',
#   'time': 148806,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837817299498537106,
#   'uname': '',
#   'content': '姐姐们加油❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#   'time': 148249,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837701700453413184,
#   'uname': '',
#   'content': '芒果的文案写手是年薪百万的吧，写的文案太绝了',
#   'time': 149418,
#   'v2_up_count': 125},
#  {'stype': '8337559',
#   'id': 6837314139783245119,
#   'uname': '',
#   'content': '变形记口吻',
#   'time': 149884,
#   'v2_up_count': 302},
#  {'stype': '8337559',
#   'id': 6837389718323101766,
#   'uname': '',
#   'content': '开场白也太棒了吧，起鸡皮疙瘩了',
#   'time': 149476,
#   'v2_up_count': 55},
#  {'stype': '8337559',
#   'id': 6837357819600840859,
#   'uname': '',
#   'content': '蓝盈莹加油啊',
#   'time': 149479,
#   'v2_up_count': 33},
#  {'stype': '8337559',
#   'id': 6837467504476176888,
#   'uname': '拎包妹',
#   'content': '我来啦我来啦我来啦 ！！！',
#   'time': 149000,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6838086228876292010,
#   'uname': '听姐姐的',
#   'content': '前面的，90后最大的也有30了',
#   'time': 149832,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837456788532717373,
#   'uname': '太后驾到',
#   'content': '你爸爸终究是你爸爸，芒果太给力了，这个文案这个舞台我都好喜欢！',
#   'time': 150175,
#   'v2_up_count': 71},
#  {'stype': '8337559',
#   'id': 6837307997979992469,
#   'uname': '',
#   'content': '芒果文案🐮🍺',
#   'time': 150083,
#   'v2_up_count': 243},
#  {'stype': '8337559',
#   'id': 6837340777170530421,
#   'uname': '听姐姐的',
#   'content': '姐姐我来啦～',
#   'time': 150680,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837439947965861145,
#   'uname': '气场强大',
#   'content': '芒果的文案果然没有让人失望😊',
#   'time': 150728,
#   'v2_up_count': 12},
#  {'stype': '8337559',
#   'id': 6837855919844600244,
#   'uname': '',
#   'content': '这也是成团出道吗😂️',
#   'time': 150014,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6840019896169544991,
#   'uname': '',
#   'content': '有趣的灵魂，万里挑一',
#   'time': 150433,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837307972210188609,
#   'uname': '',
#   'content': '想哭是咋回事',
#   'time': 151049,
#   'v2_up_count': 92},
#  {'stype': '8337559',
#   'id': 6837423438111494933,
#   'uname': '听姐姐的',
#   'content': '开头好像变形记哦～',
#   'time': 151000,
#   'v2_up_count': 21},
#  {'stype': '8337559',
#   'id': 6837471868162972173,
#   'uname': '气场强大',
#   'content': '我大弗兰台的文案真的绝！！！',
#   'time': 151000,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6838386511515239486,
#   'uname': '',
#   'content': '这才是女团 现在 年轻女团长得谁是谁都分不清全一个模样',
#   'time': 151660,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6837309642952472084,
#   'uname': '',
#   'content': '宁静万茜出道',
#   'time': 151360,
#   'v2_up_count': 20},
#  {'stype': '8337559',
#   'id': 6840103424693748392,
#   'uname': '气场强大',
#   'content': '写文案直接把我听的鸡皮疙瘩都起来了，太棒了！吹爆我大芒果台！',
#   'time': 151289,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837326449159565942,
#   'uname': '',
#   'content': '芒果综艺太用心了喜欢',
#   'time': 152000,
#   'v2_up_count': 103},
#  {'stype': '8337559',
#   'id': 6837491242760542579,
#   'uname': '',
#   'content': '文案稿子真不错',
#   'time': 152288,
#   'v2_up_count': 81},
#  {'stype': '8337559',
#   'id': 6837828255960140796,
#   'uname': '',
#   'content': '先给芒果台点个赞 真的厉害',
#   'time': 152000,
#   'v2_up_count': 54},
#  {'stype': '8337559',
#   'id': 6838916171177717148,
#   'uname': '',
#   'content': '什么是山，就是人心中的偏见啊，还记得吗',
#   'time': 152000,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837321948033819484,
#   'uname': '',
#   'content': '吴小昕冲',
#   'time': 152793,
#   'v2_up_count': 66},
#  {'stype': '8337559',
#   'id': 6840001758522615593,
#   'uname': '',
#   'content': '90年的已经三十了，95年的还远吗？',
#   'time': 152443,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837314255747362502,
#   'uname': '',
#   'content': '文案好棒',
#   'time': 153000,
#   'v2_up_count': 101},
#  {'stype': '8337559',
#   'id': 6837719120840831041,
#   'uname': '',
#   'content': '给大家点赞点的我手都累了',
#   'time': 153000,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837313048861548141,
#   'uname': '',
#   'content': '万茜我爱你',
#   'time': 153385,
#   'v2_up_count': 42},
#  {'stype': '8337559',
#   'id': 6837484697230351833,
#   'uname': '',
#   'content': '为了这节目特意充了会员hhh',
#   'time': 153000,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837623862760907209,
#   'uname': '',
#   'content': '文案必须好呀 吴梦知大神的作品',
#   'time': 153000,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6838461407155062636,
#   'uname': '',
#   'content': '我喜欢宁静，她就是乘风破浪的人',
#   'time': 153000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837314023819127705,
#   'uname': '',
#   'content': '文案太棒了',
#   'time': 154000,
#   'v2_up_count': 132},
#  {'stype': '8337559',
#   'id': 6837307431044307572,
#   'uname': '',
#   'content': '昕昕子给我冲',
#   'time': 154898,
#   'v2_up_count': 42},
#  {'stype': '8337559',
#   'id': 6837307010137511198,
#   'uname': '',
#   'content': '没用青春归位好评',
#   'time': 154472,
#   'v2_up_count': 22},
#  {'stype': '8337559',
#   'id': 6837706283183536145,
#   'uname': '',
#   'content': '这几个姐姐们还好，至少不是网红脸，能分清😂😂😂',
#   'time': 154797,
#   'v2_up_count': 10},
#  {'stype': '8337559',
#   'id': 6837307766051757698,
#   'uname': '',
#   'content': '姐姐们 冲鸭 ',
#   'time': 154632,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837858178997406378,
#   'uname': '',
#   'content': '霸气魔丸静静子! 第一金瓜茜茜子! 笨蛋美人琦琦子! 冲鸭!',
#   'time': 154112,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837307426749340254,
#   'uname': '',
#   'content': '为什么有一种想哭的感觉？我还不到30呀',
#   'time': 155000,
#   'v2_up_count': 16},
#  {'stype': '8337559',
#   'id': 6837860923481518348,
#   'uname': '',
#   'content': '蓝盈莹刚好30',
#   'time': 155705,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837727500322054186,
#   'uname': '',
#   'content': '百万文案千万后期',
#   'time': 155000,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837631421903357822,
#   'uname': '',
#   'content': '再来一遍，这是哪个表演组，就坐轮椅👩\u200d\U0001f9bc了',
#   'time': 155000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6839918565005845762,
#   'uname': '',
#   'content': '这里面最小年龄20多到50多岁',
#   'time': 155008,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837307907785678937,
#   'uname': '',
#   'content': '太好哭了',
#   'time': 155000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6837832190150196002,
#   'uname': '',
#   'content': '这文案绝了！！！！！！！！！！！！！！',
#   'time': 156206,
#   'v2_up_count': 74},
#  {'stype': '8337559',
#   'id': 6837307912080646245,
#   'uname': '',
#   'content': '湖南卫视太会了',
#   'time': 156972,
#   'v2_up_count': 570},
#  {'stype': '8337559',
#   'id': 6837309346599727858,
#   'uname': '',
#   'content': '芒果文案绝了',
#   'time': 156000,
#   'v2_up_count': 203},
#  {'stype': '8337559',
#   'id': 6837308195548488805,
#   'uname': '',
#   'content': '姐姐们我来啦！冲',
#   'time': 156000,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6837700880114656542,
#   'uname': '',
#   'content': '我是为了体验会员的',
#   'time': 156000,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6838080280346567051,
#   'uname': '',
#   'content': '刚三十出头的自己，想哭',
#   'time': 156000,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837308556325742900,
#   'uname': '',
#   'content': '湖南卫视的后期与文字真的在我的点上',
#   'time': 157000,
#   'v2_up_count': 47},
#  {'stype': '8337559',
#   'id': 6837308332987442760,
#   'uname': '',
#   'content': '昕昕冲啊',
#   'time': 157017,
#   'v2_up_count': 26},
#  {'stype': '8337559',
#   'id': 6837308968642604674,
#   'uname': '',
#   'content': '茜茜子冲鸭',
#   'time': 157000,
#   'v2_up_count': 24},
#  {'stype': '8337559',
#   'id': 6837408233927197627,
#   'uname': '',
#   'content': '每个姐姐都喜欢，怎么办😱，投谁啊！',
#   'time': 157000,
#   'v2_up_count': 6},
#  {'stype': '8337559',
#   'id': 6837971922616432440,
#   'uname': '',
#   'content': '有一说一，wuli芒果台文案真是强啊',
#   'time': 157495,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6839522899733244174,
#   'uname': '',
#   'content': '谢谢正能量的节目，也让30+的我，充满阳光',
#   'time': 157419,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6838169091680534167,
#   'uname': '',
#   'content': '这些姐姐都好有辨识度，真的是好看',
#   'time': 158120,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837309591412864396,
#   'uname': '',
#   'content': '片头文案好戳心啊',
#   'time': 158651,
#   'v2_up_count': 315},
#  {'stype': '8337559',
#   'id': 6839229669430825728,
#   'uname': '',
#   'content': '牛皮，这个文案我服了，我听着鸡皮疙瘩都起来了，真的厉害！',
#   'time': 158000,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837332109926487082,
#   'uname': '气场强大',
#   'content': '想念霏霏',
#   'time': 158000,
#   'v2_up_count': 11},
#  {'stype': '8337559',
#   'id': 6840035340871979575,
#   'uname': '',
#   'content': '太棒了，这个节目，被感动到了❤️',
#   'time': 158515,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837307809001430807,
#   'uname': '',
#   'content': '哈哈哈哈姐姐们冲',
#   'time': 158157,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6837309935010249078,
#   'uname': '',
#   'content': '芒果文案绝了绝了！',
#   'time': 159653,
#   'v2_up_count': 360},
#  {'stype': '8337559',
#   'id': 6837307611432934606,
#   'uname': '',
#   'content': '鸡汤文案',
#   'time': 159000,
#   'v2_up_count': 83},
#  {'stype': '8337559',
#   'id': 6837345944016211215,
#   'uname': '听姐姐的',
#   'content': '有变形记内味了',
#   'time': 159230,
#   'v2_up_count': 64},
#  {'stype': '8337559',
#   'id': 6837741454670843799,
#   'uname': '',
#   'content': '这就是变形记的独白小哥吧😂',
#   'time': 159000,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6838394744967554170,
#   'uname': '',
#   'content': '100分钟是不敢剪嘛哈哈哈哈哈',
#   'time': 159818,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6838790655053311530,
#   'uname': '浪花崽',
#   'content': '不出所料的话不久之后应该又有很多类似的节目出现了',
#   'time': 159115,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837308607865350617,
#   'uname': '',
#   'content': '昕姐加油，pick你',
#   'time': 160941,
#   'v2_up_count': 63},
#  {'stype': '8337559',
#   'id': 6837340485112752936,
#   'uname': '',
#   'content': '有、、、高级',
#   'time': 160409,
#   'v2_up_count': 37},
#  {'stype': '8337559',
#   'id': 6837309183390970128,
#   'uname': '',
#   'content': '这个节目的性质可可可可可可',
#   'time': 160000,
#   'v2_up_count': 19},
#  {'stype': '8337559',
#   'id': 6837647914577802509,
#   'uname': '',
#   'content': '姐姐们我来了，这是我今年唯一看的综艺了',
#   'time': 160141,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837309479743714411,
#   'uname': '',
#   'content': '来了 漂亮姐姐们 ！！',
#   'time': 160068,
#   'v2_up_count': 13},
#  {'stype': '8337559',
#   'id': 6837766344006393552,
#   'uname': '',
#   'content': '我也是姐姐的年龄了，还有两个礼拜就是30岁啦，三十而励，加油自己',
#   'time': 160158,
#   'v2_up_count': 2},
#  {'stype': '8337559',
#   'id': 6840276838293442026,
#   'uname': '',
#   'content': '这鸡汤好喝',
#   'time': 161000,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837417176049148531,
#   'uname': '',
#   'content': '这是丁文山的声音吗？',
#   'time': 161000,
#   'v2_up_count': 30},
#  {'stype': '8337559',
#   'id': 6837598462324300530,
#   'uname': '',
#   'content': '片头看的我 想多读些书了',
#   'time': 161000,
#   'v2_up_count': 28},
#  {'stype': '8337559',
#   'id': 6837698504997732437,
#   'uname': '',
#   'content': '这鸡汤干了，为30而励干杯🍻',
#   'time': 161692,
#   'v2_up_count': 18},
#  {'stype': '8337559',
#   'id': 6839889861739329077,
#   'uname': '',
#   'content': '湖南卫视的文案从来都没让我失望',
#   'time': 161148,
#   'v2_up_count': 8},
#  {'stype': '8337559',
#   'id': 6841076574090029267,
#   'uname': '',
#   'content': '那个说蓝盈莹90后的，90年今年刚刚30🙄',
#   'time': 161074,
#   'v2_up_count': ''},
#  {'stype': '8337559',
#   'id': 6837770995455987411,
#   'uname': '',
#   'content': '湖南卫视做综艺真的没话说',
#   'time': 162000,
#   'v2_up_count': 69},
#  {'stype': '8337559',
#   'id': 6837309252110447068,
#   'uname': '',
#   'content': '这文案太好了',
#   'time': 162477,
#   'v2_up_count': 290},
#  {'stype': '8337559',
#   'id': 6838850200479977009,
#   'uname': '',
#   'content': '我想到了SNH48 SII的公演，一切过往，皆为序章，233',
#   'time': 162969,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837351454459277350,
#   'uname': '听姐姐的',
#   'content': '湖南卫视还是稳的',
#   'time': 162754,
#   'v2_up_count': 52},
#  {'stype': '8337559',
#   'id': 6837309093196656654,
#   'uname': '',
#   'content': '好期待  终于开播了',
#   'time': 162764,
#   'v2_up_count': 15},
#  {'stype': '8337559',
#   'id': 6837648352664467585,
#   'uname': '',
#   'content': '奥利给   雨绮姐加油  看好你哦  希望你霸气依旧',
#   'time': 162000,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6838841481696357212,
#   'uname': '',
#   'content': '怎么开头一股变形计的味道哈哈',
#   'time': 163426,
#   'v2_up_count': 17},
#  {'stype': '8337559',
#   'id': 6837309685902145163,
#   'uname': '',
#   'content': '芒果文案好棒',
#   'time': 163000,
#   'v2_up_count': 88},
#  {'stype': '8337559',
#   'id': 6837309333714825941,
#   'uname': '',
#   'content': '好热血，我起鸡皮疙瘩了',
#   'time': 163623,
#   'v2_up_count': 72},
#  {'stype': '8337559',
#   'id': 6837636206496932607,
#   'uname': '',
#   'content': '文案哪里好了 全身不舒适 ',
#   'time': 163442,
#   'v2_up_count': 9},
#  {'stype': '8337559',
#   'id': 6838119330189332687,
#   'uname': '',
#   'content': '芒果台的综艺真可明侦迷逃向往的生活',
#   'time': 163295,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6839216806003763195,
#   'uname': '',
#   'content': '我大芒果是真的有钱。',
#   'time': 163056,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837308826908683433,
#   'uname': '',
#   'content': '文案也太热血了 励志',
#   'time': 164462,
#   'v2_up_count': 230},
#  {'stype': '8337559',
#   'id': 6837442134104226023,
#   'uname': '听姐姐的',
#   'content': '开场说的好有激情啊🌹',
#   'time': 164607,
#   'v2_up_count': 22},
#  {'stype': '8337559',
#   'id': 6838017870176607830,
#   'uname': '',
#   'content': '姐姐们一起出道吧！我选不出来！！',
#   'time': 164000,
#   'v2_up_count': 3},
#  {'stype': '8337559',
#   'id': 6837621496233924701,
#   'uname': '',
#   'content': 'momode开了会员',
#   'time': 164000,
#   'v2_up_count': 5},
#  {'stype': '8337559',
#   'id': 6837308539145873643,
#   'uname': '',
#   'content': '姐姐们好漂酿',
#   'time': 164361,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837884459902364004,
#   'uname': '',
#   'content': '哇 好喜欢这句  青春归位',
#   'time': 164498,
#   'v2_up_count': 1},
#  {'stype': '8337559',
#   'id': 6837388399768135627,
#   'uname': '听姐姐的',
#   'content': '这个开头看得我热血沸腾，激情澎湃的',
#   'time': 165000,
#   'v2_up_count': 33},
#  {'stype': '8337559',
#   'id': 6837307851951103910,
#   'uname': '',
#   'content': '为金晨而来',
#   'time': 165234,
#   'v2_up_count': 47},
#  {'stype': '8337559',
#   'id': 6837309290765152846,
#   'uname': '',
#   'content': '没有投票吗？',
#   'time': 165000,
#   'v2_up_count': 26},
#  {'stype': '8337559',
#   'id': 6837468964765065077,
#   'uname': '浪花崽',
#   'content': '孟佳！！王霏霏！！冲冲冲！！！！',
#   'time': 165005,
#   'v2_up_count': 14},
#  {'stype': '8337559',
#   'id': 6837646707691989918,
#   'uname': '',
#   'content': '这个节目不知道做出来有什么意义，反而优秀的人被淘汰',
#   'time': 165852,
#   'v2_up_count': 4},
#  {'stype': '8337559',
#   'id': 6837308534850906335,
#   'uname': '',
#   'content': '王霏霏冲呀！',
#   'time': 165000,
#   'v2_up_count': 26},
#  {'stype': '8337559',
#   'id': 6837604629897340520,
#   'uname': '',
#   'content': '芒果台文案是一绝',
#   'time': 166869,
#   'v2_up_count': 641},
#  {'stype': '8337559',
#   'id': 6837324310265842958,
#   'uname': '',
#   'content': '文案满分，喜欢～～',
#   'time': 166569,
#   'v2_up_count': 406},
#  {'stype': '8337559',
#   'id': 6837453653206574500,
#   'uname': '',
#   'content': '文案太好了，高考语文作文满分吧！',
#   'time': 166031,
#   'v2_up_count': 151},
#  {'stype': '8337559',
#   'id': 6837782806616084522,
#   'uname': '',
#   'content': '前面cue蓝盈莹的 90也30了呀……哈哈',
#   'time': 166000,
#   'v2_up_count': 7},
#  ...]

# %%
df_end = pd.DataFrame(df)

# %%
df_end
# Out:
#          stype                   id uname                content     time  \
# 0      8337559  6837425357961885168  听姐姐的                 昕姐冲！！！        0
# 1      8337559  6837994106122529085                        在看一次！        0
# 2      8337559  6838116886352935403            为黄圣依，张雨绮，郑希怡打call        0
# 3      8337559  6837307130396595873                 姐姐们 我来了~~！！！        0
# 4      8337559  6837758462741384194               我去，真的爱了，都是我喜欢的        0
# ...        ...                  ...   ...                    ...      ...
# 35929  8337559  6837429889152404148                       我喘不过气了  6011000
# 35930  8337559  6837341872387195924        我开倍速了🐴怎么感觉说的好快，哈哈哈哈哈哈  6011259
# 35931  8337559  6837466258935654471                        你停一会儿  6012212
# 35932  8337559  6837447391144223619                         奇奇怪怪  6012240
# 35933  8337559  6837342353423535327                   这播报可以啊！！！！  6012226
#
#       v2_up_count
# 0              24
# 1
# 2              10
# 3              21
# 4              13
# ...           ...
# 35929
# 35930
# 35931
# 35932
# 35933
#
# [35934 rows x 6 columns]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
dff=pd.read_excel('danmu.xlsx')

# %%
dff.head()
# Out:
#    Unnamed: 0    stype                   id uname            content  time  \
# 0           0  8337559  6837425357961884672  听姐姐的             昕姐冲！！！     0
# 1           1  8337559  6837994106122528768   NaN              在看一次！     0
# 2           2  8337559  6838116886352934912   NaN  为黄圣依，张雨绮，郑希怡打call     0
# 3           3  8337559  6837307130396596224   NaN       姐姐们 我来了~~！！！     0
# 4           4  8337559  6837758462741384192   NaN     我去，真的爱了，都是我喜欢的     0
#
#    v2_up_count
# 0         24.0
# 1          NaN
# 2         10.0
# 3         21.0
# 4         13.0

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131726 entries, 0 to 131725
# Data columns (total 7 columns):
# Unnamed: 0     131726 non-null int64
# stype          131726 non-null int64
# id             131726 non-null int64
# uname          6749 non-null object
# content        131726 non-null object
# time           131726 non-null int64
# v2_up_count    123417 non-null float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 7.0+ MB

# %%
url = 'https://pcweb.api.mgtv.com/star/list?video_id=8337559&_support=10000000&callback=jsonp_1592879331738_65936'

# %%
res=requests.get(url)
res.encoding = 'utf-8'

# %%
jd=json.loads(res.text.lstrip('jsonp_1592879331738_65936(').rstrip(")'"))

# %%
jd['data'][0]
# Out:
# {'uid': 'c73729ae759a255a7cb891bdf1e5c9ef',
#  'img': 'https://ugc.hitv.com/platform_oss/5605DBE979B74A709E2A05E26DD5AA36.jpg',
#  'intro': '吴昕，中国电视节目主持人、演员。2006年，获得“闪亮新主播”亚军，并签约湖南卫视，与何炅、李维嘉、谢娜、杜海涛一起主持《快乐大本营》。2016年，参与时尚真人秀《我的新衣》。2017年，主持网综《爱in思谈》。2019年，参加湖南卫视观察成长节目《我家那闺女》。2020年，参加录制芒果TV女团成长综艺《乘风破浪的姐姐》。',
#  'name': '吴昕',
#  'online': '0',
#  'id': '0',
#  'hot': '15.0万关注'}

# %%
dff.head()
# Out:
#    Unnamed: 0    stype                   id uname            content  time  \
# 0           0  8337559  6837425357961884672  听姐姐的             昕姐冲！！！     0
# 1           1  8337559  6837994106122528768   NaN              在看一次！     0
# 2           2  8337559  6838116886352934912   NaN  为黄圣依，张雨绮，郑希怡打call     0
# 3           3  8337559  6837307130396596224   NaN       姐姐们 我来了~~！！！     0
# 4           4  8337559  6837758462741384192   NaN     我去，真的爱了，都是我喜欢的     0
#
#    v2_up_count
# 0         24.0
# 1          NaN
# 2         10.0
# 3         21.0
# 4         13.0

# %%
my_words_list =['蓝盈莹', '盈莹', '黄龄', '丹妮', '孟佳', '梦辰', '可唯', '宁静', '静静子', '静姐', '霏霏', '希怡', '袁咏琳', '圣依', '依依子', '金晨', '阿朵', '含韵', '白冰', '钟丽缇', '茜', '张萌', '萌萌子', '婧汐', '丁当', '许飞', '刘芸', '芸芸子', '吴昕', '昕昕子', '昕姐', '昕昕', '伊能静', '松伶', '丽坤', '张雨绮', '雨绮', '绮绮子', '海陆', '金莎', '王智']

# %%
dff['content'] = dff.content.astype('str')

# %%
def get_cut_words(content_series):
    # 读入停用词表
    import jieba 
    stop_words = [] 
    
    with open(r"/Users/nika/Desktop/chineseStopWords.txt") as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    # 添加关键词
    my_words = ['杜华', '辣鸡', '导演组', '节目组', '不公平', '黄圣依', '无杜华版']      
    for i in my_words:
        jieba.add_word(i) 
        
    my_words2 = my_words_list
    for j in my_words2:
        jieba.add_word(j) 

    # 自定义停用词
    my_stop_words = ['第一期', '一堆', '三个', '真的', '哈哈哈', '哈哈哈哈', '啊啊啊']    
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected

# %%
text1 = get_cut_words(content_series=dff.content)
text1[:5]
# Out:
# ['昕姐', '黄圣依', '张雨绮', '郑希怡', 'call']

# %%
# 导入包
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import stylecloud
from IPython.display import Image # 用于在jupyter lab中显示本地图片
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-103-5dae9b420960> in <module>
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 5 import stylecloud
#       6 from IPython.display import Image # 用于在jupyter lab中显示本地图片
#
# ModuleNotFoundError: No module named 'stylecloud'

# %%
text2 = get_cut_words(dff.content[dff.content.str.contains('宁静|静静子|静姐')])
text2[:5]
# Out:
# ['宁静', '宁静', '宁静', 'call', '宁静']

# %%
text2
# Out:
# ['宁静',
#  '宁静',
#  '宁静',
#  'call',
#  '宁静',
#  '宁静',
#  '来看',
#  '宁静',
#  '伊能静',
#  '姐姐',
#  '温柔',
#  '宁静',
#  '宁静',
#  '喜欢',
#  '李斯',
#  '丹妮',
#  '含韵',
#  '丁当',
#  '宁静',
#  '吴昕',
#  '金晨',
#  '宁静',
#  '张雨绮',
#  '出道',
#  '来看',
#  '姐姐',
#  '静姐',
#  '我来',
#  '宁静',
#  '加油',
#  '张雨绮',
#  '加油',
#  '吴昕',
#  '加油',
#  '宁静',
#  '姐姐',
#  '尖叫',
#  '静姐',
#  'call',
#  '宁静',
#  '金晨',
#  '张雨绮',
#  '宁静',
#  '宁静',
#  '大姐大',
#  '静姐',
#  '宁静',
#  '宁静',
#  'pink',
#  '静姐',
#  '宁静',
#  '姐姐',
#  '冲冲',
#  '冲冲',
#  '抖音',
#  '刷到',
#  '宁静',
#  '姐姐',
#  '宁静',
#  '很漂亮',
#  '美丽',
#  '魅力',
#  '个性',
#  '宁静',
#  '宁静',
#  '我来',
#  '静静子',
#  '伊能静',
#  '姐姐',
#  '不管怎样',
#  '选择',
#  '昕姐',
#  '宁静',
#  '加油',
#  '万茜',
#  '宁静',
#  '张雨绮',
#  '姐姐',
#  '宁静',
#  '静姐',
#  '加油',
#  '静姐',
#  '宁静',
#  '静姐',
#  '万茜',
#  '张雨绮',
#  '宁静',
#  '静姐',
#  '太飒',
#  '静静子',
#  '宁静',
#  '姐冲',
#  '宁静',
#  '万茜',
#  '蓝盈莹',
#  '宁静',
#  '张雨绮',
#  '冲冲',
#  '宁静',
#  '宁静',
#  '期待',
#  '宁静',
#  '静静子',
#  '宁静',
#  'aaaaaaaa',
#  '出道',
#  '出道',
#  '宁静',
#  '耳环',
#  '好好看',
#  '宁静',
#  '粉头',
#  '哦哦哦',
#  '静姐',
#  '宁静',
#  '使劲',
#  '努力',
#  '宁静',
#  '宁静',
#  '加油',
#  '留个',
#  '喜欢',
#  '宁静',
#  '静姐',
#  '张雨绮',
#  '宁静',
#  '高位',
#  '宁静',
#  '冲冲',
#  '宁静',
#  '越来越',
#  '年轻',
#  '宁静',
#  '万茜',
#  '出道',
#  '喜欢',
#  '宁静',
#  '乘风破浪',
#  '霸气',
#  '魔丸',
#  '静静子',
#  '金瓜',
#  '茜茜子',
#  '笨蛋',
#  '美人琦琦子',
#  '静静子',
#  '绮绮子',
#  '霸气',
#  '魔丸',
#  '静静子',
#  '金瓜',
#  '茜茜子',
#  '笨蛋',
#  '美人琦琦子',
#  '静姐',
#  '发色',
#  '求求',
#  '宁静',
#  '偶像',
#  '好多',
#  '静静子',
#  '宁静',
#  '张雨绮',
#  '静静子',
#  '宁静',
#  '最美',
#  '宁静',
#  '静姐',
#  '综艺',
#  '莫名',
#  '搞笑',
#  '静姐',
#  '漂亮',
#  '静静子',
#  '静姐',
#  '越来越',
#  '漂亮',
#  '静姐',
#  '妆发',
#  '好看',
#  '宁静',
#  '冲冲',
#  '静静子',
#  '喜欢',
#  '宁静',
#  '真实',
#  '宁静',
#  '姐姐',
#  '宁静',
#  '好看',
#  'pick',
#  '绮绮子',
#  '静静子',
#  '静姐',
#  '张雨绮',
#  '宁静',
#  '加油',
#  '宁静',
#  '嚣张',
#  '喜欢',
#  '怎么回事',
#  '宁静',
#  '脾气',
#  '礼貌',
#  '张雨绮',
#  '两个',
#  '概念',
#  '不愧',
#  '静姐',
#  '伊能静',
#  '姐姐',
#  '喜欢',
#  '宁静',
#  '张雨绮',
#  '宁静',
#  '位出',
#  '静姐',
#  '不愧',
#  '宁静',
#  '静静子',
#  '好美',
#  '静姐',
#  '跟娜',
#  '短发',
#  '有点像',
#  '好好看',
#  '静姐',
#  '我来',
#  '宁静',
#  '太太',
#  '太太',
#  '太美',
#  '静姐',
#  '静姐',
#  '女团',
#  '广场',
#  '动作',
#  '看不见',
#  '静姐',
#  '真相',
#  '宁静',
#  '姐姐',
#  '静姐',
#  '开起',
#  '学渣',
#  '模式',
#  '静姐',
#  '真敢',
#  '宁静',
#  '感觉',
#  '不老',
#  '宁静',
#  '万茜',
#  '小姐姐',
#  '女团',
#  '舞台',
#  '静姐',
#  '我会',
#  '宁静',
#  '不愧',
#  '静姐',
#  '宁静',
#  'hiahiahia',
#  '宁静',
#  '耳钉',
#  '个性',
#  '静姐',
#  '搞笑',
#  '宁静',
#  '想法',
#  '静静子',
#  '静姐',
#  '宁静',
#  '好像',
#  '耳返',
#  '静姐',
#  '干嘛',
#  '宁静',
#  '美绝',
#  '喜欢',
#  '宁静',
#  '宁静',
#  '真敢',
#  '宁静',
#  '姐姐',
#  '出道',
#  '静姐',
#  '总说',
#  '实话',
#  '静姐',
#  '静姐',
#  '太暗',
#  '静姐',
#  '毛病',
#  '能静',
#  '姐姐',
#  '随和',
#  '亲切',
#  '亚子',
#  '有个',
#  '镜头',
#  '静姐',
#  '没加',
#  '滤镜',
#  '姐姐',
#  '宁静',
#  '爱死',
#  '静姐',
#  '太美',
#  '宁静',
#  '真相',
#  '张雨绮',
#  '万茜',
#  '吴昕',
#  '宁静',
#  '加油',
#  '宁静',
#  '姐姐',
#  '气质',
#  '气势',
#  '静姐',
#  '一战',
#  '张雨绮',
#  '宁静',
#  '出道',
#  '太宣',
#  'pick',
#  '万茜',
#  '宁静',
#  '张雨绮',
#  '静姐',
#  '匹敌',
#  '喜欢',
#  '张雨绮',
#  '宁静',
#  '期待',
#  '姐姐',
#  '静姐',
#  '位出',
#  '暴风雨',
#  '宁静',
#  '我来',
#  '来看',
#  '宁静',
#  '张雨绮',
#  '宁静',
#  '静静子',
#  '位出',
#  '宁静',
#  '宁静',
#  '冲冲',
#  '喜欢',
#  '宁静',
#  '张雨绮',
#  '姐姐',
#  '我来',
#  '万茜',
#  '张雨绮',
#  '静姐',
#  '宁静',
#  '宁静',
#  '加油',
#  '宁静',
#  '万茜冲',
#  '宁静',
#  '给爷',
#  '金晨',
#  '给爷',
#  '雨绮',
#  '姐姐',
#  '给爷',
#  '宁静',
#  '静静子',
#  '位出',
#  '宁静',
#  '姐姐',
#  '位出',
#  '琦琦子',
#  '静静子',
#  '宁静',
#  '静静子',
#  '琦琦子',
#  '小花',
#  '昕昕子',
#  '茜茜子',
#  '感觉',
#  '看点',
#  '十足',
#  '静姐',
#  '静姐',
#  '刚来',
#  '会员',
#  '静姐',
#  'call',
#  '黄圣依',
#  '万茜',
#  '宁静',
#  '张雨绮',
#  '伊能静',
#  '蓝盈莹',
#  '梦辰',
#  '黄龄',
#  '孟佳',
#  '丽坤',
#  '吴昕',
#  '钟丽缇',
#  '金莎',
#  '白冰',
#  '金晨',
#  '刘芸',
#  '钟丽缇',
#  '宁静',
#  '最美',
#  '霸气',
#  '长得',
#  '喜欢',
#  '钟丽缇',
#  '宁静',
#  '来看',
#  '宁静',
#  '一个',
#  '大爷',
#  '抖音',
#  '来看',
#  '宁静',
#  '人选',
#  '静姐',
#  '宁静',
#  '压轴',
#  '出场',
#  '万茜',
#  '加油',
#  '宁静',
#  '加油',
#  '期待',
#  '宁静',
#  '节目',
#  '宁静',
#  '张雨绮',
#  '钟丽缇',
#  '刘诗',
#  '粉丝',
#  'pick',
#  '静静子',
#  '绮绮子',
#  '喜欢',
#  '张雨绮',
#  '宁静',
#  '性格',
#  '看雨琪',
#  '静姐',
#  '梦辰',
#  '静姐',
#  '静姐',
#  '静姐',
#  '静静子',
#  '静姐',
#  '排面',
#  '静姐',
#  '静姐',
#  '静姐',
#  '宁静',
#  '姐冲',
#  '静静子',
#  '排面',
#  '静姐',
#  '气场',
#  '碾压',
#  '欢乐',
#  '源泉',
#  '静姐',
#  '静姐',
#  '静姐',
#  '排面',
#  '静姐',
#  '排面',
#  '宁静',
#  '哇哇',
#  '静姐',
#  '排名',
#  '静姐',
#  '加油',
#  '静姐',
#  '排面',
#  '静静子',
#  '宁静',
#  '姐姐',
#  '排面',
#  '满蒙',
#  '大美人',
#  '压群芳',
#  '冲冲',
#  '静姐',
#  '静姐',
#  '宁静',
#  '姐姐',
#  '静姐',
#  'slay',
#  '静姐',
#  'call',
#  '静姐',
#  '静姐',
#  '宁静',
#  '姐姐',
#  '位出',
#  '静姐',
#  '来看',
#  '吴昕',
#  '舞蹈',
#  '静姐',
#  '说话',
#  '静静子',
#  '位出',
#  '宁静',
#  '杀气',
#  '宁静',
#  '宁静',
#  '宁静',
#  '姐姐',
#  '我爱你',
#  '静姐',
#  '好帅',
#  '静静子',
#  '我来',
#  '静姐',
#  '静姐',
#  '排面',
#  '静姐',
#  '宁静',
#  '可爱',
#  '气场',
#  '完胜',
#  '静姐',
#  '静姐',
#  '冲冲',
#  '静姐',
#  '排面',
#  '静姐',
#  '排面',
#  '静姐',
#  '静姐',
#  '牌面',
#  '静静子',
#  '宁静',
#  '张雨绮',
#  '静姐',
#  '排面',
#  '静静子',
#  '静姐',
#  '排面',
#  '静姐',
#  '静姐',
#  '静姐',
#  '排面',
#  '妈呀',
#  '宁静',
#  '越来越',
#  '好看',
#  '不愧',
#  '静姐',
#  '静姐',
#  '霸气',
#  '来自',
#  '静姐',
#  '底气',
#  '静姐',
#  '加油',
#  '打电话',
#  '投票',
#  '出道',
#  '静姐',
#  '排面',
#  '宁静',
#  '姐姐',
#  '静姐',
#  '排面',
#  '静姐',
#  '豪横',
#  '静姐',
#  '霸气',
#  '可爱',
#  '静姐',
#  '排面',
#  '静姐',
#  '00',
#  '社会',
#  '静姐',
#  '静姐',
#  '静静子',
#  '静姐',
#  '静姐',
#  '静姐',
#  '可爱',
#  '静姐',
#  '排面',
#  '宁静',
#  '静姐',
#  '霸气',
#  'hiahiahia',
#  '静姐',
#  '走个',
#  '流程',
#  '喜欢',
#  '静姐',
#  '静姐',
#  '静姐',
#  '静姐',
#  'call',
#  '静姐',
#  '静姐',
#  '静姐',
#  '不准',
#  '淘汰',
#  '静姐',
#  '跟琦姐',
#  '静姐',
#  '我爱你',
#  '静姐',
#  '排面',
#  '静姐',
#  '人气',
#  'top',
#  '宁静',
#  'pike',
#  '静姐',
#  '张雨绮',
#  '钟丽缇',
#  '好好',
#  '宁静',
#  '姐姐',
#  '太酷',
#  '静静子',
#  '排面',
#  '静姐',
#  '位出',
#  '静静子',
#  '宁静',
#  '不出',
#  '所料',
#  '静姐',
#  '静姐',
#  '排面',
#  '我太爱',
#  '宁静',
#  '静姐',
#  '加油',
#  '加油',
#  '静姐',
#  '排面',
#  '静姐',
#  'slay',
#  '静姐',
#  '加油',
#  '静姐',
#  '位出',
#  '静姐',
#  '排面',
#  '我太爱',
#  '静姐',
#  '静姐',
#  '娱乐圈',
#  '静姐',
#  '预测',
#  '宁静',
#  '喜欢',
#  '静姐',
#  '不愧',
#  '静姐',
#  '几十年',
#  '白干',
#  '静姐',
#  '排面',
#  '排面',
#  '排面',
#  '静姐',
#  '气场',
#  '静姐',
#  '还要',
#  '介绍',
#  '静姐',
#  '霸气',
#  '静姐',
#  '排面',
#  '跟上',
#  '静姐',
#  '宁静',
#  '霸气',
#  '静姐',
#  '自信',
#  '好看',
#  '静姐',
#  'slay',
#  '全场',
#  '暂时',
#  '喜欢',
#  '静姐',
#  '昕姐',
#  '梦辰',
#  '静静子',
#  '霸气',
#  '静姐',
#  '静姐',
#  '好帅',
#  '静姐',
#  '打野',
#  '辅助',
#  '静姐',
#  '吊坠',
#  '静姐',
#  '静姐',
#  '宁静',
#  '好看',
#  '...',
#  '光脸',
#  '....',
#  '喜欢',
#  '静姐',
#  '喜欢',
#  '静姐',
#  '霸气',
#  '静姐',
#  '棒棒',
#  '静静子',
#  '排面',
#  '静姐',
#  '女王',
#  '静姐',
#  '排面',
#  '静姐',
#  '位出',
#  '静姐',
#  '我爱你',
#  '仔细听',
#  '静姐',
#  '背景音乐',
#  '宁静',
#  '出名',
#  '宁静',
#  '好飒',
#  '宁静',
#  '静姐',
#  '霸气',
#  '出场',
#  '静姐',
#  '代表作',
#  '花儿',
#  '少年',
#  '宁静',
#  '张雨绮',
#  '说话',
#  '气场',
#  '一米',
#  '静姐',
#  '妆容',
#  '好好看',
#  '静姐',
#  '静姐',
#  '这双大',
#  '眼睛',
#  '美到',
#  '逆天',
#  '排面',
#  '钟比',
#  '宁静',
#  '大几',
#  '竟然',
#  '静静子',
#  '位出',
#  '静姐',
#  '代表作',
#  '碾压',
#  '48',
#  '状态',
#  '无敌',
#  '静静子',
#  '辅助',
#  '静姐',
#  '静姐',
#  '照片',
#  '静姐',
#  '庄太后',
#  '叫好',
#  '宁静',
#  '简介',
#  '厉害',
#  '静姐',
#  '霸气',
#  '社会',
#  '静姐',
#  '介绍',
#  '代表作',
#  '只能',
#  '宁静',
#  '不止',
#  '宁静',
#  '唱歌',
#  '好听',
#  '宁静',
#  '50',
#  '宁静',
#  '宁静',
#  '48',
#  '好好看',
#  '两个',
#  '静静子',
#  '00',
#  '宁静',
#  '别人',
#  '绮姐',
#  '位出',
#  '静姐',
#  '伊能静',
#  '宁静',
#  '还要',
#  '哇塞',
#  '伊能静',
#  '好看',
#  '静姐',
#  '同岁',
#  '惊呆',
#  '宁静',
#  '看起来',
#  '年轻',
#  '是因为',
#  '骨头',
#  '长得',
#  '伊能静',
#  '姐姐',
#  '观点',
#  '特别',
#  '宁静',
#  '静姐',
#  '两位',
#  '静姐',
#  '碰面',
#  '只想',
#  '静静',
#  '两个',
#  '静姐',
#  '喜欢',
#  '两位',
#  '静姐',
#  '排面',
#  '静静子',
#  '绝美',
#  '宁静',
#  '姐姐',
#  '请选',
#  '黑色',
#  '宁静',
#  '眼角',
#  '静静地',
#  '转身',
#  '不愧',
#  '喜欢',
#  '宁静',
#  '静姐',
#  '气场',
#  '两米',
#  '宁静',
#  '那张',
#  '照片',
#  '好飒',
#  '两位',
#  '静姐',
#  '相遇',
#  '内味',
#  '张雨绮',
#  '宁静',
#  '钟丽缇',
#  '小姐姐',
#  '出道',
#  '我太爱',
#  '静姐',
#  '这款',
#  '大姐大',
#  '静姐',
#  '霸气',
#  '宁静',
#  '气场',
#  '宁静',
#  '好会',
#  '搭配',
#  '静姐',
#  '宁静',
#  'call',
#  '喜欢',
#  '宁静',
#  '宁静',
#  '霸道',
#  '总裁',
#  '不行',
#  '听到',
#  '宁静',
#  '声音',
#  '想到',
#  '大玉儿',
#  '伊能静',
#  '竟然',
#  '宁静',
#  '静静子',
#  '太帅',
#  '宁静',
#  '很瘦',
#  '静姐',
#  '别人',
#  '宁静',
#  '姐好',
#  '气场',
#  '两个',
#  '静姐',
#  '静姐',
#  '气场',
#  '两米',
#  '宁静',
#  '气场',
#  '好强',
#  '宁静',
#  '女王',
#  '气场',
#  '宁静',
#  '感觉',
#  '谢可寅',
#  '好像',
#  '两个',
#  '静姐',
#  '厉害',
#  '宁静',
#  '宁静',
#  '气场',
#  '宁静',
#  '长得',
#  '太凶了',
#  '两位',
#  '静姐',
#  '宁静',
#  '伊能静',
#  '聊天',
#  '画风',
#  '同事',
#  '家常',
#  '聊天',
#  '互吹',
#  '伊能静',
#  '宁静',
#  '伊能静',
#  '运动',
#  '静静子',
#  '客套话',
#  '优秀',
#  '宁静',
#  '气场',
#  '静姐',
#  '干嘛',
#  '口红',
#  '静姐',
#  '好会',
#  '伊能静',
#  '保养',
#  '好好',
#  '宁静',
#  '势力',
#  '说话',
#  '静姐',
#  '受不了',
#  '不想',
#  '想起',
#  '花少',
#  '采访',
#  '宁静',
#  '老娘',
#  '终于',
#  '松口气',
#  '宁静',
#  '算是',
#  '摆老资',
#  '我充',
#  '会员',
#  '节目',
#  '冲着',
#  '宁静',
#  '张雨绮',
#  '不愧',
#  '静姐',
#  '静姐',
#  '太好',
#  '宁静',
#  '保养',
#  '太好了',
#  '静姐',
#  '好帅',
#  '宁静',
#  '简直',
#  '一大',
#  '看点',
#  '一半',
#  '看点',
#  '宁静',
#  '静姐',
#  '宁静',
#  ...]

# %%
stylecloud.gen_stylecloud(text=' '.join(text2), 
                          collocations=False,
                          font_path=r'‪C:\Windows\Fonts\msyh.ttc',
                          icon_name='fas fa-guitar',
                          size=653,
                          output_name='./可视化/芒果TV弹幕词云-宁静.png')
Image(filename='./可视化/芒果TV弹幕词云-宁静.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-8ea06fc9b021> in <module>
# ----> 1 stylecloud.gen_stylecloud(text=' '.join(text2),
#       2                           collocations=False,
#       3                           font_path=r'‪C:\Windows\Fonts\msyh.ttc',
#       4                           icon_name='fas fa-guitar',
#       5                           size=653,
#
# NameError: name 'stylecloud' is not defined

# %%
from wordcloud import WordCloud, ImageColorGenerator
import imageio
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
mk = imageio.imread('/Users/nika/Desktop/wx-removebg-preview.png')
wordcloud = WordCloud(background_color='white',
                      #设置字体为中文字体！！！
                      font_path="/Library/Fonts/Songti.ttc",
                      #设置清晰度
                      scale=15,
                      mode='RGBA',
                      mask=mk).generate(' '.join(text2))
image_colors = ImageColorGenerator(mk)
#将图片颜色应用到词云中
wc_color = wordcloud.recolor(color_func=image_colors)
wc_color.to_file('宁静2.png')
plt.imshow(wc_color)

# %%
plt.imshow(mk)

# %%
names_countall=[]

for name in my_words_list:
    # 筛选
    dff_sel = dff[dff.content.str.contains(name)]
    # 弹幕/点赞数
    names_count = dff_sel.shape[0]
    dff['flag']=name
    # 追加
    names_countall.append(names_count)

# %%
dff
# Out:
#         Unnamed: 0    stype                   id uname            content  \
# 0                0  8337559  6837425357961884672  听姐姐的             昕姐冲！！！
# 1                1  8337559  6837994106122528768   NaN              在看一次！
# 2                2  8337559  6838116886352934912   NaN  为黄圣依，张雨绮，郑希怡打call
# 3                3  8337559  6837307130396596224   NaN       姐姐们 我来了~~！！！
# 4                4  8337559  6837758462741384192   NaN     我去，真的爱了，都是我喜欢的
# ...            ...      ...                  ...   ...                ...
# 131721      131721  8437644  6841105139917549568   NaN               再来一瓶
# 131722      131722  8437644  6841094192045898752   NaN              嘴急着还吗
# 131723      131723  8437644  6841052977539672064   NaN        春春这歌好听，太洗脑了
# 131724      131724  8437644  6841096803386017792   NaN       各位更细新时间是怎么样的
# 131725      131725  8437644  6841038847097243648   NaN         各位集美，明天中午见
#
#            time  v2_up_count flag
# 0             0         24.0   王智
# 1             0          NaN   王智
# 2             0         10.0   王智
# 3             0         21.0   王智
# 4             0         13.0   王智
# ...         ...          ...  ...
# 131721  2053464          NaN   王智
# 131722  2053879          NaN   王智
# 131723  2053000          NaN   王智
# 131724  2054232          NaN   王智
# 131725  2054533          NaN   王智
#
# [131726 rows x 8 columns]

# %%
dff
# Out:
#         Unnamed: 0    stype                   id uname            content  \
# 0                0  8337559  6837425357961884672  听姐姐的             昕姐冲！！！
# 1                1  8337559  6837994106122528768   NaN              在看一次！
# 2                2  8337559  6838116886352934912   NaN  为黄圣依，张雨绮，郑希怡打call
# 3                3  8337559  6837307130396596224   NaN       姐姐们 我来了~~！！！
# 4                4  8337559  6837758462741384192   NaN     我去，真的爱了，都是我喜欢的
# ...            ...      ...                  ...   ...                ...
# 131721      131721  8437644  6841105139917549568   NaN               再来一瓶
# 131722      131722  8437644  6841094192045898752   NaN              嘴急着还吗
# 131723      131723  8437644  6841052977539672064   NaN        春春这歌好听，太洗脑了
# 131724      131724  8437644  6841096803386017792   NaN       各位更细新时间是怎么样的
# 131725      131725  8437644  6841038847097243648   NaN         各位集美，明天中午见
#
#            time  v2_up_count
# 0             0         24.0
# 1             0          NaN
# 2             0         10.0
# 3             0         21.0
# 4             0         13.0
# ...         ...          ...
# 131721  2053464          NaN
# 131722  2053879          NaN
# 131723  2053000          NaN
# 131724  2054232          NaN
# 131725  2054533          NaN
#
# [131726 rows x 7 columns]

# %%
names_countall=[]

if name == '宁静':
    # 筛选
    dff_sel = dff[dff.content.str.contains(name)]
    # 弹幕/点赞数
    names_count = dff_sel.content
    # 追加
    names_countall.append(names_count)

# %%
names_countall[0]
# Out:
# ['宁静',
#  ' ',
#  ' ',
#  '宁静',
#  ' ',
#  ' ',
#  '宁静',
#  ' ',
#  ' ',
#  '为',
#  '您',
#  '打',
#  'call',
#  ' ',
#  ' ',
#  '。',
#  '宁静',
#  '宁静',
#  '！',
#  '。',
#  '来看',
#  '宁静',
#  '了',
#  ' ',
#  '哈哈',
#  '。',
#  '宁静',
#  '宁静',
#  '！',
#  '！',
#  '！',
#  '！',
#  '？',
#  '！',
#  '！',
#  '！',
#  '。',
#  '喜欢',
#  '李斯',
#  '丹妮',
#  '跟',
#  '含韵',
#  '，',
#  '丁当',
#  '，',
#  '宁静',
#  '，',
#  '。',
#  '吴昕',
#  ' ',
#  ' ',
#  '金晨',
#  ' ',
#  ' ',
#  ' ',
#  '宁静',
#  ' ',
#  ' ',
#  ' ',
#  '张雨绮',
#  '出道',
#  '吧',
#  '。',
#  '我来',
#  '了',
#  '我',
#  '来',
#  '了',
#  '宁静',
#  '姐',
#  '加油',
#  '张雨绮',
#  '加油',
#  '吴昕',
#  '加油',
#  '。',
#  '宁静',
#  '姐姐',
#  '！',
#  '！',
#  '！',
#  '（',
#  '尖叫',
#  '！',
#  '）',
#  '。',
#  '爱',
#  '宁静',
#  '，',
#  '爱',
#  '金晨',
#  '。',
#  '张雨绮',
#  '，',
#  '宁静',
#  '冲',
#  '啊啊啊',
#  '啊',
#  '。',
#  '宁静',
#  '大姐大',
#  ' ',
#  ' ',
#  ' ',
#  '最',
#  '爱',
#  '。',
#  '静姐',
#  '~',
#  '宁静',
#  '~',
#  '。',
#  '宁静',
#  '冲',
#  '呀',
#  '！',
#  '！',
#  '！',
#  '。',
#  '宁静',
#  '姐姐',
#  '冲冲',
#  '啊',
#  '冲冲',
#  '冲',
#  '。',
#  '在',
#  '抖音',
#  '一直',
#  '刷到',
#  '宁静',
#  '姐姐',
#  '哈哈',
#  '来',
#  '看看',
#  '。',
#  '宁静',
#  '真的',
#  '很漂亮',
#  '，',
#  '超',
#  '美丽',
#  '，',
#  '很',
#  '有',
#  '魅力',
#  '，',
#  '很',
#  '有',
#  '个性',
#  '。',
#  '宁静',
#  ' ',
#  '冲',
#  '。',
#  '宁静',
#  '我来',
#  '了',
#  '！',
#  '静静子',
#  '冲',
#  '鸭',
#  '。',
#  '昕姐',
#  '宁静',
#  '姐',
#  '加油',
#  '！',
#  '。',
#  '万茜',
#  '！',
#  '宁静',
#  '！',
#  '张雨绮',
#  '！',
#  '。',
#  '姐姐',
#  '们',
#  '我',
#  '来',
#  '了',
#  '…',
#  '…',
#  '宁静',
#  '姐',
#  '我',
#  '来',
#  '了',
#  '啊啊啊',
#  '啊',
#  '。',
#  '宁静',
#  '！',
#  '！',
#  '！',
#  '静姐',
#  '！',
#  '。',
#  '万茜',
#  ' ',
#  '张雨绮',
#  ' ',
#  '宁静',
#  ' ',
#  '冲',
#  '啊',
#  '！',
#  '。',
#  '宁静',
#  '姐冲',
#  '啊',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '。',
#  '宁静',
#  '冲',
#  '鸭',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '。',
#  '万茜',
#  '!',
#  '蓝盈莹',
#  '!',
#  '宁静',
#  '!',
#  '张雨绮',
#  '!',
#  '冲冲',
#  '冲',
#  '!',
#  '。',
#  '为了',
#  '宁静',
#  '来',
#  '的',
#  '！',
#  '！',
#  '！',
#  '冲',
#  '。',
#  '为了',
#  '宁静',
#  ' ',
#  '期待',
#  '宁静',
#  '。',
#  '宁静',
#  '给',
#  '我',
#  '冲',
#  'aaaaaaaa',
#  ' ',
#  ' ',
#  ' ',
#  '出道',
#  '出道',
#  ' ',
#  '。',
#  '宁静',
#  '耳环',
#  '好好看',
#  '。',
#  '啊啊啊',
#  '啊',
#  '我',
#  '是',
#  '宁静',
#  '的',
#  '粉头',
#  '哦哦哦',
#  '静姐',
#  '冲',
#  '鸭',
#  '。',
#  '宁静',
#  '给',
#  '我',
#  '使劲',
#  '冲',
#  '，',
#  '你',
#  '要',
#  '努力',
#  '啊',
#  '宁静',
#  '。',
#  '宁静',
#  '姐',
#  '加油',
#  '。',
#  '第一期',
#  '，',
#  '留个',
#  '名',
#  ',',
#  '喜欢',
#  '宁静',
#  '。',
#  ' ',
#  '张雨绮',
#  '宁静',
#  '给',
#  '我',
#  '高位',
#  '出',
#  '道',
#  '。',
#  '宁静',
#  '！',
#  '冲冲',
#  '冲',
#  '。',
#  '宁静',
#  '越来越',
#  '年轻',
#  '了',
#  '。',
#  '宁静',
#  '万茜',
#  '出道',
#  '。',
#  '我',
#  '喜欢',
#  '宁静',
#  '，',
#  '她',
#  '就是',
#  '乘风破浪',
#  '的',
#  '人',
#  '。',
#  '宁静',
#  '比',
#  '偶像',
#  '来',
#  '了',
#  '的',
#  '时候',
#  '瘦',
#  '好多',
#  '，',
#  '，',
#  '，',
#  '。',
#  '宁静',
#  ' ',
#  '张雨绮',
#  '。',
#  '宁静',
#  '最美',
#  '。',
#  '宁静',
#  '冲',
#  '！',
#  '。',
#  '宁静',
#  '姐',
#  '冲冲',
#  '冲',
#  '！',
#  '！',
#  '。',
#  '真的',
#  '很',
#  '喜欢',
#  '宁静',
#  '，',
#  '虽然',
#  '很',
#  '直接',
#  '但是',
#  '真实',
#  '。',
#  '宁静',
#  '姐姐',
#  '。',
#  '宁静',
#  '太',
#  '好看',
#  '了',
#  '！',
#  '！',
#  '！',
#  '。',
#  '张雨绮',
#  ' ',
#  '宁静',
#  ' ',
#  ' ',
#  '加油',
#  '。',
#  '宁静',
#  '很',
#  '嚣张',
#  '，',
#  '但',
#  '我',
#  '就是',
#  '很',
#  '喜欢',
#  '，',
#  '怎么回事',
#  '啊',
#  '。',
#  '我',
#  '觉得',
#  '宁静',
#  '虽然',
#  '脾气',
#  '爆',
#  '但是',
#  '礼貌',
#  '，',
#  '跟',
#  '张雨绮',
#  '是',
#  '两个',
#  '概念',
#  '。',
#  '我',
#  '可',
#  '太',
#  '喜欢',
#  '宁静',
#  '和',
#  '张雨绮',
#  '了',
#  '。',
#  '宁静',
#  '！',
#  'c',
#  '位出',
#  '道',
#  '！',
#  '！',
#  '。',
#  '宁静',
#  '啊啊啊',
#  '啊',
#  '。',
#  '宁静',
#  '真的',
#  '太太',
#  '太太',
#  '太美',
#  '啦',
#  '!',
#  '!',
#  ' ',
#  ' ',
#  '啊啊啊',
#  '啊',
#  '冲',
#  '啊',
#  '静姐',
#  '。',
#  '宁静',
#  '姐姐',
#  '冲',
#  '啊',
#  '。',
#  '宁静',
#  '都',
#  '感觉',
#  '不老',
#  '的',
#  '吗',
#  '。',
#  '宁静',
#  '万茜',
#  '小姐姐',
#  '。',
#  '我会',
#  '一直',
#  '看到',
#  '你',
#  '的',
#  '宁静',
#  '。',
#  '宁静',
#  '姐',
#  '，',
#  '哈哈哈',
#  '哈哈哈',
#  '(',
#  'ಡ',
#  'ω',
#  'ಡ',
#  ')',
#  'hiahiahia',
#  '，',
#  '。',
#  '宁静',
#  '的',
#  '耳钉',
#  '好',
#  '个性',
#  '。',
#  '哈哈哈',
#  '宁静',
#  '好',
#  '有',
#  '想法',
#  '。',
#  '宁静',
#  '这个',
#  '好像',
#  '耳返',
#  '。',
#  '宁静',
#  '美绝',
#  '了',
#  '。',
#  '就',
#  '喜欢',
#  '宁静',
#  '的',
#  '敢',
#  '说',
#  '。',
#  '哈哈哈哈',
#  '宁静',
#  '是',
#  '真敢',
#  '啊',
#  '。',
#  '宁静',
#  '冲',
#  '啊',
#  ' ',
#  '姐姐',
#  '出道',
#  '了',
#  ' ',
#  '。',
#  '姐姐',
#  '们',
#  '冲',
#  '啊',
#  '冲',
#  '啊',
#  '宁静',
#  '冲',
#  '啊',
#  '！',
#  '！',
#  '！',
#  '！',
#  '。',
#  '宁静',
#  '姐',
#  '别说',
#  '了',
#  '，',
#  '真相',
#  '了',
#  '。',
#  '张雨绮',
#  '万茜',
#  '吴昕',
#  '宁静',
#  '加油',
#  '。',
#  '宁静',
#  '姐姐',
#  '冲',
#  '。',
#  '张雨绮',
#  '，',
#  '宁静',
#  '出道',
#  '吧',
#  '，',
#  '太宣',
#  '你',
#  '俩',
#  '了',
#  '。',
#  '有',
#  'pick',
#  '万茜',
#  '和',
#  '宁静',
#  '的',
#  '吗',
#  '。',
#  '哈哈哈哈',
#  '哈哈哈',
#  '哈哈哈',
#  '张雨绮',
#  '和',
#  '宁静',
#  '我',
#  '好',
#  '期待',
#  '。',
#  '暴风雨',
#  '前',
#  '的',
#  '宁静',
#  '，',
#  '我来',
#  '了',
#  '。',
#  '就是',
#  '来看',
#  '宁静',
#  '张雨绮',
#  '的',
#  '。',
#  '宁静',
#  '给',
#  '我',
#  'C',
#  '位',
#  ' ',
#  '最',
#  '不',
#  '一样',
#  '的',
#  '就是',
#  '你',
#  '。',
#  '静静子',
#  'C',
#  '位出',
#  '道',
#  '！',
#  '宁静',
#  '冲',
#  '鸭',
#  '。',
#  '宁静',
#  '冲冲',
#  '冲',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '。',
#  '我',
#  '喜欢',
#  '的',
#  '第一',
#  '宁静',
#  ' ',
#  '第二',
#  '张雨绮',
#  '。',
#  '宁静',
#  '冲',
#  '啊啊啊',
#  '啊啊啊',
#  '啊',
#  '啊',
#  '。',
#  '宁静',
#  '节',
#  '加油',
#  '。',
#  '宁静',
#  '万茜冲',
#  '鸭',
#  '。',
#  '宁静',
#  '给爷',
#  '冲',
#  '！',
#  '金晨',
#  '给爷',
#  '冲',
#  '！',
#  '雨绮',
#  '姐姐',
#  '给爷',
#  '冲',
#  '！',
#  '。',
#  '宁静',
#  '冲',
#  '。',
#  '宁静',
#  '姐姐',
#  '，',
#  'c',
#  '位出',
#  '道',
#  '！',
#  '。',
#  '宁静',
#  '静静子',
#  '！',
#  '琦琦子',
#  '！',
#  '小花',
#  '！',
#  '昕昕子',
#  '！',
#  '1',
#  '茜茜子',
#  '！',
#  '给',
#  '我',
#  '冲',
#  '鸭',
#  '！',
#  '！',
#  '。',
#  '黄圣依',
#  '万茜',
#  '宁静',
#  '张雨绮',
#  '伊能静',
#  '蓝盈莹',
#  '沈',
#  '梦辰',
#  '黄龄',
#  '孟佳',
#  '王',
#  '丽坤',
#  '吴昕',
#  '钟丽缇',
#  '金莎',
#  '白冰',
#  '金晨',
#  '刘芸',
#  '。',
#  '钟丽缇',
#  '和',
#  '宁静',
#  '最美',
#  '最',
#  '霸气',
#  '长得',
#  '。',
#  '好',
#  '喜欢',
#  '钟丽缇',
#  '和',
#  '宁静',
#  '。',
#  '我们',
#  '是',
#  '来看',
#  '宁静',
#  '的',
#  '。',
#  '我',
#  '一个',
#  '大爷',
#  '们',
#  ' ',
#  '抖音',
#  '上',
#  '来看',
#  '宁静',
#  '姐',
#  '的',
#  '。',
#  '宁静',
#  '是不是',
#  '要',
#  '压轴',
#  '出场',
#  '哈哈哈',
#  '哈哈哈',
#  '哈哈哈',
#  '。',
#  '万茜',
#  '加油',
#  '，',
#  '宁静',
#  '加油',
#  '。',
#  '还',
#  '在',
#  '期待',
#  '宁静',
#  '哈哈哈哈',
#  '。',
#  '这个',
#  '节目',
#  '多少',
#  '人',
#  '是',
#  '奔',
#  '着',
#  '宁静',
#  '，',
#  '张雨绮',
#  '，',
#  '钟丽缇',
#  '来',
#  '的',
#  '。',
#  '我',
#  '好',
#  '喜欢',
#  '张雨绮',
#  '和',
#  '宁静',
#  '的',
#  '性格',
#  '哈哈哈哈',
#  '。',
#  '宁静',
#  '姐冲',
#  '啊',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '。',
#  '静姐',
#  '！',
#  '！',
#  '！',
#  '！',
#  '排面',
#  '啊啊啊',
#  '宁静',
#  '。',
#  '给',
#  '宁静',
#  '姐姐',
#  '排面',
#  '！',
#  '！',
#  '满蒙',
#  '第一',
#  '大美人',
#  '！',
#  '！',
#  '！',
#  '！',
#  '艳',
#  '压群芳',
#  '冲冲',
#  '冲',
#  '！',
#  '！',
#  '！',
#  '。',
#  '宁静',
#  '姐姐',
#  '！',
#  '！',
#  '！',
#  '。',
#  '啊啊啊',
#  '啊啊啊',
#  '宁静',
#  '！',
#  '！',
#  '！',
#  '！',
#  '我',
#  '好',
#  '爱',
#  '！',
#  '！',
#  '！',
#  '姐姐',
#  'c',
#  '位出',
#  '道',
#  '！',
#  '！',
#  '！',
#  '。',
#  '哈哈哈',
#  '哈哈',
#  ' ',
#  '宁静',
#  '一',
#  '出来',
#  '就',
#  '有',
#  '杀气',
#  '。',
#  '宁静',
#  '宁静',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '！',
#  '。',
#  '宁静',
#  '姐姐',
#  '我爱你',
#  '。',
#  '宁静',
#  '大',
#  '可爱',
#  '来',
#  '了',
#  ' ',
#  '哈哈哈',
#  '哈哈哈',
#  ' ',
#  '气场',
#  '完胜',
#  '。',
#  '宁静',
#  '和',
#  '张雨绮',
#  '哇',
#  '哦',
#  '😯',
#  '。',
#  '妈呀',
#  '宁静',
#  '怎么',
#  '越来越',
#  '好看',
#  '啊',
#  '。',
#  '哈哈哈哈',
#  '，',
#  '我',
#  '爱',
#  '死',
#  '你',
#  '了',
#  '宁静',
#  '姐姐',
#  '。',
#  '快',
#  '给',
#  '静姐',
#  '排面',
#  '！',
#  '！',
#  '！',
#  '。',
#  '我',
#  '爱',
#  '宁静',
#  '啊啊啊',
#  '啊啊啊',
#  '。',
#  '宁静',
#  '哈哈哈哈',
#  '哈哈哈哈',
#  '。',
#  '宁静',
#  '姐姐',
#  '你',
#  '太酷',
#  '了',
#  '吧',
#  '。',
#  '宁静',
#  '果然',
#  '笑',
#  '死',
#  '我',
#  '不出',
#  '我',
#  '所料',
#  '。',
#  '啊',
#  '啊啊啊',
#  '啊啊啊',
#  '我太爱',
#  '宁静',
#  '了',
#  '。',
#  '预测',
#  ...]

# %%
    stop_words = [] 
    
    with open(r"/Users/nika/Desktop/chineseStopWords.txt") as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())

    my_stop_words = ['第一期', '一堆', '三个', '真的', '哈哈哈', '哈哈哈哈', '啊啊啊']    
    stop_words.extend(my_stop_words)

# %%
stop_words
# Out:
# ['?',
#  '、',
#  '。',
#  '“',
#  '”',
#  '《',
#  '》',
#  '!',
#  '！',
#  '，',
#  ',',
#  '：',
#  ':',
#  '；',
#  '？',
#  '-',
#  '(',
#  ')',
#  '（',
#  '）',
#  '·',
#  '--',
#  '⋯⋯',
#  '/',
#  '.',
#  '|',
#  '——',
#  '‘',
#  '’',
#  '□',
#  '【',
#  '】',
#  'A',
#  'B',
#  'C',
#  'D',
#  '啊',
#  '阿',
#  '哎',
#  '哎呀',
#  '哎哟',
#  '唉',
#  '俺',
#  '俺们',
#  '按',
#  '按照',
#  '吧',
#  '吧哒',
#  '把',
#  '罢了',
#  '被',
#  '本',
#  '本着',
#  '比',
#  '比方',
#  '比如',
#  '鄙人',
#  '彼',
#  '彼此',
#  '边',
#  '别',
#  '别的',
#  '别说',
#  '并',
#  '并且',
#  '不比',
#  '不成',
#  '不单',
#  '不但',
#  '不独',
#  '不管',
#  '不光',
#  '不过',
#  '不仅',
#  '不拘',
#  '不论',
#  '不怕',
#  '不然',
#  '不如',
#  '不特',
#  '不惟',
#  '不问',
#  '不只',
#  '朝',
#  '朝着',
#  '趁',
#  '趁着',
#  '乘',
#  '冲',
#  '除',
#  '除此之外',
#  '除非',
#  '除了',
#  '此',
#  '此间',
#  '此外',
#  '从',
#  '从而',
#  '出',
#  '打',
#  '待',
#  '但',
#  '但是',
#  '当',
#  '当着',
#  '到',
#  '得',
#  '的',
#  '的话',
#  '等',
#  '等等',
#  '地',
#  '第',
#  '叮咚',
#  '对',
#  '对于',
#  '多',
#  '多少',
#  '而',
#  '而况',
#  '而且',
#  '而是',
#  '而外',
#  '而言',
#  '而已',
#  '尔后',
#  '反过来',
#  '反过来说',
#  '反之',
#  '非但',
#  '非徒',
#  '否则',
#  '嘎',
#  '嘎登',
#  '刚',
#  '刚刚',
#  '该',
#  '赶',
#  '个',
#  '各',
#  '各个',
#  '各位',
#  '各种',
#  '各自',
#  '给',
#  '根据',
#  '跟',
#  '故',
#  '故此',
#  '固然',
#  '关于',
#  '管',
#  '归',
#  '果然',
#  '果真',
#  '过',
#  '哈',
#  '哈哈',
#  '呵',
#  '和',
#  '何',
#  '何处',
#  '何况',
#  '何时',
#  '嘿',
#  '哼',
#  '哼唷',
#  '呼哧',
#  '乎',
#  '哗',
#  '还是',
#  '还有',
#  '换句话说',
#  '换言之',
#  '或',
#  '或是',
#  '或者',
#  '极了',
#  '及',
#  '及其',
#  '及至',
#  '即',
#  '即便',
#  '即或',
#  '即令',
#  '即若',
#  '即使',
#  '几',
#  '几时',
#  '己',
#  '既',
#  '既然',
#  '既是',
#  '继而',
#  '加之',
#  '假如',
#  '假若',
#  '假使',
#  '鉴于',
#  '将',
#  '较',
#  '较之',
#  '叫',
#  '接着',
#  '结果',
#  '借',
#  '紧接着',
#  '进而',
#  '尽',
#  '尽管',
#  '经',
#  '经过',
#  '就',
#  '就是',
#  '就是说',
#  '据',
#  '具体地说',
#  '具体说来',
#  '开始',
#  '开外',
#  '靠',
#  '咳',
#  '可',
#  '可见',
#  '可是',
#  '可以',
#  '况且',
#  '啦',
#  '来',
#  '来着',
#  '离',
#  '例如',
#  '哩',
#  '连',
#  '连同',
#  '两者',
#  '了',
#  '临',
#  '另',
#  '另外',
#  '另一方面',
#  '论',
#  '嘛',
#  '吗',
#  '慢说',
#  '漫说',
#  '冒',
#  '么',
#  '每',
#  '每当',
#  '们',
#  '莫若',
#  '某',
#  '某个',
#  '某些',
#  '拿',
#  '哪',
#  '哪边',
#  '哪儿',
#  '哪个',
#  '哪里',
#  '哪年',
#  '哪怕',
#  '哪天',
#  '哪些',
#  '哪样',
#  '那',
#  '那边',
#  '那儿',
#  '那个',
#  '那会儿',
#  '那里',
#  '那么',
#  '那么些',
#  '那么样',
#  '那时',
#  '那些',
#  '那样',
#  '乃',
#  '乃至',
#  '呢',
#  '能',
#  '你',
#  '你们',
#  '您',
#  '宁',
#  '宁可',
#  '宁肯',
#  '宁愿',
#  '哦',
#  '呕',
#  '啪达',
#  '旁人',
#  '呸',
#  '凭',
#  '凭借',
#  '其',
#  '其次',
#  '其二',
#  '其他',
#  '其它',
#  '其一',
#  '其余',
#  '其中',
#  '却',
#  '去',
#  '起',
#  '起见',
#  '起见',
#  '岂但',
#  '恰恰相反',
#  '前后',
#  '前者',
#  '且',
#  '然而',
#  '然后',
#  '然则',
#  '让',
#  '人家',
#  '任',
#  '任何',
#  '任凭',
#  '如',
#  '如此',
#  '如果',
#  '如何',
#  '如其',
#  '如若',
#  '如上所述',
#  '若',
#  '若非',
#  '若是',
#  '啥',
#  '上下',
#  '尚且',
#  '设若',
#  '设使',
#  '甚而',
#  '甚么',
#  '甚至',
#  '省得',
#  '时候',
#  '十分',
#  '什么',
#  '什么样',
#  '使得',
#  '是',
#  '是的',
#  '首先',
#  '谁',
#  '谁知',
#  '顺',
#  '顺着',
#  '似的',
#  '虽',
#  '虽然',
#  '虽说',
#  '虽则',
#  '随',
#  '随着',
#  '所',
#  '所以',
#  '他',
#  '他们',
#  '他人',
#  '它',
#  '它们',
#  '她',
#  '她们',
#  '倘',
#  '倘或',
#  '倘然',
#  '倘若',
#  '倘使',
#  '腾',
#  '替',
#  '通过',
#  '同',
#  '同时',
#  '哇',
#  '万一',
#  '往',
#  '望',
#  '为',
#  '为何',
#  '为了',
#  '为什么',
#  '为着',
#  '喂',
#  '嗡嗡',
#  '我',
#  '我们',
#  '呜',
#  '呜呼',
#  '乌乎',
#  '无论',
#  '无宁',
#  '毋宁',
#  '嘻',
#  '吓',
#  '相对而言',
#  '像',
#  '向',
#  '向着',
#  '嘘',
#  '呀',
#  '焉',
#  '沿',
#  '沿着',
#  '要',
#  '要不',
#  '要不然',
#  '要不是',
#  '要么',
#  '要是',
#  '也',
#  '也罢',
#  '也好',
#  '一一',
#  '———',
#  '一般',
#  '一边',
#  '一会儿',
#  '一旦',
#  '一定',
#  '一点点',
#  '一方面',
#  '一面',
#  '一来',
#  '一起',
#  '一切',
#  '一下',
#  '一下子',
#  '一样',
#  '一些',
#  '一则',
#  '一直',
#  '依',
#  '依照',
#  '矣',
#  '以',
#  '以便',
#  '以及',
#  '以免',
#  '以至',
#  '以至于',
#  '以致',
#  '抑或',
#  '因',
#  '因此',
#  '因而',
#  '因为',
#  '哟',
#  '用',
#  '由',
#  '由此可见',
#  '由于',
#  '有',
#  '有的',
#  '有关',
#  '有些',
#  '又',
#  '于',
#  '于是',
#  '于是乎',
#  '与',
#  '与此同时',
#  '与否',
#  '与其',
#  '越是',
#  '云云',
#  '哉',
#  '再说',
#  '再者',
#  '在',
#  '在下',
#  '咱',
#  '咱们',
#  '则',
#  '怎',
#  '怎么',
#  '怎么办',
#  '怎么样',
#  '怎样',
#  '咋',
#  '照',
#  '照着',
#  '者',
#  '这',
#  '这边',
#  '这儿',
#  '这个',
#  '这会儿',
#  '这就是说',
#  '这里',
#  '这么',
#  '这么点儿',
#  '这么些',
#  '这么样',
#  '这时',
#  '这些',
#  '这样',
#  '正如',
#  '吱',
#  '之',
#  '之类',
#  '之所以',
#  '之一',
#  '只是',
#  '只限',
#  '只要',
#  '只有',
#  '至',
#  '至于',
#  '诸位',
#  '着',
#  '着呢',
#  '自',
#  '自从',
#  '自个儿',
#  '自各儿',
#  '自己',
#  '自家',
#  '自身',
#  '综上所述',
#  '总的来看',
#  '总的来说',
#  '总的说来',
#  '总而言之',
#  '总之',
#  '纵',
#  '纵令',
#  '纵然',
#  '纵使',
#  '遵照',
#  '作为',
#  '兮',
#  '呃',
#  '呗',
#  '咚',
#  '咦',
#  '喏',
#  '啐',
#  '喔唷',
#  '嗬',
#  '嗯',
#  '嗳',
#  '上',
#  '下',
#  '不',
#  '不再',
#  '不同',
#  '不少',
#  '一',
#  '二',
#  '两',
#  '三',
#  '四',
#  '五',
#  '六',
#  '七',
#  '八',
#  '九',
#  '十',
#  '个人',
#  '中',
#  '之前',
#  '之后',
#  '之外',
#  '之间',
#  '也许',
#  '人',
#  '前',
#  '前天',
#  '今天',
#  '今年',
#  '明天',
#  '明年',
#  '后天',
#  '去年',
#  '从来',
#  '令',
#  '以下',
#  '以前',
#  '以后',
#  '以往',
#  '以来',
#  '份',
#  '件',
#  '伏',
#  '众',
#  '众多',
#  '会',
#  '位',
#  '做',
#  '停',
#  '顶',
#  '先',
#  '先前',
#  '全',
#  '公司',
#  '公斤',
#  '其实',
#  '内',
#  '已',
#  '再',
#  '小',
#  '大',
#  '还',
#  '里',
#  '都',
#  '部',
#  '遍',
#  '道',
#  '说',
#  '第一',
#  '第二',
#  '第三',
#  '第四',
#  '第五',
#  '第六',
#  '第七',
#  '第八',
#  '第九',
#  '第十',
#  '只',
#  '后',
#  '太',
#  '大家',
#  '女',
#  '男',
#  '看',
#  '新浪',
#  '年',
#  '很',
#  '才',
#  '时',
#  '更',
#  '最',
#  '本报',
#  '讯',
#  '记者',
#  '演',
#  '片',
#  '一',
#  '一下',
#  '一些',
#  '一切',
#  '一则',
#  '一天',
#  '一定',
#  '一方面',
#  '一旦',
#  '一时',
#  '一来',
#  '一样',
#  '一次',
#  '一片',
#  '一直',
#  '一致',
#  '一般',
#  '一起',
#  '一边',
#  '一面',
#  '万一',
#  '上下',
#  '上升',
#  '上去',
#  '上来',
#  '上述',
#  '上面',
#  '下列',
#  '下去',
#  '下来',
#  '下面',
#  '不一',
#  '不久',
#  '不仅',
#  '不会',
#  '不但',
#  '不光',
#  '不单',
#  '不变',
#  '不只',
#  '不可',
#  '不同',
#  '不够',
#  '不如',
#  '不得',
#  '不怕',
#  '不惟',
#  '不成',
#  '不拘',
#  '不敢',
#  '不断',
#  '不是',
#  '不比',
#  '不然',
#  '不特',
#  '不独',
#  '不管',
#  '不能',
#  '不要',
#  '不论',
#  '不足',
#  '不过',
#  '不问',
#  '与',
#  '与其',
#  '与否',
#  '与此同时',
#  '专门',
#  '且',
#  '两者',
#  '严格',
#  '严重',
#  '个',
#  '个人',
#  '个别',
#  '中小',
#  '中间',
#  '丰富',
#  '临',
#  '为',
#  '为主',
#  '为了',
#  '为什么',
#  '为什麽',
#  '为何',
#  '为着',
#  '主张',
#  '主要',
#  '举行',
#  '乃',
#  '乃至',
#  '么',
#  '之',
#  '之一',
#  '之前',
#  '之后',
#  '之後',
#  '之所以',
#  '之类',
#  '乌乎',
#  '乎',
#  '乘',
#  '也',
#  '也好',
#  '也是',
#  '也罢',
#  '了',
#  '了解',
#  '争取',
#  '于',
#  '于是',
#  '于是乎',
#  '云云',
#  '互相',
#  '产生',
#  '人们',
#  '人家',
#  '什么',
#  '什么样',
#  '什麽',
#  '今后',
#  '今天',
#  '今年',
#  '今後',
#  '仍然',
#  '从',
#  '从事',
#  '从而',
#  '他',
#  '他人',
#  '他们',
#  '他的',
#  '代替',
#  '以',
#  '以上',
#  '以下',
#  '以为',
#  '以便',
#  '以免',
#  '以前',
#  '以及',
#  '以后',
#  '以外',
#  '以後',
#  '以来',
#  '以至',
#  '以至于',
#  '以致',
#  '们',
#  '任',
#  '任何',
#  '任凭',
#  '任务',
#  '企图',
#  '伟大',
#  '似乎',
#  '似的',
#  '但',
#  '但是',
#  '何',
#  '何况',
#  '何处',
#  '何时',
#  '作为',
#  '你',
#  '你们',
#  '你的',
#  '使得',
#  '使用',
#  '例如',
#  '依',
#  '依照',
#  '依靠',
#  '促进',
#  '保持',
#  '俺',
#  '俺们',
#  '倘',
#  '倘使',
#  '倘或',
#  '倘然',
#  '倘若',
#  '假使',
#  '假如',
#  '假若',
#  '做到',
#  '像',
#  '允许',
#  '充分',
#  '先后',
#  '先後',
#  '先生',
#  '全部',
#  '全面',
#  '兮',
#  '共同',
#  '关于',
#  '其',
#  '其一',
#  '其中',
#  '其二',
#  '其他',
#  '其余',
#  '其它',
#  '其实',
#  '其次',
#  '具体',
#  '具体地说',
#  '具体说来',
#  '具有',
#  '再者',
#  '再说',
#  '冒',
#  '冲',
#  '决定',
#  '况且',
#  '准备',
#  '几',
#  '几乎',
#  '几时',
#  '凭',
#  '凭借',
#  '出去',
#  '出来',
#  '出现',
#  '分别',
#  '则',
#  '别',
#  '别的',
#  '别说',
#  '到',
#  '前后',
#  '前者',
#  '前进',
#  '前面',
#  '加之',
#  '加以',
#  '加入',
#  '加强',
#  '十分',
#  '即',
#  '即令',
#  '即使',
#  '即便',
#  '即或',
#  '即若',
#  '却不',
#  '原来',
#  '又',
#  '及',
#  '及其',
#  '及时',
#  '及至',
#  '双方',
#  '反之',
#  '反应',
#  '反映',
#  '反过来',
#  '反过来说',
#  '取得',
#  '受到',
#  '变成',
#  '另',
#  '另一方面',
#  '另外',
#  '只是',
#  '只有',
#  '只要',
#  '只限',
#  '叫',
#  '叫做',
#  '召开',
#  '叮咚',
#  '可',
#  '可以',
#  '可是',
#  '可能',
#  '可见',
#  '各',
#  '各个',
#  '各人',
#  '各位',
#  '各地',
#  '各种',
#  '各级',
#  '各自',
#  '合理',
#  '同',
#  '同一',
#  '同时',
#  '同样',
#  '后来',
#  '后面',
#  '向',
#  '向着',
#  '吓',
#  '吗',
#  '否则',
#  '吧',
#  '吧哒',
#  '吱',
#  '呀',
#  '呃',
#  '呕',
#  '呗',
#  '呜',
#  '呜呼',
#  '呢',
#  '周围',
#  '呵',
#  '呸',
#  '呼哧',
#  '咋',
#  '和',
#  '咚',
#  '咦',
#  '咱',
#  '咱们',
#  '咳',
#  '哇',
#  '哈',
#  '哈哈',
#  '哉',
#  '哎',
#  '哎呀',
#  '哎哟',
#  '哗',
#  '哟',
#  '哦',
#  '哩',
#  '哪',
#  '哪个',
#  '哪些',
#  '哪儿',
#  '哪天',
#  '哪年',
#  '哪怕',
#  '哪样',
#  '哪边',
#  '哪里',
#  '哼',
#  '哼唷',
#  '唉',
#  '啊',
#  '啐',
#  '啥',
#  '啦',
#  '啪达',
#  '喂',
#  '喏',
#  '喔唷',
#  '嗡嗡',
#  '嗬',
#  '嗯',
#  '嗳',
#  '嘎',
#  ...]

# %%
dff_sel = dff[dff.content.str.contains('宁静|静静子|静姐')]
names_countall=[]
names_countall.append( jieba.lcut(dff_sel['content'].str.cat(sep='。'), cut_all=False))

# %%
import jieba

# %%
need_cut=' '.join(names_countall[0])

# %%
mk = imageio.imread('/Users/nika/Desktop/wx-removebg-preview.png')
wordcloud = WordCloud(background_color='white',
                      #设置字体为中文字体！！！
                      font_path="/Library/Fonts/Songti.ttc",
                      #设置清晰度
                      scale=15,mask=mk,stopwords=stop_words).generate(need_cut)
image_colors = ImageColorGenerator(mk)
#将图片颜色应用到词云中
wc_color = wordcloud.recolor(color_func=image_colors)
wc_color.to_file('ciyun.png')
plt.imshow(wc_color)

# %%
import collections # 词频统计库

# %%
seg_list_exact = jieba.cut(need_cut, cut_all=False) # 精确模式分词
object_list = []
for word in seg_list_exact: # 循环读出每个分词
    if word not in stop_words: # 如果不在去除词库中
        object_list.append(word) # 分词追加到列表

word_counts = collections.Counter(object_list) # 对分词做词频统计

# %%
word_counts
# Out:
# Counter({'宁静': 1700,
#          ' ': 16771,
#          'call': 5,
#          '来看': 7,
#          '喜欢': 117,
#          '李斯': 5,
#          '丹妮': 3,
#          '含韵': 4,
#          '丁当': 21,
#          '吴昕': 13,
#          '金晨': 14,
#          '张雨绮': 123,
#          '我来': 3,
#          '姐': 78,
#          '加油': 31,
#          '姐姐': 94,
#          '尖叫': 1,
#          '爱': 45,
#          '大姐大': 22,
#          '静姐': 29,
#          '~': 24,
#          '冲冲': 12,
#          '抖音': 3,
#          '刷到': 1,
#          '很漂亮': 1,
#          '超': 10,
#          '美丽': 1,
#          '魅力': 6,
#          '个性': 8,
#          '静静子': 5,
#          '鸭': 10,
#          '昕姐': 1,
#          '万茜': 38,
#          '…': 63,
#          '姐冲': 2,
#          '蓝盈莹': 12,
#          '期待': 16,
#          'aaaaaaaa': 1,
#          '耳环': 2,
#          '好好看': 8,
#          '粉头': 1,
#          '哦哦哦': 1,
#          '使劲': 1,
#          '努力': 6,
#          '留个': 1,
#          '名': 1,
#          '高位': 1,
#          '越来越': 3,
#          '年轻': 9,
#          '乘风破浪': 1,
#          '偶像': 9,
#          '瘦': 2,
#          '好多': 6,
#          '最美': 3,
#          '真实': 13,
#          '好看': 24,
#          '嚣张': 1,
#          '怎么回事': 1,
#          '脾气': 4,
#          '爆': 1,
#          '礼貌': 1,
#          '两个': 24,
#          '概念': 2,
#          'c': 10,
#          '位出': 7,
#          '太太': 5,
#          '美': 7,
#          '感觉': 50,
#          '不老': 1,
#          '小姐姐': 5,
#          '我会': 1,
#          'ಡ': 4,
#          'ω': 2,
#          'hiahiahia': 2,
#          '耳钉': 1,
#          '好': 146,
#          '想法': 1,
#          '好像': 23,
#          '耳返': 1,
#          '美绝': 1,
#          '敢': 6,
#          '真敢': 1,
#          '真相': 1,
#          '太宣': 1,
#          '俩': 10,
#          'pick': 3,
#          '暴风雨': 18,
#          '节': 1,
#          '万茜冲': 1,
#          '给爷': 3,
#          '雨绮': 8,
#          '琦琦子': 1,
#          '小花': 3,
#          '昕昕子': 1,
#          '1': 1,
#          '茜茜子': 1,
#          '黄圣依': 13,
#          '伊能静': 54,
#          '沈': 7,
#          '梦辰': 13,
#          '黄龄': 9,
#          '孟佳': 2,
#          '王': 4,
#          '丽坤': 3,
#          '钟丽缇': 25,
#          '金莎': 4,
#          '白冰': 10,
#          '刘芸': 7,
#          '霸气': 10,
#          '长得': 3,
#          '一个': 30,
#          '大爷': 1,
#          '压轴': 3,
#          '出场': 2,
#          '节目': 15,
#          '奔': 1,
#          '性格': 29,
#          '排面': 3,
#          '满蒙': 1,
#          '大美人': 1,
#          '艳': 1,
#          '压群芳': 1,
#          '杀气': 1,
#          '我爱你': 5,
#          '可爱': 71,
#          '气场': 34,
#          '完胜': 1,
#          '😯': 1,
#          '妈呀': 4,
#          '死': 75,
#          '快': 10,
#          '太酷': 2,
#          '笑': 90,
#          '料': 1,
#          '我太爱': 4,
#          '预测': 1,
#          '绝': 7,
#          '...': 5,
#          '光脸': 1,
#          '....': 2,
#          '撕': 1,
#          '出名': 1,
#          '真': 21,
#          '好飒': 4,
#          '站': 11,
#          '说话': 15,
#          '一米': 1,
#          '钟比': 1,
#          '大几': 1,
#          '竟然': 5,
#          '简介': 1,
#          '厉害': 10,
#          '代表作': 1,
#          '只能': 2,
#          '不止': 1,
#          '唱歌': 15,
#          '好听': 11,
#          '50': 2,
#          '4': 1,
#          '岁': 7,
#          '天': 5,
#          '48': 2,
#          '哭': 22,
#          '00': 1,
#          '别人': 6,
#          '还要': 4,
#          '看起来': 3,
#          '是因为': 1,
#          '骨头': 1,
#          '垮': 2,
#          '请选': 1,
#          '黑色': 1,
#          '眼角': 1,
#          '瞄': 1,
#          '静静地': 2,
#          '转身': 1,
#          '走': 6,
#          '不愧': 6,
#          '那张': 1,
#          '照片': 1,
#          '好会': 2,
#          '搭配': 1,
#          '霸道': 3,
#          '总裁': 2,
#          '不行': 5,
#          '听到': 2,
#          '声音': 4,
#          '想到': 2,
#          '大玉儿': 1,
#          '很瘦': 1,
#          '姐好': 3,
#          '霸': 1,
#          '总': 3,
#          '好强': 3,
#          '静': 5,
#          '女王': 12,
#          '谢可寅': 3,
#          '强': 7,
#          '太凶了': 1,
#          '聊天': 3,
#          '画风': 4,
#          '同事': 1,
#          '家常': 1,
#          '😄': 9,
#          '互吹': 1,
#          '吹': 3,
#          '运动': 2,
#          '势力': 1,
#          '火': 2,
#          '点': 8,
#          '老娘': 2,
#          '终于': 5,
#          '松口气': 1,
#          '算是': 2,
#          '摆老资': 1,
#          '我充': 1,
#          '会员': 2,
#          '冲着': 2,
#          '保养': 2,
#          '太好了': 3,
#          '简直': 3,
#          '一大': 1,
#          '看点': 6,
#          '一半': 2,
#          '太帅': 2,
#          '这真': 1,
#          '逗': 3,
#          '一群': 2,
#          '美艳': 1,
#          '女人': 9,
#          '老师': 12,
#          '搞笑': 28,
#          '憨憨的': 2,
#          '眼睛': 4,
#          '洋娃娃': 1,
#          '型': 1,
#          '羡慕': 1,
#          '🙉': 1,
#          '说错': 1,
#          '成团': 5,
#          '签到': 1,
#          '我能': 1,
#          '一年': 1,
#          '加上': 1,
#          '表情': 21,
#          '傲娇': 4,
#          '流程': 1,
#          'hhhhhhhhhhh': 1,
#          '下次': 1,
#          '不能不': 1,
#          '喊': 2,
#          '其他人': 1,
#          '涂': 1,
#          '口红': 4,
#          '化妆师': 3,
#          '太飒': 1,
#          '整': 1,
#          '花里胡哨': 1,
#          '干': 3,
#          '选择': 2,
#          '无视': 1,
#          '规则': 1,
#          'I': 1,
#          'don': 1,
#          "'": 3,
#          't': 1,
#          'care': 1,
#          '唇': 1,
#          '印笑': 1,
#          '好美': 2,
#          '呜呜': 1,
#          '太强大': 1,
#          '一枝独秀': 1,
#          '功气': 1,
#          '十足': 1,
#          '位置': 1,
#          '大姐': 7,
#          '好酷': 5,
#          '拽': 18,
#          '发火': 4,
#          '太强': 3,
#          '害怕': 3,
#          '两位': 1,
#          '紧张': 13,
#          '怕': 9,
#          '眼神': 3,
#          '想': 53,
#          'hhhh': 2,
#          '姐太强': 1,
#          '静静': 9,
#          '劲': 2,
#          '😂': 35,
#          '活': 2,
#          '想要': 10,
#          '姐妹': 2,
#          '又帅': 1,
#          '太有': 5,
#          '范儿': 4,
#          '招': 1,
#          '台风': 1,
#          '强行': 1,
#          '营业': 1,
#          '敷衍': 2,
#          '实锤': 1,
#          '大牌': 6,
#          '老': 4,
#          '实力派': 1,
#          '好怕': 1,
#          'os': 2,
#          '快乐': 6,
#          '香香的': 1,
#          '负责': 2,
#          '雅雅': 1,
#          '甜美': 3,
#          '磕': 6,
#          '搞': 3,
#          '主场': 2,
#          '开': 2,
#          'party': 1,
#          '莫名其妙': 1,
#          '围着': 1,
#          '馋': 1,
#          '美女': 8,
#          '姐是': 3,
#          '衣服': 11,
#          '选大': 1,
#          '大概': 2,
#          '很难': 3,
#          '假': 2,
#          '选爱妃': 1,
#          '面子': 2,
#          '啊哈': 4,
#          '憨': 8,
#          '太足': 1,
#          '衣领': 2,
#          '故意': 4,
#          '想唱作': 1,
#          '人里': 1,
#          '郑钧': 1,
#          '所有人': 5,
#          '见': 3,
#          '起立': 1,
#          '领子': 2,
#          '影响': 2,
#          '气质': 4,
#          '本人': 2,
#          '扎': 1,
#          '没弄': 1,
#          '好笑': 11,
#          '好好笑': 1,
#          '看上去': 1,
#          '懵': 1,
#          '铁': 2,
#          '本体': 1,
#          '隐藏': 1,
#          '不住': 2,
#          '自夸': 1,
#          '看着': 3,
#          '面前': 2,
#          '虚': 1,
#          '的确': 1,
#          '世界级': 1,
#          '大奖': 3,
#          '正式': 1,
#          '教导': 1,
#          '主任': 1,
#          '玩': 4,
#          '选秀': 2,
#          '魔王': 1,
#          '年轻人': 2,
#          '8090': 1,
#          '记得': 4,
#          '录过': 1,
#          '农夫': 2,
#          '坐梦晨': 1,
#          '旁边': 3,
#          '一句': 4,
#          '梦晨': 1,
#          '杨': 1,
#          '超越': 1,
#          '住在一起': 1,
#          '五天': 1,
#          '去过': 3,
#          '几期': 1,
#          '火星': 1,
#          '情报局': 1,
#          '老大': 2,
#          '心想': 2,
#          '想着': 1,
#          '介绍': 1,
#          '长辈': 1,
#          '目光': 1,
#          '信': 1,
#          'boss': 1,
#          '选': 7,
#          '女团': 7,
#          '挑人': 1,
#          '队长': 2,
#          '来选': 2,
#          '队员': 2,
#          '顺眼': 2,
#          '领导': 1,
#          '视察': 1,
#          '像是': 1,
#          '长大': 14,
#          '喻言': 3,
#          '我要': 11,
#          '代表': 4,
#          '天呐': 5,
#          '李静': 1,
#          '搞混': 1,
#          'sorry': 1,
#          '合不拢嘴': 2,
#          '突变': 2,
#          '选人': 1,
#          '姐笑': 1,
#          '导师': 5,
#          '旁白': 1,
#          '妆': 4,
#          '捧得': 1,
#          '哪有': 1,
#          '夸张': 1,
#          '锁骨': 1,
#          '这段话': 1,
#          '虞书欣': 3,
#          '孔': 1,
#          '雪儿': 1,
#          '初': 1,
#          '舞台': 2,
#          '伴舞': 3,
#          '有意思': 5,
#          '赵棠': 1,
#          '味儿': 1,
#          '姐太可': 1,
#          '太后': 3,
#          '众星捧月': 1,
#          '抬回': 1,
#          '拼': 2,
#          '直肠子': 1,
#          '😊': 2,
#          '蓝盈盈': 2,
#          '支持': 2,
#          '正剧': 2,
#          '演成': 1,
#          '实绩': 1,
#          '百度': 1,
#          '百科': 1,
#          '长': 3,
#          '几个': 11,
#          '😘': 2,
#          '碰撞': 2,
#          '有没有': 2,
#          '告诉': 1,
#          '人比': 1,
#          '漂亮': 7,
#          '一点': 5,
#          '不输': 1,
#          '～': 5,
#          '火花': 1,
#          'nice': 1,
#          '一组': 18,
#          '红红火火': 1,
#          '化学反应': 1,
#          '这一卦': 1,
#          '超级': 2,
#          '她俩': 4,
#          '圈粉': 3,
#          '最有': 5,
#          '梗': 2,
#          '子': 3,
#          'kdl': 1,
#          '磕到': 2,
#          '没': 25,
#          '拉动': 1,
#          '没想到': 4,
#          '居然': 4,
#          '融洽': 2,
#          '磕死': 1,
#          '搞事': 1,
#          '对手': 1,
#          '反对': 1,
#          '美到': 1,
#          '爆炸': 2,
#          '性感': 3,
#          '发现': 3,
#          '两梗王': 1,
#          '怂': 7,
#          '熟女': 1,
#          '身材': 1,
#          '迷人': 1,
#          '我见': 1,
#          'xswl': 1,
#          '如果说': 1,
#          '郑像': 1,
#          '大哥': 1,
#          '郑希怡': 12,
#          '酷': 1,
#          '年龄': 4,
#          '早就': 2,
#          '大不了': 1,
#          '姐怕': 2,
#          '事': 4,
#          '动': 3,
#          '自动': 2,
#          '轮流': 2,
#          '打招呼': 7,
#          '爱死': 1,
#          '形状': 1,
#          '🐻': 2,
#          '晚辈': 1,
#          '逐个': 1,
#          '请安': 2,
#          '虎': 2,
#          '逼': 1,
#          '好尖': 1,
#          '得罪人': 1,
#          '走动': 1,
#          '接见': 1,
#          '正儿八经': 1,
#          '爆金句': 1,
#          '笑死人': 3,
#          '得罪': 5,
#          '主动': 6,
#          '拜见': 1,
#          '阿朵': 40,
#          '合得来': 1,
#          '担当': 9,
#          '直': 3,
#          '听得出': 1,
#          '咖位': 1,
#          '就算': 2,
#          '找': 3,
#          '姐太': 5,
#          '子好': 1,
#          '花少里': 2,
#          '用刀': 1,
#          '照镜子': 1,
#          '许晴': 2,
#          '张含韵': 7,
#          '姐要': 2,
#          '惊慌失措': 1,
#          '哇哇': 5,
#          '⊙': 2,
#          'o': 1,
#          '握手': 1,
#          '劈叉': 1,
#          '接地': 1,
#          '气': 3,
#          '全是': 2,
#          'hhh': 1,
#          '不用': 4,
#          '高': 11,
#          '冷': 2,
#          '人长': 1,
#          '高冷': 3,
#          '捶': 1,
#          'CP': 3,
#          '来到': 2,
#          '姐请': 1,
#          '下安': 1,
#          '讲真': 1,
#          '有句': 1,
#          '话': 5,
#          '可怕': 3,
#          'hhhhh': 4,
#          '撩': 1,
#          '强大': 4,
#          '参加': 14,
#          '稳如泰山': 1,
#          '张': 3,
#          '互动': 1,
#          '很会': 3,
#          '活跃': 1,
#          '气氛': 1,
#          '怕人': 1,
#          '可唯': 4,
#          '黄玲': 5,
#          '大汉': 11,
#          '天子': 11,
#          '2': 4,
#          '卫子夫': 3,
#          '一脸': 4,
#          '嫌弃': 2,
#          '不屑': 1,
#          '黄晓明': 12,
#          '夫妻': 2,
#          '刘云': 1,
#          '表演': 3,
#          '小明': 1,
#          '莫': 1,
#          'cue': 3,
#          '第一个': 1,
#          '广告': 1,
#          '金沙': 2,
#          '海露': 1,
#          '蓝': 1,
#          '姐站': 1,
#          '熟悉': 1,
#          '绝晓明': 1,
#          '历险记': 1,
#          '咯': 1,
#          '好帅': 5,
#          '绮': 5,
#          '黄金搭档': 1,
#          '不让': 1,
#          '揍': 1,
#          '姐化': 1,
#          '红色': 2,
#          '最具': 1,
#          '东方': 1,
#          '拜托': 2,
#          '镜头': 9,
#          '少': 2,
#          '涂些': 1,
#          '鲜艳': 1,
#          '更好': 3,
#          '看些': 1,
#          '第一次': 5,
#          '秋蝉': 1,
#          '张萌': 3,
#          '神话': 1,
#          '鬓边': 1,
#          '疯狂': 2,
#          '宋茜': 1,
#          '很多': 1,
#          '盲猜': 4,
#          '温柔': 1,
#          '软萌': 1,
#          '二姐': 1,
#          '小妹': 1,
#          '风格': 2,
#          '裙子': 1,
#          '公主': 5,
#          '仙女': 2,
#          '蛮': 4,
#          '耶': 1,
#          '七位': 1,
#          '蓝莹盈': 1,
#          '好炸': 1,
#          '吖': 1,
#          '身': 3,
#          '我天': 1,
#          '坐': 6,
#          'kswl': 1,
#          'cp': 3,
#          '一票': 2,
#          '意外': 1,
#          '坐在': 2,
#          '两人': 1,
#          '合': 1,
#          '三位': 3,
#          '合拍': 1,
#          '好淡定': 4,
#          '请': 3,
#          '行业': 1,
#          '大佬': 3,
#          '能评': 1,
#          '脸': 3,
#          '自然': 2,
#          '名单': 1,
#          '本来': 8,
#          '打个样': 1,
#          '表面': 1,
#          '老作': 1,
#          '高高在上': 1,
#          '摆架子': 5,
#          '尊重': 2,
#          '不去': 1,
#          '海陆': 6,
#          '看不出来': 1,
#          '没错': 2,
#          '可静': 1,
#          '可动': 1,
#          '发型': 4,
#          '造型': 4,
#          '黑眼圈': 3,
#          '版': 1,
#          '哪咤': 1,
#          '认认真真': 1,
#          '多点': 1,
#          '好不好': 3,
#          '挺': 13,
#          '签了': 2,
#          '合约': 3,
#          '人间': 1,
#          'ớ': 1,
#          '₃': 1,
#          'ờ': 1,
#          '棒': 5,
#          '成长': 1,
#          '金牛': 2,
#          '3': 2,
#          '6': 2,
#          '恐怖': 1,
#          '老乡': 1,
#          '姐太逗': 1,
#          '无瓜': 1,
#          '就要': 4,
#          '黄和张': 1,
#          '耍': 1,
#          '尽事': 1,
#          '实力': 7,
#          '选手': 1,
#          '淘汰': 5,
#          '担心': 1,
#          '静静的': 1,
#          '装': 1,
#          '冷漠': 1,
#          '睡': 2,
#          '安静': 9,
#          '反感': 1,
#          '闹哄哄': 1,
#          '场面': 1,
#          '一尊': 1,
#          '佛像': 1,
#          '睡着': 1,
#          '活泼': 1,
#          '睡觉': 2,
#          'hsy': 2,
#          '好稳': 2,
#          '入定': 1,
#          '喷泉': 1,
#          '大快人心': 1,
#          '反正': 1,
#          '感受': 2,
#          '有用': 1,
#          '累': 4,
#          'slay': 1,
#          '做作': 1,
#          '样子': 4,
#          '你好': 1,
#          'man': 1,
#          '打分': 1,
#          '淡定姐': 1,
#          '签': 2,
#          '合同': 2,
#          '一秒': 1,
#          '翻白眼': 1,
#          '后悔': 2,
#          '签合同': 2,
#          '柔和': 1,
#          '不想': 10,
#          '讲': 4,
#          '闯入': 1,
#          '女儿国': 1,
#          '男人': 1,
#          '定': 1,
#          '那心': 1,
#          '老佛爷': 1,
#          '挖': 2,
#          '太逗': 3,
#          '过于': 2,
#          '忍住': 1,
#          '一看': 2,
#          'hold': 2,
#          '住': 5,
#          '别问': 1,
#          '灵魂': 1,
#          '唯我独尊': 1,
#          '确实': 7,
#          '忍': 1,
#          '压制': 1,
#          '怒火': 1,
#          '娇气': 1,
#          '妹妹': 1,
#          '这句': 1,
#          '肯定': 4,
#          '姐困': 2,
#          '2333': 1,
#          '一副': 2,
#          '早已': 1,
#          '看破红尘': 1,
#          '全场': 1,
#          '无表情': 1,
#          '坑': 1,
#          '奔溃': 1,
#          '挖坑': 1,
#          '跳': 6,
#          '门面': 2,
#          '看穿': 1,
#          '充了': 1,
#          '开启': 1,
#          '乖巧': 2,
#          '模式': 2,
#          '叽叽喳喳': 1,
#          '稳重': 1,
#          '端庄': 1,
#          '忍不住': 1,
#          '镇定': 1,
#          '不符': 1,
#          '不红好': 1,
#          '欺负': 3,
#          '100': 1,
#          '分': 4,
#          '观察': 2,
#          '前夕': 1,
#          '有点儿': 1,
#          '嘴唇': 1,
#          '白': 2,
#          '看得出来': 1,
#          '别忍': 1,
#          '一本正经': 1,
#          '逗死': 2,
#          '对比': 2,
#          '完': 4,
#          '煤矿': 1,
#          '朋友': 3,
#          '椰子': 1,
#          '耿直': 2,
#          '很圈': 1,
#          '粉': 3,
#          '不干斯': 1,
#          '话少': 1,
#          '点儿': 1,
#          '怼': 3,
#          '️': 6,
#          '分数': 1,
#          '当场': 1,
#          '发飙': 3,
#          '小辫子': 1,
#          '奶凶奶': 1,
#          '凶': 1,
#          '姐给': 1,
#          '出镜': 1,
#          '没说': 1,
#          '丢不起': 1,
#          '铃个': 1,
#          '这话': 1,
#          '怡怡子': 1,
#          '欣赏': 2,
#          '组个': 2,
#          '霏霏': 2,
#          '搁': 1,
#          '点评': 1,
#          '少数几个': 1,
#          '不起': 1,
#          '太久': 1,
#          'x': 1,
#          '惊呼': 1,
#          '观赏': 1,
#          '以表': 1,
#          '敬意': 1,
#          '双料': 2,
#          '影后': 6,
#          '成员': 2,
#          '演出': 1,
#          '单纯': 2,
#          '综艺': 3,
#          '打赌': 1,
#          '高分': 1,
#          '很少': 1,
#          '发言': 2,
#          '纯路': 1,
#          '过头': 1,
#          '分钟': 1,
#          '点头': 3,
#          '👏': 2,
#          '笑意': 1,
#          '认可': 1,
#          '满意': 2,
#          '点点头': 1,
#          '好乖': 3,
#          '坐月子': 1,
#          '微微': 1,
#          '病人': 1,
#          '身体': 2,
#          '不好': 7,
#          '救命': 1,
#          '疯': 3,
#          '从头到尾': 1,
#          '一种': 1,
#          '状态': 3,
#          '不像': 2,
#          '平常': 1,
#          '场合': 1,
#          '为啥': 4,
#          '话题': 1,
#          '言行': 1,
#          '一模一样': 2,
#          '够颯': 1,
#          '笑容': 1,
#          '变': 3,
#          '偷着乐': 1,
#          '专场': 1,
#          '注意力': 2,
#          '全在': 1,
#          '身上': 2,
#          '力': 2,
#          'max': 1,
#          '唱': 31,
#          '夏天': 8,
#          '好好': 5,
#          '古灵精怪': 1,
#          '娇妻': 1,
#          '关系': 1,
#          '和平': 2,
#          '暴雨': 1,
#          'szd': 1,
#          '嗑': 2,
#          '姐听': 1,
#          '歌是': 2,
#          '一路': 2,
#          '不多成': 1,
#          '团': 2,
#          '蓝莹莹': 3,
#          '吊打': 1,
#          '国内': 1,
#          '韵味': 1,
#          '啥时候': 2,
#          '不适': 1,
#          '各有所长': 1,
#          '百花齐放': 1,
#          '舞蹈': 2,
#          '歌手': 8,
#          '高音': 2,
#          '气势': 3,
#          '那种': 3,
#          '小雨': 1,
#          '重点': 1,
#          '艺人': 2,
#          '算': 3,
#          '问': 2,
#          '才能': 1,
#          '凑': 1,
#          '隔壁': 2,
#          '郁': 2,
#          '来个': 1,
#          '民族': 1,
#          '阳台': 1,
#          '江水': 1,
#          '好哇': 1,
#          '熟': 1,
#          '万': 1,
#          '老板': 1,
#          '后宫': 2,
#          '演技': 3,
#          '不唱': 1,
#          'loving': 5,
#          'you': 4,
#          '子冲': 1,
#          '太牛': 1,
#          '姐有': 1,
#          '海豚音': 5,
#          '多一些': 1,
#          '剧组': 2,
#          '拍戏': 1,
#          '锁死': 1,
#          '超搭': 1,
#          '带': 7,
#          '耳机': 1,
#          '放': 1,
#          '听过': 1,
#          '听': 18,
#          '🐬': 1,
#          '歌': 5,
#          'lovingyou': 2,
#          '惊艳': 2,
#          '呦': 1,
#          '张雨琦才': 1,
#          '占个': 1,
#          '采访': 3,
#          '每次': 4,
#          '嘟嘴': 1,
#          '傻': 2,
#          '白甜': 1,
#          '路线': 1,
#          '冷艳': 1,
#          '卦': 1,
#          '耐看': 1,
#          '五十多': 1,
#          '拿谢': 1,
#          '可寅': 1,
#          '姐比得': 1,
#          '可比性': 1,
#          '🐛': 3,
#          '档次': 1,
#          '勿': 1,
#          '模特': 1,
#          '穿': 25,
#          '适合': 11,
#          '外国': 1,
#          'open': 1,
#          '环境': 1,
#          '本国': 1,
#          '文化': 1,
#          '拘束': 1,
#          '媒体': 2,
#          '天呐人': 1,
#          '美歌': 1,
#          '甜': 1,
#          '系列': 1,
#          '👍': 3,
#          '貂蝉': 6,
#          '版本': 2,
#          '穆桂英': 1,
#          '左': 2,
#          '张雨馨': 1,
#          '副': 1,
#          '主唱': 1,
#          '主舞': 1,
#          ...})

# %%
mk = imageio.imread('/Users/nika/Desktop/wx-removebg-preview.png')
wordcloud = WordCloud(background_color='white',
                      #设置字体为中文字体！！！
                      font_path="/Library/Fonts/Songti.ttc",
                      #设置清晰度
                      scale=15,mask=mk,stopwords=stop_words).generate_from_frequencies(word_counts) # 从字典生成词云
image_colors = ImageColorGenerator(mk)
#将图片颜色应用到词云中
wc_color = wordcloud.recolor(color_func=image_colors)
wc_color.to_file('ciyun.png')
plt.imshow(wc_color)

# %%
word_counts = collections.Counter(need_cut) # 对分词做词频统计

# %%
word_counts
# Out:
# Counter({'宁静': 1700,
#          ' ': 363,
#          'call': 5,
#          '来看': 7,
#          '喜欢': 117,
#          '李斯': 5,
#          '丹妮': 3,
#          '含韵': 4,
#          '丁当': 21,
#          '吴昕': 13,
#          '金晨': 14,
#          '张雨绮': 123,
#          '出道': 16,
#          '我来': 3,
#          '姐': 78,
#          '加油': 31,
#          '姐姐': 94,
#          '尖叫': 1,
#          '爱': 45,
#          '大姐大': 22,
#          '静姐': 29,
#          '~': 24,
#          '冲冲': 12,
#          '抖音': 3,
#          '刷到': 1,
#          '很漂亮': 1,
#          '超': 9,
#          '美丽': 1,
#          '魅力': 6,
#          '个性': 8,
#          '静静子': 5,
#          '鸭': 10,
#          '昕姐': 1,
#          '万茜': 38,
#          '…': 63,
#          '姐冲': 2,
#          '蓝盈莹': 12,
#          '期待': 16,
#          'aaaaaaaa': 1,
#          '耳环': 2,
#          '好好看': 8,
#          '粉头': 1,
#          '哦哦哦': 1,
#          '使劲': 1,
#          '努力': 6,
#          '留个': 1,
#          '名': 1,
#          '高位': 1,
#          '越来越': 3,
#          '年轻': 9,
#          '乘风破浪': 1,
#          '偶像': 9,
#          '瘦': 2,
#          '好多': 6,
#          '最美': 3,
#          '真实': 13,
#          '好看': 24,
#          '嚣张': 1,
#          '怎么回事': 1,
#          '脾气': 4,
#          '爆': 1,
#          '礼貌': 1,
#          '两个': 24,
#          '概念': 2,
#          'c': 10,
#          '位出': 7,
#          '太太': 5,
#          '太美': 4,
#          '感觉': 50,
#          '不老': 1,
#          '小姐姐': 5,
#          '我会': 1,
#          'ಡ': 4,
#          'ω': 2,
#          'hiahiahia': 2,
#          '耳钉': 1,
#          '好': 146,
#          '想法': 1,
#          '好像': 23,
#          '耳返': 1,
#          '美绝': 1,
#          '敢': 6,
#          '真敢': 1,
#          '真相': 1,
#          '太宣': 1,
#          '俩': 9,
#          'pick': 3,
#          '暴风雨': 18,
#          '节': 1,
#          '万茜冲': 1,
#          '给爷': 3,
#          '雨绮': 8,
#          '琦琦子': 1,
#          '小花': 3,
#          '昕昕子': 1,
#          '1': 1,
#          '茜茜子': 1,
#          '黄圣依': 13,
#          '伊能静': 54,
#          '沈': 7,
#          '梦辰': 13,
#          '黄龄': 9,
#          '孟佳': 2,
#          '王': 4,
#          '丽坤': 3,
#          '钟丽缇': 25,
#          '金莎': 4,
#          '白冰': 10,
#          '刘芸': 7,
#          '霸气': 10,
#          '长得': 3,
#          '一个': 30,
#          '大爷': 1,
#          '压轴': 3,
#          '出场': 2,
#          '节目': 15,
#          '奔': 1,
#          '性格': 29,
#          '排面': 3,
#          '满蒙': 1,
#          '大美人': 1,
#          '艳': 1,
#          '压群芳': 1,
#          '杀气': 1,
#          '我爱你': 5,
#          '可爱': 71,
#          '气场': 34,
#          '完胜': 1,
#          '😯': 1,
#          '妈呀': 4,
#          '死': 75,
#          '快': 10,
#          '太酷': 2,
#          '笑': 90,
#          '不出': 1,
#          '所料': 1,
#          '我太爱': 4,
#          '预测': 1,
#          '绝': 7,
#          '...': 5,
#          '光脸': 1,
#          '....': 2,
#          '撕': 1,
#          '出名': 1,
#          '真': 19,
#          '好飒': 4,
#          '站': 11,
#          '说话': 15,
#          '一米': 1,
#          '钟比': 1,
#          '大几': 1,
#          '竟然': 5,
#          '简介': 1,
#          '厉害': 10,
#          '代表作': 1,
#          '只能': 2,
#          '不止': 1,
#          '唱歌': 15,
#          '好听': 11,
#          '50': 2,
#          '4': 1,
#          '岁': 7,
#          '天': 5,
#          '48': 2,
#          '哭': 22,
#          '00': 1,
#          '别人': 6,
#          '还要': 4,
#          '看起来': 3,
#          '是因为': 1,
#          '骨头': 1,
#          '垮': 2,
#          '请选': 1,
#          '黑色': 1,
#          '眼角': 1,
#          '瞄': 1,
#          '静静地': 2,
#          '转身': 1,
#          '走': 5,
#          '不愧': 6,
#          '那张': 1,
#          '照片': 1,
#          '好会': 2,
#          '搭配': 1,
#          '霸道': 3,
#          '总裁': 2,
#          '不行': 5,
#          '听到': 2,
#          '声音': 4,
#          '想到': 2,
#          '大玉儿': 1,
#          '很瘦': 1,
#          '姐好': 3,
#          '霸': 1,
#          '总': 3,
#          '好强': 3,
#          '静': 5,
#          '女王': 12,
#          '谢可寅': 3,
#          '强': 7,
#          '太凶了': 1,
#          '聊天': 3,
#          '画风': 4,
#          '同事': 1,
#          '家常': 1,
#          '😄': 9,
#          '互吹': 1,
#          '吹': 3,
#          '运动': 2,
#          '势力': 1,
#          '火': 2,
#          '点': 8,
#          '老娘': 2,
#          '终于': 5,
#          '松口气': 1,
#          '算是': 2,
#          '摆老资': 1,
#          '我充': 1,
#          '会员': 2,
#          '冲着': 2,
#          '保养': 2,
#          '太好了': 3,
#          '简直': 3,
#          '一大': 1,
#          '看点': 6,
#          '一半': 2,
#          '太帅': 2,
#          '这真': 1,
#          '逗': 3,
#          '一群': 2,
#          '美艳': 1,
#          '女人': 9,
#          '老师': 12,
#          '搞笑': 28,
#          '憨憨的': 2,
#          '眼睛': 4,
#          '洋娃娃': 1,
#          '型': 1,
#          '羡慕': 1,
#          '🙉': 1,
#          '说错': 1,
#          '成团': 5,
#          '签到': 1,
#          '我能': 1,
#          '一年': 1,
#          '加上': 1,
#          '表情': 21,
#          '傲娇': 4,
#          '流程': 1,
#          'hhhhhhhhhhh': 1,
#          '下次': 1,
#          '不能不': 1,
#          '喊': 2,
#          '其他人': 1,
#          '涂': 1,
#          '口红': 4,
#          '化妆师': 3,
#          '太飒': 1,
#          '整': 1,
#          '花里胡哨': 1,
#          '干': 3,
#          '选择': 2,
#          '无视': 1,
#          '规则': 1,
#          'I': 1,
#          'don': 1,
#          "'": 3,
#          't': 1,
#          'care': 1,
#          '唇': 1,
#          '印笑': 1,
#          '好美': 2,
#          '呜呜': 1,
#          '太强大': 1,
#          '一枝独秀': 1,
#          '功气': 1,
#          '十足': 1,
#          '位置': 1,
#          '大姐': 7,
#          '好酷': 5,
#          '拽': 18,
#          '发火': 4,
#          '太强': 3,
#          '害怕': 3,
#          '两位': 1,
#          '紧张': 13,
#          '怕': 9,
#          '眼神': 3,
#          '想': 52,
#          'hhhh': 2,
#          '姐太强': 1,
#          '静静': 9,
#          '劲': 2,
#          '😂': 35,
#          '活': 2,
#          '想要': 10,
#          '姐妹': 2,
#          '又帅': 1,
#          '太有': 5,
#          '范儿': 4,
#          '招': 1,
#          '台风': 1,
#          '强行': 1,
#          '营业': 1,
#          '敷衍': 2,
#          '实锤': 1,
#          '大牌': 6,
#          '老': 4,
#          '实力派': 1,
#          '好怕': 1,
#          'os': 2,
#          '快乐': 6,
#          '香香的': 1,
#          '负责': 2,
#          '雅雅': 1,
#          '甜美': 3,
#          '磕': 6,
#          '搞': 3,
#          '主场': 2,
#          '开': 2,
#          'party': 1,
#          '莫名其妙': 1,
#          '围着': 1,
#          '馋': 1,
#          '美女': 8,
#          '姐是': 3,
#          '衣服': 11,
#          '选大': 1,
#          '大概': 2,
#          '很难': 3,
#          '假': 2,
#          '选爱妃': 1,
#          '面子': 2,
#          '啊哈': 4,
#          '憨': 8,
#          '太足': 1,
#          '衣领': 2,
#          '故意': 4,
#          '想唱作': 1,
#          '人里': 1,
#          '郑钧': 1,
#          '所有人': 5,
#          '见': 3,
#          '起立': 1,
#          '领子': 2,
#          '影响': 2,
#          '气质': 4,
#          '本人': 2,
#          '扎': 1,
#          '没弄': 1,
#          '好笑': 11,
#          '好好笑': 1,
#          '看上去': 1,
#          '懵': 1,
#          '铁': 2,
#          '本体': 1,
#          '隐藏': 1,
#          '不住': 2,
#          '自夸': 1,
#          '看着': 3,
#          '面前': 2,
#          '虚': 1,
#          '的确': 1,
#          '世界级': 1,
#          '大奖': 3,
#          '正式': 1,
#          '教导': 1,
#          '主任': 1,
#          '玩': 4,
#          '选秀': 2,
#          '魔王': 1,
#          '年轻人': 2,
#          '8090': 1,
#          '记得': 4,
#          '录过': 1,
#          '农夫': 2,
#          '坐梦晨': 1,
#          '旁边': 3,
#          '一句': 4,
#          '梦晨': 1,
#          '杨': 1,
#          '超越': 1,
#          '住在一起': 1,
#          '五天': 1,
#          '去过': 3,
#          '几期': 1,
#          '火星': 1,
#          '情报局': 1,
#          '老大': 2,
#          '心想': 2,
#          '想着': 1,
#          '介绍': 1,
#          '长辈': 1,
#          '目光': 1,
#          '信': 1,
#          'boss': 1,
#          '选': 6,
#          '女团': 7,
#          '挑人': 1,
#          '队长': 2,
#          '来选': 2,
#          '队员': 2,
#          '顺眼': 2,
#          '领导': 1,
#          '视察': 1,
#          '像是': 1,
#          '长大': 14,
#          '喻言': 3,
#          '我要': 11,
#          '代表': 4,
#          '天呐': 5,
#          '李静': 1,
#          '搞混': 1,
#          'sorry': 1,
#          '合不拢嘴': 2,
#          '突变': 2,
#          '选人': 1,
#          '姐笑': 1,
#          '导师': 5,
#          '旁白': 1,
#          '妆': 4,
#          '捧得': 1,
#          '哪有': 1,
#          '夸张': 1,
#          '锁骨': 1,
#          '这段话': 1,
#          '虞书欣': 3,
#          '孔': 1,
#          '雪儿': 1,
#          '初': 1,
#          '舞台': 2,
#          '伴舞': 3,
#          '有意思': 5,
#          '赵棠': 1,
#          '味儿': 1,
#          '姐太可': 1,
#          '太后': 3,
#          '众星捧月': 1,
#          '抬回': 1,
#          '拼': 2,
#          '直肠子': 1,
#          '😊': 2,
#          '蓝盈盈': 2,
#          '支持': 2,
#          '正剧': 2,
#          '演成': 1,
#          '实绩': 1,
#          '百度': 1,
#          '百科': 1,
#          '长': 3,
#          '几个': 11,
#          '😘': 2,
#          '碰撞': 2,
#          '有没有': 2,
#          '告诉': 1,
#          '人比': 1,
#          '漂亮': 7,
#          '一点': 5,
#          '不输': 1,
#          '～': 5,
#          '火花': 1,
#          'nice': 1,
#          '一组': 18,
#          '红红火火': 1,
#          '化学反应': 1,
#          '这一卦': 1,
#          '超级': 2,
#          '她俩': 4,
#          '圈粉': 3,
#          '最有': 5,
#          '梗': 2,
#          '子': 2,
#          '子会': 1,
#          'kdl': 1,
#          '磕到': 2,
#          '没': 23,
#          '拉动': 1,
#          '没想到': 4,
#          '居然': 4,
#          '融洽': 2,
#          '磕死': 1,
#          '搞事': 1,
#          '对手': 1,
#          '反对': 1,
#          '美到': 1,
#          '爆炸': 2,
#          '性感': 3,
#          '发现': 3,
#          '两梗王': 1,
#          '怂': 7,
#          '熟女': 1,
#          '身材': 1,
#          '迷人': 1,
#          '我见': 1,
#          'xswl': 1,
#          '如果说': 1,
#          '郑像': 1,
#          '大哥': 1,
#          '郑希怡': 12,
#          '酷': 1,
#          '年龄': 4,
#          '早就': 2,
#          '大不了': 1,
#          '姐怕': 2,
#          '事': 4,
#          '动': 3,
#          '自动': 2,
#          '轮流': 2,
#          '打招呼': 7,
#          '爱死': 1,
#          '形状': 1,
#          '🐻': 2,
#          '晚辈': 1,
#          '逐个': 1,
#          '请安': 2,
#          '虎': 2,
#          '逼': 1,
#          '好尖': 1,
#          '得罪人': 1,
#          '走动': 1,
#          '接见': 1,
#          '正儿八经': 1,
#          '爆金句': 1,
#          '笑死人': 3,
#          '得罪': 5,
#          '主动': 6,
#          '拜见': 1,
#          '阿朵': 40,
#          '合得来': 1,
#          '担当': 9,
#          '直': 3,
#          '听得出': 1,
#          '咖位': 1,
#          '就算': 2,
#          '找': 3,
#          '姐太': 5,
#          '子好': 1,
#          '花少里': 2,
#          '用刀': 1,
#          '照镜子': 1,
#          '许晴': 2,
#          '张含韵': 7,
#          '姐要': 2,
#          '惊慌失措': 1,
#          '哇哇': 5,
#          '⊙': 2,
#          'o': 1,
#          '握手': 1,
#          '劈叉': 1,
#          '接地': 1,
#          '气': 3,
#          '全是': 2,
#          'hhh': 1,
#          '不用': 4,
#          '高': 11,
#          '冷': 2,
#          '人长': 1,
#          '高冷': 3,
#          '捶': 1,
#          'CP': 3,
#          '来到': 2,
#          '姐请': 1,
#          '下安': 1,
#          '讲真': 1,
#          '有句': 1,
#          '话': 5,
#          '可怕': 3,
#          'hhhhh': 4,
#          '撩': 1,
#          '强大': 4,
#          '参加': 14,
#          '稳如泰山': 1,
#          '张': 3,
#          '互动': 1,
#          '很会': 3,
#          '活跃': 1,
#          '气氛': 1,
#          '怕人': 1,
#          '可唯': 4,
#          '黄玲': 5,
#          '大汉': 11,
#          '天子': 11,
#          '2': 4,
#          '卫子夫': 3,
#          '一脸': 4,
#          '嫌弃': 2,
#          '不屑': 1,
#          '黄晓明': 12,
#          '夫妻': 2,
#          '刘云': 1,
#          '表演': 3,
#          '小明': 1,
#          '莫': 1,
#          'cue': 3,
#          '第一个': 1,
#          '广告': 1,
#          '金沙': 2,
#          '海露': 1,
#          '蓝': 1,
#          '姐站': 1,
#          '熟悉': 1,
#          '绝晓明': 1,
#          '历险记': 1,
#          '咯': 1,
#          '好帅': 5,
#          '绮': 5,
#          '黄金搭档': 1,
#          '不让': 1,
#          '揍': 1,
#          '姐化': 1,
#          '红色': 2,
#          '最具': 1,
#          '东方': 1,
#          '拜托': 2,
#          '镜头': 9,
#          '少': 2,
#          '涂些': 1,
#          '鲜艳': 1,
#          '更好': 3,
#          '看些': 1,
#          '第一次': 5,
#          '演过': 1,
#          '秋蝉': 1,
#          '张萌': 3,
#          '神话': 1,
#          '鬓边': 1,
#          '疯狂': 2,
#          '宋茜': 1,
#          '很多': 1,
#          '盲猜': 4,
#          '温柔': 1,
#          '软萌': 1,
#          '二姐': 1,
#          '小妹': 1,
#          '风格': 2,
#          '裙子': 1,
#          '公主': 5,
#          '仙女': 2,
#          '蛮': 4,
#          '耶': 1,
#          '七位': 1,
#          '蓝莹盈': 1,
#          '好炸': 1,
#          '吖': 1,
#          '这身': 2,
#          '我天': 1,
#          '坐': 6,
#          'kswl': 1,
#          'cp': 3,
#          '一票': 2,
#          '意外': 1,
#          '坐在': 2,
#          '两人': 1,
#          '合': 1,
#          '三位': 3,
#          '合拍': 1,
#          '好淡定': 4,
#          '请': 3,
#          '行业': 1,
#          '大佬': 3,
#          '能评': 1,
#          '脸': 3,
#          '自然': 2,
#          '名单': 1,
#          '本来': 8,
#          '打个样': 1,
#          '表面': 1,
#          '老作': 1,
#          '高高在上': 1,
#          '摆架子': 5,
#          '尊重': 2,
#          '不去': 1,
#          '海陆': 6,
#          '看不出来': 1,
#          '没错': 2,
#          '可静': 1,
#          '可动': 1,
#          '发型': 4,
#          '造型': 4,
#          '黑眼圈': 3,
#          '版': 1,
#          '哪咤': 1,
#          '认认真真': 1,
#          '多点': 1,
#          '好不好': 3,
#          '挺': 13,
#          '签了': 2,
#          '合约': 3,
#          '人间': 1,
#          'ớ': 1,
#          '₃': 1,
#          'ờ': 1,
#          '棒': 5,
#          '成长': 1,
#          '金牛': 2,
#          '3': 2,
#          '6': 2,
#          '恐怖': 1,
#          '老乡': 1,
#          '姐太逗': 1,
#          '无瓜': 1,
#          '就要': 4,
#          '黄和张': 1,
#          '耍': 1,
#          '尽事': 1,
#          '实力': 7,
#          '选手': 1,
#          '淘汰': 5,
#          '担心': 1,
#          '静静的': 1,
#          '装': 1,
#          '冷漠': 1,
#          '睡': 2,
#          '安静': 9,
#          '反感': 1,
#          '闹哄哄': 1,
#          '场面': 1,
#          '一尊': 1,
#          '佛像': 1,
#          '睡着': 1,
#          '活泼': 1,
#          '睡觉': 2,
#          'hsy': 2,
#          '好稳': 2,
#          '入定': 1,
#          '喷泉': 1,
#          '大快人心': 1,
#          '反正': 1,
#          '感受': 2,
#          '有用': 1,
#          '累': 3,
#          'slay': 1,
#          '做作': 1,
#          '样子': 4,
#          '你好': 1,
#          'man': 1,
#          '打分': 1,
#          '淡定姐': 1,
#          '签': 2,
#          '合同': 2,
#          '一秒': 1,
#          '翻白眼': 1,
#          '后悔': 2,
#          '签合同': 2,
#          '柔和': 1,
#          '不想': 10,
#          '讲': 4,
#          '闯入': 1,
#          '女儿国': 1,
#          '男人': 1,
#          '定': 1,
#          '那心': 1,
#          '老佛爷': 1,
#          '挖': 2,
#          '太逗': 3,
#          '过于': 2,
#          '忍住': 1,
#          '一看': 2,
#          'hold': 2,
#          '住': 5,
#          '别问': 1,
#          '灵魂': 1,
#          '唯我独尊': 1,
#          '确实': 7,
#          '忍': 1,
#          '压制': 1,
#          '怒火': 1,
#          '娇气': 1,
#          '妹妹': 1,
#          '这句': 1,
#          '肯定': 4,
#          '姐困': 2,
#          '2333': 1,
#          '一副': 2,
#          '早已': 1,
#          '看破红尘': 1,
#          '全场': 1,
#          '无表情': 1,
#          '坑': 1,
#          '奔溃': 1,
#          '挖坑': 1,
#          '跳': 6,
#          '门面': 2,
#          '看穿': 1,
#          '充了': 1,
#          '开启': 1,
#          '乖巧': 2,
#          '模式': 2,
#          '叽叽喳喳': 1,
#          '稳重': 1,
#          '端庄': 1,
#          '忍不住': 1,
#          '镇定': 1,
#          '不符': 1,
#          '不红好': 1,
#          '欺负': 3,
#          '100': 1,
#          '分': 4,
#          '观察': 2,
#          '前夕': 1,
#          '有点儿': 1,
#          '嘴唇': 1,
#          '白': 2,
#          '看得出来': 1,
#          '别忍': 1,
#          '一本正经': 1,
#          '逗死': 2,
#          '对比': 2,
#          '完': 4,
#          '煤矿': 1,
#          '朋友': 3,
#          '椰子': 1,
#          '耿直': 2,
#          '很圈': 1,
#          '粉': 3,
#          '不干斯': 1,
#          '话少': 1,
#          '点儿': 1,
#          '怼': 3,
#          '️': 6,
#          '分数': 1,
#          '当场': 1,
#          '发飙': 3,
#          '小辫子': 1,
#          '奶凶奶': 1,
#          '凶': 1,
#          '姐给': 1,
#          '出镜': 1,
#          '没说': 1,
#          '丢不起': 1,
#          '铃个': 1,
#          '这话': 1,
#          '怡怡子': 1,
#          '欣赏': 2,
#          '组个': 2,
#          '霏霏': 2,
#          '搁': 1,
#          '超想': 1,
#          '点评': 1,
#          '少数几个': 1,
#          '不起': 1,
#          '太久': 1,
#          'x': 1,
#          '惊呼': 1,
#          '观赏': 1,
#          '以表': 1,
#          '敬意': 1,
#          '双料': 2,
#          '影后': 6,
#          '成员': 2,
#          '演出': 1,
#          '单纯': 2,
#          '综艺': 3,
#          '打赌': 1,
#          '高分': 1,
#          '很少': 1,
#          '发言': 2,
#          '纯路': 1,
#          '过头': 1,
#          '分钟': 1,
#          '点头': 3,
#          '👏': 2,
#          '笑意': 1,
#          '认可': 1,
#          '满意': 2,
#          '点点头': 1,
#          '好乖': 3,
#          '坐月子': 1,
#          '微微': 1,
#          '病人': 1,
#          '身体': 2,
#          '不好': 7,
#          '救命': 1,
#          '疯': 3,
#          '从头到尾': 1,
#          '一种': 1,
#          '状态': 3,
#          '不像': 2,
#          '平常': 1,
#          '场合': 1,
#          '为啥': 4,
#          '话题': 1,
#          '言行': 1,
#          '一模一样': 2,
#          '够颯': 1,
#          '笑容': 1,
#          '没变': 1,
#          '偷着乐': 1,
#          '专场': 1,
#          '注意力': 2,
#          '全在': 1,
#          '身上': 2,
#          '力': 2,
#          'max': 1,
#          '唱': 31,
#          '夏天': 8,
#          '好好': 5,
#          '古灵精怪': 1,
#          '娇妻': 1,
#          '这俩': 1,
#          '关系': 1,
#          '和平': 2,
#          '暴雨': 1,
#          'szd': 1,
#          '嗑': 2,
#          '姐听': 1,
#          '歌是': 2,
#          '一路': 2,
#          '不多成': 1,
#          '团': 2,
#          '蓝莹莹': 3,
#          '吊打': 1,
#          '国内': 1,
#          '韵味': 1,
#          '啥时候': 2,
#          '不适': 1,
#          '各有所长': 1,
#          '百花齐放': 1,
#          '舞蹈': 2,
#          '歌手': 8,
#          '高音': 2,
#          '气势': 3,
#          '那种': 3,
#          '小雨': 1,
#          '重点': 1,
#          '艺人': 2,
#          '算': 3,
#          '问': 2,
#          '才能': 1,
#          '凑': 1,
#          '隔壁': 2,
#          '郁': 2,
#          '来个': 1,
#          '民族': 1,
#          '阳台': 1,
#          '江水': 1,
#          '好哇': 1,
#          '不熟': 1,
#          '万': 1,
#          '老板': 1,
#          '后宫': 2,
#          '演技': 3,
#          '不唱': 1,
#          'loving': 5,
#          'you': 4,
#          '子冲': 1,
#          '太牛': 1,
#          '姐有': 1,
#          '海豚音': 5,
#          '多一些': 1,
#          '剧组': 2,
#          '拍戏': 1,
#          '锁死': 1,
#          '超搭': 1,
#          '带': 7,
#          '耳机': 1,
#          '放': 1,
#          '听过': 1,
#          '听': 18,
#          '🐬': 1,
#          '歌': 5,
#          'lovingyou': 2,
#          '惊艳': 2,
#          '呦': 1,
#          '张雨琦才': 1,
#          '占个': 1,
#          '采访': 3,
#          '每次': 4,
#          '嘟嘴': 1,
#          '傻': 2,
#          '白甜': 1,
#          '路线': 1,
#          '冷艳': 1,
#          '卦': 1,
#          '耐看': 1,
#          '五十多': 1,
#          '拿谢': 1,
#          '可寅': 1,
#          '姐比得': 1,
#          '可比性': 1,
#          '🐛': 3,
#          '档次': 1,
#          '勿': 1,
#          '身': 1,
#          '模特': 1,
#          '穿': 25,
#          '适合': 11,
#          '外国': 1,
#          'open': 1,
#          '环境': 1,
#          '本国': 1,
#          '文化': 1,
#          '拘束': 1,
#          '媒体': 2,
#          '天呐人': 1,
#          '美歌': 1,
#          '甜': 1,
#          '系列': 1,
#          '👍': 3,
#          '貂蝉': 6,
#          ...})

# %%
def get_photo(name):
    
    #设置停止词
    stop_words = []    
    with open(r"/Users/nika/Desktop/chineseStopWords.txt") as f:
        lines = f.readlines()
        for line in lines:
            stop_words.append(line.strip())
    #自定义停止词
    my_stop_words = ['第一期', '一堆', '三个', '真的', '哈哈哈', '哈哈哈哈', '啊啊啊']    
    stop_words.extend(my_stop_words)  
    
    dff_sel = dff[dff.content.str.contains(name)]
    seg_list_exact = jieba.cut(dff_sel['content'].str.cat(sep='。'), cut_all=False) # 精确模式分词
    object_list = []
    for word in seg_list_exact: # 循环读出每个分词
        if word not in stop_words: # 如果不在去除词库中
            object_list.append(word) # 分词追加到列表

    word_counts = collections.Counter(object_list) # 对分词做词频统计
    
    re_pic='/Users/nika/Desktop/jiejie/'+name+'.png'
    mk = imageio.imread(re_pic)
    wordcloud = WordCloud(background_color='white',
                          #设置字体为中文字体！！！
                          font_path="/Library/Fonts/Songti.ttc",
                          #设置清晰度
                          scale=15,mask=mk,stopwords=stop_words).generate_from_frequencies(word_counts) # 从字典生成词云
    image_colors = ImageColorGenerator(mk)
    #将图片颜色应用到词云中
    wc_color = wordcloud.recolor(color_func=image_colors)
    new_pic='/Users/nika/Desktop/jiejie/'+'new_'+name+'.png'
    wc_color.to_file(new_pic)
    plt.imshow(wc_color)

# %%
name='宁静'
get_photo(name)

# %%
my_words_list =['袁咏琳','朱婧汐','钟丽缇','王智','沈梦辰','陈松伶','阿朵','白冰','海陆','刘芸','孟佳','金莎','伊能静','王霏霏','许飞','张萌',
                '黄龄','吴昕','金晨','王丽坤','李斯丹妮','蓝盈莹','张含韵','郑希怡','宁静','郁可唯','黄圣依','丁当','万茜','张雨绮']
for name in my_words_list:
    get_photo(name)

# %%
names_countall = []

for name in my_words_list:
    # 筛选
    df_sel = dff[dff.content.str.contains(name)]
    # 弹幕/点赞数
    names_count = df_sel.shape[0]
    # 追加
    names_countall.append(names_count)

# %%
my_words_list.names_countall
# Out:
# [288,
#  371,
#  1069,
#  492,
#  842,
#  355,
#  897,
#  1627,
#  1920,
#  514,
#  595,
#  867,
#  2082,
#  246,
#  1489,
#  812,
#  1293,
#  1601,
#  1872,
#  806,
#  737,
#  809,
#  852,
#  1102,
#  1656,
#  1195,
#  921,
#  2642,
#  2941,
#  2723]
